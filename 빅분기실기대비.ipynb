# %%
# 데이터프레임, 원핫인코딩, 데이터 병합
from pandas import DataFrame,get_dummies, concat, read_excel

# 정규성검정, t검정, f검정
from scipy.stats import (
    shapiro,
    normaltest,
    bartlett, # 가설검정
    levene, # 가설검정
    ttest_1samp, # 단일 표본
    ttest_ind, # 독립표본
    ttest_rel, # 대응표본
    f_oneway, # f검정
    chisquare, # 카이제곱검정
    t, # 신뢰구간 계산시 필요
    binom, # 이항분포
    poisson, # 포아송분포
)

# chisquare(f_obs=관측된빈도, f_exp=예상빈도)

# 상관계수
DataFrame().corr(method='spearman'          #'pearson'         #'kendall'
)

# 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier

# 데이터분할, 스케일러
from sklearn.model_selection import train_test_split # __all__에 있음
from sklearn.preprocessing import StandardScaler, MinMaxScaler # __all__에 있음


# VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 선형회귀 - 릿지, 라쏘, 로지스틱회귀
from sklearn.linear_model import ( # __all__에 있음
    LinearRegression,
    Ridge,
    Lasso,
    LogisticRegression
    )

# 신뢰구간 계산법, 샘플평균 = 점추정
# sample_std_error =  df['변수명'].std(ddof=1)/(len(df)**0.5)
# cmin, cmax = t.interval(clevel, len(df)-1, loc=sample_mean, scale=sample_std_error) # interval(신뢰도, 자유도, loc=샘플평균, scale=샘플표준오차)

# 이항분포 계산번
# binom.pmf(관측하고자하는 성공횟수, 전체시도횟수, 각 시도에서 성공할 확률)

# 포아송분포 계산법
# poisson.pmf(n번, 평균발생횟수)


import sklearn, scipy



# scipy.stats.__all__
# sklearn.__all__

# %% [markdown]
# # pandas 통계함수
#
# | 통계 | 함수 |
# | -- | -- |
# | 분위수 | .quantile |
# | 분산 | .var |
# | 표준편차 | .std |
# | 왜도 | .skew |
# | 첨도 | .kurt |
# | 누적합 | .cumsum |
# | 누적곱 | .cumprod |
# | 누적 최대값 | .cummax |
# | 누적 최소값 |.cummin |
#
# round(숫자, 자리수) 자리수에 해당하는 숫자까지 나옴, 예를들어 round(0.1234,2) = 0.12
