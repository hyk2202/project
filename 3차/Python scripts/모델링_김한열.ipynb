# %%
# pip install --upgrade git+https://github.com/hyk2202/helper.git

import pandas as pd
from helper.util import *
from helper.analysis import *
from helper.tensor import *
from helper.plot import *
from helper.timeserise import *
from helper.core import *
from helper.classification import *
from helper.re import *
from helper.regression import *

# %%
origin = my_read_data('데이터_전처리_최종.xlsx',info=False, index_col='IDX')

# %%
df = origin.copy()
df.columns
# Out:
# Index(['발생날짜', '요일', '공휴일여부', '오전오후', '시간대', '시간', '사고인지 시간', '공공/민간 구분', '날씨',
#        '기온', '습도', '인적사고', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호', '공종_대분류',
#        '공종_중분류', '사고객체_대분류', '사고객체_중분류', '작업프로세스', '장소_대분류', '장소_중분류',
#        '부위_대분류', '부위_중분류', '사고원인_주원인', '사상자수', '사고신고사유_부상', '사고신고사유_사망',
#        '사고신고사유_물적', '시', '전체공사비', '전체공사비_분류', '해당공종_공사비', '구체적 사고원인',
#        '사고발생후 조치사항', '공사기간_시작일', '공사기간_종료일', '공종_시작일', '공종_종료일', '재발방지대책',
#        '공정률', '안전관리계획', '설계안전성검토', '작업자수', '지점 번호', '관측소', '기온.1', '강수량', '풍속',
#        '풍향', '습도.1', '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량',
#        '시정', '지면온도'],
#       dtype='object')

# %%
df.drop(['발생날짜','지점 번호','관측소'],axis=1,inplace=True)

# %%
temp = []
for i in df['인적사고']:
    if i == '기타':temp.append('분류불능')
    elif i == '없음':temp.append(None)
    else:temp.append(i)

df['인적사고'] = temp
df['인적사고'].value_counts()
# Out:
# 넘어짐       5814
# 떨어짐       4321
# 물체에 맞음    3509
# 끼임        2576
# 분류불능      2152
# 부딪힘       1850
# 절단, 베임    1688
# 깔림         521
# 질병         381
# 찔림         307
# 화상         186
# 교통사고       123
# 감전          48
# 질식          18
# Name: 인적사고, dtype: int64

# %%
temp =[]
for i in df['강수량']:
    if i>=0.1 : temp.append(1)
    else:temp.append(0)

# %%
# 결측치 : 0 정규작업 :1 그외: 2

temp = []
for i in df['사고인지 시간'].fillna(0):
    if i == 0 : temp.append(0)
    elif i == '정규작업 ': temp.append(1)
    else:temp.append(2)

df['사고인지 시간'] = temp
df['사고인지 시간'].value_counts()
# Out:
# 1    18032
# 0     3167
# 2     2523
# Name: 사고인지 시간, dtype: int64

# %%
# 결측치 : 0, 조치/해당없음:1, 비조치:2

temp = []
for i in df["보호(방호)조치여부 - 안전방호"].fillna(0):
    if i == 0 :temp.append(0)
    elif i == '비조치': temp.append(2)
    else:temp.append(1)
df["보호(방호)조치여부 - 안전방호"] =temp


df["보호(방호)조치여부 - 안전방호"].value_counts()
# Out:
# 1    17153
# 0     5411
# 2     1158
# Name: 보호(방호)조치여부 - 안전방호, dtype: int64

# %%
# 결측치 : 0, 조치/해당없음:1, 비조치:2

temp = []
for i in df["보호(방호)조치여부 - 개인방호"].fillna(0):
    if i == 0 :temp.append(0)
    elif i == '비조치': temp.append(2)
    else:temp.append(1)
df["보호(방호)조치여부 - 개인방호"] =temp


df["보호(방호)조치여부 - 개인방호"].value_counts()
# Out:
# 1    17455
# 0     5410
# 2      857
# Name: 보호(방호)조치여부 - 개인방호, dtype: int64

# %%
# 통신설비, 산업설비, 전기설비 => 기타
temp = []
for i in df['공종_대분류']:
    if i in ['통신설비','산업설비','전기설비']:temp.append('기타')
    else:temp.append(i)
df['공종_대분류'] =temp

# %%
# 비조치 :2 , 조치,해당없음 : 1 ,결측치 : 0
temp = []
for i in origin["작업프로세스"]:
    if i == '비조치': temp.append(2)
    elif i ==0:temp.append(1)
    else:temp.append(0)

# %%
#노동부고시 제2002-8호, 『화학물질 및 물리적인자의 노출기준』 중 <별표 4>의 고온의 노출기준
temp = []
for i in origin['지면온도']:
    if i <25.0: temp.append(0)
    elif i <25.9:temp.append(1)
    elif i<27.9:temp.append(2)
    elif i <30:temp.append(3)
    else:temp.append(4)
df['지면온도'] = temp

# %%
df['전체공사비_분류'] = df['전체공사비_분류'].map({'2,000만 ~ 5억원 미만':2, '2,000만 미만':1, '50억원 이상':4, '5억 ~ 50억원 미만':3, '분류불능':0})
df['전체공사비_분류'].value_counts()
# Out:
# 4    15759
# 2     3961
# 3     3654
# 1      228
# 0      120
# Name: 전체공사비_분류, dtype: int64

# %%
temp = []
for i in df['작업자수']:
    try:
        a = int(i[:3])
        if a == 100: temp.append(4)
        elif a == 300: temp.append(5)
        elif a == 500: temp.append(6)

    except:
        a = int(i[:2])
        if a ==19:temp.append(0)
        elif a == 20 :temp.append(1)
        elif a==50:temp.append(2)
df['작업자수'] = temp

# %%
temp = []
for i in origin['공정률']:
    try:
        if '미만' in i : temp.append(0)
        elif '이상' in i: temp.append(9)
        else:
            temp.append(int(i[:1]))
    except:
        
        temp.append(0)

df['공정률'] = temp

# %%
df.dtypes

    
fields=[]
for f in df.columns:
    if df[f].dtypes not in [
        "int",
        "int32",
        "int64",
        "float",
        "float32",
        "float64",
    ]:
        fields.append(f)

# %%
cate = df[fields]
df2 = df.drop(fields,axis=1)

# %%
df2 = my_replace_missing_value(df2,'constant',0)
cate = my_replace_missing_value(cate,'constant','0')

# %%
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '습도', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호',
#        '사상자수', '전체공사비_분류', '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1',
#        '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도'],
#       dtype='object')

# %%
fields.remove('공사기간_시작일')
fields.remove('공사기간_종료일')
fields.remove('공종_시작일')
fields.remove('공종_종료일')
fields.remove('구체적 사고원인')
fields.remove('사고발생후 조치사항')
fields.remove('재발방지대책')

# %%
drop_fields = ['시간대','습도','']

# %%
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '습도', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호',
#        '사상자수', '전체공사비_분류', '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1',
#        '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도'],
#       dtype='object')

# %%
cate = cate[fields]

# %%
df2[fields]=cate
df2.dtypes
fields.remove('인적사고')

# %%
df2 = df2.dropna()

# %%
x = my_dummies(df2,*fields)
y = my_labelling(df2[['인적사고']],'인적사고')

# %%
x.shape
# Out:
# (23526, 1746)

# %%
x['인적사고'] = y

# %%
x_train,x_test,y_train,y_test = my_train_test_split(x,'인적사고')
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((18820, 1745), (4706, 1745), (18820,), (4706,))

# %%
params = {
    "n_estimators": [10, 20, 50, 100],
    "criterion": ["squared_error", "absolute_error", "friedman_mse", "poisson"],
    "max_features": ["sqrt", "log2"],
    "max_depth": [10, 20, 50, None],
}

# %% [markdown]
# xgb - y 갯수 줄이기 전
#
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
# [분류분석 성능평가]
#
#
# | | 훈련데이터 |   검증데이터 | 설명                                                      |
# |--|--|--|--|
# | 정확도(Accuracy)  |     0.541919 |     0.488936 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.655207 |     0.420337 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.541919 |     0.335646 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.409932 |     0.357504 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.917224 |     0.868432 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.913331 |     0.860516 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |

# %% [markdown]
# [Best Params]
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
#
#
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |--|--|--|--|
# | 정확도(Accuracy)  |     0.545696 |     0.509137 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.675546 |     0.469469 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.545696 |     0.361035 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.416669 |     0.381702 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.894882 |     0.868483 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.895783 |     0.861934 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |

# %%
my_xgb_classification(x_train,y_train,x_test,y_test, pr=False,roc=False,hist=False,learning_curve=False)
# Out:
# [교차검증 TOP5]
# +----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+--------------------+-------------------+
# |    |   subsample |   reg_lambda |   reg_alpha |   n_estimators |   min_child_weight |   max_depth |   learning_rate |   gamma |   colsample_bytree |   mean_test_score |
# |----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+--------------------+-------------------|
# |  0 |           1 |            7 |           1 |            200 |                  1 |           6 |             0.1 |       2 |                0.7 |               0.5 |
# |  1 |         0.5 |            5 |           1 |            200 |                  7 |           2 |             0.3 |       4 |                0.8 |          0.497875 |
# |  2 |         0.5 |            9 |           1 |            100 |                  3 |           4 |             0.1 |       2 |                0.7 |           0.49458 |
# |  3 |           1 |            9 |           3 |            500 |                  3 |           2 |             0.3 |       3 |                0.6 |          0.494421 |
# |  4 |           1 |            5 |           1 |            300 |                  9 |           6 |             0.5 |       3 |                0.7 |          0.492349 |
# +----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+--------------------+-------------------+
#
# [Best Params]
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.545696 |     0.509137 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.675546 |     0.469469 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.545696 |     0.361035 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.416669 |     0.381702 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.894882 |     0.868483 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.895783 |     0.861934 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [변수 중요도]
# +------------------------------------------------+---------+-------------+-----------+
# |                                                |   score |        rate |    cumsum |
# |------------------------------------------------+---------+-------------+-----------|
# | 사고인지 시간                                  |     379 |    0.033791 |  0.033791 |
# | 보호(방호)조치여부 - 개인방호                  |     357 |   0.0318295 | 0.0656205 |
# | 보호(방호)조치여부 - 안전방호                  |     344 |   0.0306705 |  0.096291 |
# | 사고신고사유_사망_사망 내용 없음               |     272 |   0.0242511 |  0.120542 |
# | 기온.1                                         |     243 |   0.0216655 |  0.142208 |
# | 작업자수                                       |     233 |   0.0207739 |  0.162981 |
# | 해면기압                                       |     223 |   0.0198823 |  0.182864 |
# | 사상자수                                       |     216 |   0.0192582 |  0.202122 |
# | 습도                                           |     213 |   0.0189907 |  0.221113 |
# | 습도.1                                         |     208 |   0.0185449 |  0.239658 |
# | 사고객체_대분류_기타                           |     206 |   0.0183666 |  0.258024 |
# | 시정                                           |     196 |    0.017475 |  0.275499 |
# | 현지기압                                       |     196 |    0.017475 |  0.292974 |
# | 증기압                                         |     188 |   0.0167618 |  0.309736 |
# | 풍속                                           |     183 |    0.016316 |  0.326052 |
# | 사고객체_중분류_공구류                         |     163 |   0.0145328 |  0.340585 |
# | 작업프로세스_절단작업                          |     155 |   0.0138195 |  0.354404 |
# | 사고원인_주원인_작업자 부주의                  |     154 |   0.0137304 |  0.368135 |
# | 시간대                                         |     147 |   0.0131063 |  0.381241 |
# | 공정률                                         |     142 |   0.0126605 |  0.393902 |
# | 사고객체_대분류_건설기계                       |     141 |   0.0125713 |  0.406473 |
# | 풍향                                           |     137 |   0.0122147 |  0.418688 |
# | 사고객체_대분류_건설자재                       |     135 |   0.0120364 |  0.430724 |
# | 작업프로세스_이동                              |     123 |   0.0109665 |   0.44169 |
# | 작업프로세스_운반작업                          |     120 |    0.010699 |  0.452389 |
# | 사고객체_중분류_작업발판                       |     113 |   0.0100749 |  0.462464 |
# | 공종_중분류_철근콘크리트공사                   |     111 |  0.00989658 |  0.472361 |
# | 이슬점온도                                     |      99 |  0.00882668 |  0.481188 |
# | 공종_대분류_토목                               |      91 |  0.00811341 |  0.489301 |
# | 사고객체_중분류_기타                           |      89 |  0.00793509 |  0.497236 |
# | 부위_중분류_상부(위)                           |      89 |  0.00793509 |  0.505171 |
# | 사고원인_주원인_기타                           |      88 |  0.00784593 |  0.513017 |
# | 사고객체_대분류_질병                           |      87 |  0.00775678 |  0.520774 |
# | 사고객체_중분류_사다리                         |      81 |  0.00722183 |  0.527996 |
# | 사고객체_대분류_토사 및 암반                   |      80 |  0.00713267 |  0.535128 |
# | 중하층운량                                     |      77 |  0.00686519 |  0.541994 |
# | 안전관리계획_대상현장(1/2종)                   |      77 |  0.00686519 |  0.548859 |
# | 전체공사비_1,000억원 이상                      |      77 |  0.00686519 |  0.555724 |
# | 사고원인_주원인_개인 안전보호구 착용 불량      |      75 |  0.00668688 |  0.562411 |
# | 부위_중분류_옆                                 |      73 |  0.00650856 |  0.568919 |
# | 사고원인_주원인_운전자 자격관리 미흡           |      69 |  0.00615193 |  0.575071 |
# | 사고객체_중분류_철근                           |      67 |  0.00597361 |  0.581045 |
# | 부위_중분류_하부(아래)                         |      67 |  0.00597361 |  0.587019 |
# | 전운량                                         |      66 |  0.00588445 |  0.592903 |
# | 사고신고사유_부상_부상 내용 없음               |      66 |  0.00588445 |  0.598787 |
# | 사고객체_대분류_건설공구                       |      66 |  0.00588445 |  0.604672 |
# | 장소_중분류_외부                               |      65 |  0.00579529 |  0.610467 |
# | 부위_중분류_바닥                               |      65 |  0.00579529 |  0.616262 |
# | 부위_중분류_앞                                 |      65 |  0.00579529 |  0.622058 |
# | 작업프로세스_기타                              |      65 |  0.00579529 |  0.627853 |
# | 사고객체_중분류_비계                           |      64 |  0.00570613 |  0.633559 |
# | 부위_중분류_고소                               |      63 |  0.00561698 |  0.639176 |
# | 장소_중분류_내부                               |      62 |  0.00552782 |  0.644704 |
# | 사고객체_중분류_건물                           |      58 |  0.00517118 |  0.649875 |
# | 작업프로세스_해체작업                          |      57 |  0.00508203 |  0.654957 |
# | 사고원인_주원인_작업자의 불안전한 행동         |      56 |  0.00499287 |   0.65995 |
# | 작업프로세스_설치작업                          |      55 |  0.00490371 |  0.664854 |
# | 사고객체_중분류_자재                           |      53 |  0.00472539 |  0.669579 |
# | 사고원인_주원인_위험정보 미제공                |      53 |  0.00472539 |  0.674305 |
# | 장소_대분류_공동주택                           |      52 |  0.00463623 |  0.678941 |
# | 일조                                           |      51 |  0.00454708 |  0.683488 |
# | 작업프로세스_용접작업                          |      50 |  0.00445792 |  0.687946 |
# | 작업프로세스_마감작업                          |      50 |  0.00445792 |  0.692404 |
# | 사고객체_중분류_차량                           |      49 |  0.00436876 |  0.696772 |
# | 사고원인_주원인_작업자 건강상태 확인 미흡      |      48 |   0.0042796 |  0.701052 |
# | 사고원인_주원인_작업자 통제 미흡               |      47 |  0.00419044 |  0.705243 |
# | 안전관리계획_비대상현장                        |      46 |  0.00410128 |  0.709344 |
# | 사고객체_중분류_전주, 전선                     |      45 |  0.00401213 |  0.713356 |
# | 부위_중분류_기타                               |      43 |  0.00383381 |   0.71719 |
# | 공종_중분류_수장공사                           |      42 |  0.00374465 |  0.720934 |
# | 부위_대분류_공구류                             |      41 |  0.00365549 |   0.72459 |
# | 시간_10:00                                     |      40 |  0.00356633 |  0.728156 |
# | 작업프로세스_형틀 및 목공                      |      40 |  0.00356633 |  0.731723 |
# | 사고원인_주원인_작업순서 미준수                |      40 |  0.00356633 |  0.735289 |
# | 공종_중분류_철골공사                           |      39 |  0.00347718 |  0.738766 |
# | 장소_대분류_공장                               |      39 |  0.00347718 |  0.742243 |
# | 사고객체_중분류_굴착기                         |      38 |  0.00338802 |  0.745631 |
# | 작업프로세스_벌목작업                          |      37 |  0.00329886 |   0.74893 |
# | 전체공사비_분류                                |      34 |  0.00303138 |  0.751961 |
# | 공휴일여부_휴일                                |      34 |  0.00303138 |  0.754993 |
# | 사고객체_중분류_비산물                         |      34 |  0.00303138 |  0.758024 |
# | 공종_대분류_기타                               |      34 |  0.00303138 |  0.761056 |
# | 작업프로세스_정리작업                          |      33 |  0.00294223 |  0.763998 |
# | 사고객체_중분류_덤프트럭                       |      33 |  0.00294223 |   0.76694 |
# | 작업프로세스_전기작업                          |      32 |  0.00285307 |  0.769793 |
# | 사고객체_중분류_핀                             |      32 |  0.00285307 |  0.772646 |
# | 사고객체_중분류_굴착사면                       |      31 |  0.00276391 |   0.77541 |
# | 사고객체_중분류_거푸집                         |      31 |  0.00276391 |  0.778174 |
# | 부위_중분류_뒤                                 |      31 |  0.00276391 |  0.780938 |
# | 장소_대분류_기타                               |      31 |  0.00276391 |  0.783702 |
# | 작업프로세스_인양작업                          |      30 |  0.00267475 |  0.786377 |
# | 사고객체_중분류_안전시설물                     |      30 |  0.00267475 |  0.789051 |
# | 부위_대분류_기타                               |      29 |  0.00258559 |  0.791637 |
# | 사고객체_중분류_배관                           |      28 |  0.00249643 |  0.794133 |
# | 해당공종_공사비_100억~150억원미만              |      28 |  0.00249643 |   0.79663 |
# | 장소_대분류_하수도                             |      28 |  0.00249643 |  0.799126 |
# | 부위_대분류_비계                               |      27 |  0.00240728 |  0.801534 |
# | 안전관리계획_대상현장(1/2종외)                 |      26 |  0.00231812 |  0.803852 |
# | 사고객체_중분류_질병                           |      26 |  0.00231812 |   0.80617 |
# | 장소_대분류_창고시설                           |      24 |   0.0021398 |   0.80831 |
# | 부위_대분류_사다리                             |      24 |   0.0021398 |  0.810449 |
# | 공종_중분류_금속공사                           |      24 |   0.0021398 |  0.812589 |
# | 작업프로세스_타설작업                          |      23 |  0.00205064 |   0.81464 |
# | 장소_중분류_인접주변                           |      23 |  0.00205064 |   0.81669 |
# | 사고객체_대분류_부재                           |      23 |  0.00205064 |  0.818741 |
# | 사고객체_중분류_개구부                         |      22 |  0.00196148 |  0.820703 |
# | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 |      22 |  0.00196148 |  0.822664 |
# | 지면온도                                       |      22 |  0.00196148 |  0.824626 |
# | 기온_20℃                                       |      22 |  0.00196148 |  0.826587 |
# | 장소_중분류_지붕                               |      22 |  0.00196148 |  0.828549 |
# | 작업프로세스_도장작업                          |      22 |  0.00196148 |   0.83051 |
# | 사고원인_주원인_시공품질 미확보                |      22 |  0.00196148 |  0.832471 |
# | 시_서울특별시                                  |      21 |  0.00187233 |  0.834344 |
# | 사고객체_대분류_시설물                         |      21 |  0.00187233 |  0.836216 |
# | 작업프로세스_항타 및 항발작업                  |      21 |  0.00187233 |  0.838088 |
# | 날씨_맑음                                      |      21 |  0.00187233 |  0.839961 |
# | 기온_15℃                                       |      20 |  0.00178317 |  0.841744 |
# | 공종_중분류_관공사                             |      20 |  0.00178317 |  0.843527 |
# | 공공/민간 구분_공공                            |      20 |  0.00178317 |   0.84531 |
# | 사고객체_중분류_데크플레이트                   |      20 |  0.00178317 |  0.847093 |
# | 부위_대분류_철근                               |      20 |  0.00178317 |  0.848877 |
# | 해당공종_공사비_50억~100억원미만               |      20 |  0.00178317 |   0.85066 |
# | 전체공사비_100억 ~ 150억원 미만                |      19 |  0.00169401 |  0.852354 |
# | 부위_대분류_작업발판                           |      19 |  0.00169401 |  0.854048 |
# | 부위_대분류_전주, 전선                         |      19 |  0.00169401 |  0.855742 |
# | 작업프로세스_조립작업                          |      19 |  0.00169401 |  0.857436 |
# | 사고신고사유_물적_물적피해 내용 없음           |      19 |  0.00169401 |   0.85913 |
# | 사고객체_중분류_철골부재                       |      19 |  0.00169401 |  0.860824 |
# | 시_전라북도                                    |      18 |  0.00160485 |  0.862429 |
# | 부위_대분류_자재                               |      18 |  0.00160485 |  0.864034 |
# | 사고원인_주원인_계측데이터 관리 미흡           |      18 |  0.00160485 |  0.865638 |
# | 공종_중분류_기계설비공사                       |      17 |  0.00151569 |  0.867154 |
# | 공종_중분류_목공사                             |      17 |  0.00151569 |   0.86867 |
# | 사고객체_중분류_흙막이가시설                   |      17 |  0.00151569 |  0.870185 |
# | 사고객체_중분류_고소작업차(고소작업대 등)      |      17 |  0.00151569 |  0.871701 |
# | 전체공사비_500억 ~ 1,000억원 미만              |      16 |  0.00142653 |  0.873128 |
# | 작업프로세스_연결작업                          |      16 |  0.00142653 |  0.874554 |
# | 요일_목요일                                    |      16 |  0.00142653 |  0.875981 |
# | 시간_15:00                                     |      16 |  0.00142653 |  0.877407 |
# | 공종_중분류_미장공사                           |      16 |  0.00142653 |  0.878834 |
# | 사고객체_중분류_슬래브                         |      16 |  0.00142653 |   0.88026 |
# | 시_충청남도                                    |      15 |  0.00133738 |  0.881598 |
# | 요일_월요일                                    |      15 |  0.00133738 |  0.882935 |
# | 작업프로세스_양중작업                          |      15 |  0.00133738 |  0.884272 |
# | 해당공종_공사비_500억~1,000억원미만            |      15 |  0.00133738 |   0.88561 |
# | 부위_대분류_건물                               |      15 |  0.00133738 |  0.886947 |
# | 요일_화요일                                    |      15 |  0.00133738 |  0.888285 |
# | 시_경기도                                      |      15 |  0.00133738 |  0.889622 |
# | 공종_중분류_창호 및 유리공사                   |      15 |  0.00133738 |  0.890959 |
# | 공종_대분류_기계설비                           |      15 |  0.00133738 |  0.892297 |
# | 사고객체_중분류_콘크리트펌프                   |      14 |  0.00124822 |  0.893545 |
# | 시_충청북도                                    |      14 |  0.00124822 |  0.894793 |
# | 사고객체_중분류_시스템동바리                   |      14 |  0.00124822 |  0.896041 |
# | 공종_중분류_해체 및 철거공사                   |      14 |  0.00124822 |   0.89729 |
# | 요일_일요일                                    |      14 |  0.00124822 |  0.898538 |
# | 해당공종_공사비_4,000만~1억원미만              |      14 |  0.00124822 |  0.899786 |
# | 부위_대분류_핀                                 |      14 |  0.00124822 |  0.901034 |
# | 공종_중분류_기타                               |      14 |  0.00124822 |  0.902282 |
# | 해당공종_공사비_150억~200억원미만              |      13 |  0.00115906 |  0.903442 |
# | 해당공종_공사비_1억~2억원미만                  |      13 |  0.00115906 |  0.904601 |
# | 해당공종_공사비_5억~10억원미만                 |      13 |  0.00115906 |   0.90576 |
# | 시간_11:00                                     |      13 |  0.00115906 |  0.906919 |
# | 설계안전성검토_대상                            |      13 |  0.00115906 |  0.908078 |
# | 부위_대분류_덤프트럭                           |      13 |  0.00115906 |  0.909237 |
# | 공종_중분류_도장공사                           |      13 |  0.00115906 |  0.910396 |
# | 전체공사비_300억 ~ 500억원 미만                |      13 |  0.00115906 |  0.911555 |
# | 부위_대분류_차량                               |      13 |  0.00115906 |  0.912714 |
# | 사고객체_중분류_지게차                         |      13 |  0.00115906 |  0.913873 |
# | 공종_중분류_토공사                             |      12 |   0.0010699 |  0.914943 |
# | 사고객체_중분류_강관동바리                     |      12 |   0.0010699 |  0.916013 |
# | 시_부산광역시                                  |      12 |   0.0010699 |  0.917083 |
# | 작업프로세스_상차 및 하역작업                  |      12 |   0.0010699 |  0.918153 |
# | 장소_대분류_문화및집회시설                     |      12 |   0.0010699 |  0.919223 |
# | 사고원인_주원인_적정 공법검토 미흡             |      12 |   0.0010699 |  0.920292 |
# | 해당공종_공사비_분류불능                       |      12 |   0.0010699 |  0.921362 |
# | 장소_대분류_업무시설                           |      12 |   0.0010699 |  0.922432 |
# | 사고객체_중분류_지반                           |      12 |   0.0010699 |  0.923502 |
# | 해당공종_공사비_20억~50억원미만                |      11 | 0.000980742 |  0.924483 |
# | 공종_중분류_건축 토공사                        |      11 | 0.000980742 |  0.925464 |
# | 부위_대분류_시스템동바리                       |      11 | 0.000980742 |  0.926444 |
# | 공공/민간 구분_민간                            |      11 | 0.000980742 |  0.927425 |
# | 장소_대분류_도로                               |      11 | 0.000980742 |  0.928406 |
# | 사고객체_중분류_타워크레인                     |      10 | 0.000891583 |  0.929297 |
# | 요일_수요일                                    |      10 | 0.000891583 |  0.930189 |
# | 시간_15:30                                     |      10 | 0.000891583 |  0.931081 |
# | 공종_중분류_말뚝공사                           |      10 | 0.000891583 |  0.931972 |
# | 공종_중분류_산업설비공사                       |      10 | 0.000891583 |  0.932864 |
# | 날씨_흐림                                      |      10 | 0.000891583 |  0.933755 |
# | 부위_대분류_배관                               |      10 | 0.000891583 |  0.934647 |
# | 기온_33℃                                       |       9 | 0.000802425 |  0.935449 |
# | 기온_30℃                                       |       9 | 0.000802425 |  0.936252 |
# | 사고객체_중분류_항타 및 항발기                 |       9 | 0.000802425 |  0.937054 |
# | 사고객체_중분류_기타 가시설                    |       9 | 0.000802425 |  0.937857 |
# | 시간_8:00                                      |       9 | 0.000802425 |  0.938659 |
# | 기온_19℃                                       |       9 | 0.000802425 |  0.939461 |
# | 시간_16:00                                     |       9 | 0.000802425 |  0.940264 |
# | 요일_토요일                                    |       9 | 0.000802425 |  0.941066 |
# | 부위_대분류_개구부                             |       9 | 0.000802425 |  0.941869 |
# | 해당공종_공사비_10억~20억원미만                |       9 | 0.000802425 |  0.942671 |
# | 전체공사비_50억 ~ 100억원 미만                 |       9 | 0.000802425 |  0.943474 |
# | 부위_대분류_비산물                             |       9 | 0.000802425 |  0.944276 |
# | 부위_중분류_지하                               |       8 | 0.000713267 |  0.944989 |
# | 장소_중분류_외벽                               |       8 | 0.000713267 |  0.945703 |
# | 해당공종_공사비_3억~5억원미만                  |       8 | 0.000713267 |  0.946416 |
# | 부위_대분류_안전시설물                         |       8 | 0.000713267 |  0.947129 |
# | 부위_대분류_굴착기                             |       8 | 0.000713267 |  0.947842 |
# | 전체공사비_20억 ~ 50억원 미만                  |       8 | 0.000713267 |  0.948556 |
# | 해당공종_공사비_1,000만~2,000만원미만          |       8 | 0.000713267 |  0.949269 |
# | 장소_대분류_근린생활시설                       |       8 | 0.000713267 |  0.949982 |
# | 설계안전성검토_비대상                          |       8 | 0.000713267 |  0.950695 |
# | 시간_14:00                                     |       8 | 0.000713267 |  0.951409 |
# | 기온_25℃                                       |       8 | 0.000713267 |  0.952122 |
# | 사고객체_중분류_작업대차                       |       8 | 0.000713267 |  0.952835 |
# | 사고객체_중분류_천정패널                       |       8 | 0.000713267 |  0.953549 |
# | 기온_8℃                                        |       7 | 0.000624108 |  0.954173 |
# | 사고객체_중분류_파이프서포트                   |       7 | 0.000624108 |  0.954797 |
# | 부위_대분류_데크플레이트                       |       7 | 0.000624108 |  0.955421 |
# | 부위_대분류_경사면                             |       7 | 0.000624108 |  0.956045 |
# | 사고객체_중분류_절토사면                       |       7 | 0.000624108 |  0.956669 |
# | 작업프로세스_보수 및 교체작업                  |       7 | 0.000624108 |  0.957293 |
# | 전체공사비_5억 ~ 10억원 미만                   |       7 | 0.000624108 |  0.957917 |
# | 해당공종_공사비_2,000만~4,000만원미만          |       7 | 0.000624108 |  0.958541 |
# | 전체공사비_4,000만 ~ 1억원 미만                |       7 | 0.000624108 |  0.959165 |
# | 시간_10:30                                     |       7 | 0.000624108 |   0.95979 |
# | 부위_대분류_질병                               |       7 | 0.000624108 |  0.960414 |
# | 시간_14:30                                     |       7 | 0.000624108 |  0.961038 |
# | 전체공사비_150억 ~ 200억원 미만                |       7 | 0.000624108 |  0.961662 |
# | 전체공사비_10억 ~ 20억원 미만                  |       7 | 0.000624108 |  0.962286 |
# | 기온_24℃                                       |       7 | 0.000624108 |   0.96291 |
# | 사고원인_주원인_사다리 사용수칙 미준수         |       7 | 0.000624108 |  0.963534 |
# | 장소_대분류_석유화학공장                       |       7 | 0.000624108 |  0.964158 |
# | 공종_중분류_조적공사                           |       7 | 0.000624108 |  0.964782 |
# | 공종_중분류_도로 및 포장공사                   |       7 | 0.000624108 |  0.965407 |
# | 사고객체_중분류_건설폐기물                     |       6 |  0.00053495 |  0.965942 |
# | 시간_16:30                                     |       6 |  0.00053495 |  0.966476 |
# | 부위_대분류_흙막이가시설                       |       6 |  0.00053495 |  0.967011 |
# | 부위_대분류_지게차                             |       6 |  0.00053495 |  0.967546 |
# | 기온_5℃                                        |       6 |  0.00053495 |  0.968081 |
# | 시_경상북도                                    |       6 |  0.00053495 |  0.968616 |
# | 사고객체_중분류_지지대                         |       6 |  0.00053495 |  0.969151 |
# | 사고객체_중분류_경사면                         |       6 |  0.00053495 |  0.969686 |
# | 장소_대분류_교육연구시설                       |       6 |  0.00053495 |  0.970221 |
# | 해당공종_공사비_2억~3억원미만                  |       6 |  0.00053495 |  0.970756 |
# | 시간_9:30                                      |       6 |  0.00053495 |  0.971291 |
# | 작업프로세스_준비작업                          |       6 |  0.00053495 |  0.971826 |
# | 시간_8:30                                      |       5 | 0.000445792 |  0.972272 |
# | 부위_대분류_굴착사면                           |       5 | 0.000445792 |  0.972718 |
# | 부위_대분류_파이프서포트                       |       5 | 0.000445792 |  0.973163 |
# | 전체공사비_200억 ~ 300억원 미만                |       5 | 0.000445792 |  0.973609 |
# | 사고객체_중분류_기중기(이동식크레인 등)        |       5 | 0.000445792 |  0.974055 |
# | 부위_대분류_철골부재                           |       5 | 0.000445792 |  0.974501 |
# | 전체공사비_2억 ~ 3억원 미만                    |       5 | 0.000445792 |  0.974947 |
# | 기온_21℃                                       |       5 | 0.000445792 |  0.975392 |
# | 시간_10:05                                     |       5 | 0.000445792 |  0.975838 |
# | 기온_17℃                                       |       5 | 0.000445792 |  0.976284 |
# | 부위_대분류_고소작업차(고소작업대 등)          |       5 | 0.000445792 |   0.97673 |
# | 시_전라남도                                    |       5 | 0.000445792 |  0.977175 |
# | 시_세종특별자치시                              |       5 | 0.000445792 |  0.977621 |
# | 시_대구광역시                                  |       5 | 0.000445792 |  0.978067 |
# | 시_울산광역시                                  |       5 | 0.000445792 |  0.978513 |
# | 부위_대분류_슬래브                             |       5 | 0.000445792 |  0.978959 |
# | 부위_대분류_항타 및 항발기                     |       5 | 0.000445792 |  0.979404 |
# | 사고원인_주원인_기계장비 불안전한 거치         |       4 | 0.000356633 |  0.979761 |
# | 강수량                                         |       4 | 0.000356633 |  0.980118 |
# | 장소_대분류_숙박시설                           |       4 | 0.000356633 |  0.980474 |
# | 사고원인_주원인_안전발판 설치 미흡             |       4 | 0.000356633 |  0.980831 |
# | 공종_중분류_터널공사                           |       4 | 0.000356633 |  0.981188 |
# | 기온_3℃                                        |       4 | 0.000356633 |  0.981544 |
# | 공종_중분류_관공사 부대공사                    |       4 | 0.000356633 |  0.981901 |
# | 시_경상남도                                    |       4 | 0.000356633 |  0.982257 |
# | 시간_18:00                                     |       4 | 0.000356633 |  0.982614 |
# | 장소_대분류_단독주택                           |       4 | 0.000356633 |  0.982971 |
# | 기온_10℃                                       |       4 | 0.000356633 |  0.983327 |
# | 사고원인_주원인_시공관리 미흡                  |       4 | 0.000356633 |  0.983684 |
# | 사고원인_주원인_안전관리계획 수립 미흡         |       4 | 0.000356633 |  0.984041 |
# | 기온_28℃                                       |       4 | 0.000356633 |  0.984397 |
# | 부위_대분류_거푸집                             |       4 | 0.000356633 |  0.984754 |
# | 사고객체_중분류_지하매설물                     |       4 | 0.000356633 |  0.985111 |
# | 해당공종_공사비_1,000억원이상                  |       4 | 0.000356633 |  0.985467 |
# | 사고객체_중분류_창호                           |       4 | 0.000356633 |  0.985824 |
# | 기온_16℃                                       |       4 | 0.000356633 |   0.98618 |
# | 시_광주광역시                                  |       3 | 0.000267475 |  0.986448 |
# | 기온_13℃                                       |       3 | 0.000267475 |  0.986715 |
# | 사고객체_중분류_천공기                         |       3 | 0.000267475 |  0.986983 |
# | 기온_29℃                                       |       3 | 0.000267475 |   0.98725 |
# | 장소_대분류_하수처리시설                       |       3 | 0.000267475 |  0.987518 |
# | 작업프로세스_굴착작업                          |       3 | 0.000267475 |  0.987785 |
# | 작업프로세스_청소작업                          |       3 | 0.000267475 |  0.988053 |
# | 사고원인_주원인_작업전 점검 미흡               |       3 | 0.000267475 |   0.98832 |
# | 기온_12℃                                       |       3 | 0.000267475 |  0.988588 |
# | 부위_대분류_기타 가시설                        |       3 | 0.000267475 |  0.988855 |
# | 장소_대분류_부지조성                           |       3 | 0.000267475 |  0.989123 |
# | 공종_중분류_방수공사                           |       3 | 0.000267475 |   0.98939 |
# | 작업프로세스_적재작업                          |       3 | 0.000267475 |  0.989658 |
# | 해당공종_공사비_200억~300억원미만              |       3 | 0.000267475 |  0.989925 |
# | 시간_13:30                                     |       3 | 0.000267475 |  0.990193 |
# | 작업프로세스_부설 및 다짐작업                  |       3 | 0.000267475 |   0.99046 |
# | 부위_대분류_지반                               |       3 | 0.000267475 |  0.990728 |
# | 기온_18℃                                       |       3 | 0.000267475 |  0.990995 |
# | 날씨_강우                                      |       3 | 0.000267475 |  0.991262 |
# | 부위_대분류_타워크레인                         |       3 | 0.000267475 |   0.99153 |
# | 장소_대분류_의료시설                           |       3 | 0.000267475 |  0.991797 |
# | 기온_27℃                                       |       3 | 0.000267475 |  0.992065 |
# | 시_제주특별자치도                              |       3 | 0.000267475 |  0.992332 |
# | 시간_15:50                                     |       3 | 0.000267475 |    0.9926 |
# | 기온_23℃                                       |       2 | 0.000178317 |  0.992778 |
# | 시간_9:10                                      |       2 | 0.000178317 |  0.992956 |
# | 해당공종_공사비_1,000만원미만                  |       2 | 0.000178317 |  0.993135 |
# | 전체공사비_1억 ~ 2억원 미만                    |       2 | 0.000178317 |  0.993313 |
# | 기온_22℃                                       |       2 | 0.000178317 |  0.993491 |
# | 시_인천광역시                                  |       2 | 0.000178317 |   0.99367 |
# | 시간_7:00                                      |       2 | 0.000178317 |  0.993848 |
# | 시간_7:40                                      |       2 | 0.000178317 |  0.994026 |
# | 기온_26℃                                       |       2 | 0.000178317 |  0.994205 |
# | 기온_14℃                                       |       2 | 0.000178317 |  0.994383 |
# | 공종_중분류_하천공사                           |       2 | 0.000178317 |  0.994561 |
# | 시간_11:30                                     |       2 | 0.000178317 |   0.99474 |
# | 시간_15:10                                     |       2 | 0.000178317 |  0.994918 |
# | 장소_대분류_판매시설                           |       2 | 0.000178317 |  0.995096 |
# | 시간_10:50                                     |       2 | 0.000178317 |  0.995275 |
# | 부위_대분류_지하매설물                         |       2 | 0.000178317 |  0.995453 |
# | 시간_13:00                                     |       2 | 0.000178317 |  0.995631 |
# | 부위_대분류_천공기                             |       2 | 0.000178317 |   0.99581 |
# | 작업프로세스_설비작업                          |       2 | 0.000178317 |  0.995988 |
# | 장소_대분류_상수도                             |       2 | 0.000178317 |  0.996166 |
# | 부위_대분류_콘크리트펌프                       |       2 | 0.000178317 |  0.996345 |
# | 부위_대분류_천정패널                           |       2 | 0.000178317 |  0.996523 |
# | 시간_10:35                                     |       2 | 0.000178317 |  0.996701 |
# | 공종_중분류_타일 및 돌공사                     |       2 | 0.000178317 |  0.996879 |
# | 공종_중분류_철도 및 궤도공사                   |       2 | 0.000178317 |  0.997058 |
# | 공종_중분류_지붕 및 홈통공사                   |       2 | 0.000178317 |  0.997236 |
# | 사고원인_주원인_시방기준 등 미준수             |       2 | 0.000178317 |  0.997414 |
# | 기온_6℃                                        |       2 | 0.000178317 |  0.997593 |
# | 공종_중분류_항만공사                           |       2 | 0.000178317 |  0.997771 |
# | 기온_-2℃                                       |       1 | 8.91583e-05 |   0.99786 |
# | 장소_대분류_도로교량                           |       1 | 8.91583e-05 |  0.997949 |
# | 시간_10:25                                     |       1 | 8.91583e-05 |  0.998039 |
# | 기온_0℃                                        |       1 | 8.91583e-05 |  0.998128 |
# | 시간_7:50                                      |       1 | 8.91583e-05 |  0.998217 |
# | 장소_대분류_지하철                             |       1 | 8.91583e-05 |  0.998306 |
# | 장소_대분류_절토사면                           |       1 | 8.91583e-05 |  0.998395 |
# | 작업프로세스_천공작업                          |       1 | 8.91583e-05 |  0.998484 |
# | 시간_9:00                                      |       1 | 8.91583e-05 |  0.998573 |
# | 장소_대분류_자동차관련시설                     |       1 | 8.91583e-05 |  0.998663 |
# | 시_대전광역시                                  |       1 | 8.91583e-05 |  0.998752 |
# | 기온_11℃                                       |       1 | 8.91583e-05 |  0.998841 |
# | 작업프로세스_매설작업                          |       1 | 8.91583e-05 |   0.99893 |
# | 부위_대분류_기중기(이동식크레인 등)            |       1 | 8.91583e-05 |  0.999019 |
# | 시간_11:14                                     |       1 | 8.91583e-05 |  0.999108 |
# | 부위_대분류_작업대차                           |       1 | 8.91583e-05 |  0.999198 |
# | 기온_31℃                                       |       1 | 8.91583e-05 |  0.999287 |
# | 사고객체_중분류_벽체                           |       1 | 8.91583e-05 |  0.999376 |
# | 부위_대분류_절토사면                           |       1 | 8.91583e-05 |  0.999465 |
# | 부위_대분류_창호                               |       1 | 8.91583e-05 |  0.999554 |
# | 부위_대분류_콘크리트믹서트럭                   |       1 | 8.91583e-05 |  0.999643 |
# | 오전오후_오후                                  |       1 | 8.91583e-05 |  0.999733 |
# | 공종_중분류_전기설비공사                       |       1 | 8.91583e-05 |  0.999822 |
# | 기온_4℃                                        |       1 | 8.91583e-05 |  0.999911 |
# | 시간_16:40                                     |       1 | 8.91583e-05 |         1 |
# +------------------------------------------------+---------+-------------+-----------+
#
# [Roc Curve]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[28], line 1
#
# ----> 1 my_xgb_classification(x_train,y_train,x_test,y_test, pr=False,roc=False,hist=False,learning_curve=False)
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:1880, in my_xgb_classification(x_train, y_train, x_test, y_test, conf_matrix, cv, hist, roc, pr, multiclass, learning_curve, report, figsize, dpi, sort, is_print, **params)
#
#    1858 @register_method
#
#    1859 def my_xgb_classification(
#
#    1860     x_train: DataFrame,
#
#    (...)
#
#    1876     **params,
#
#    1877 ) -> XGBClassifier:
#
#    1878     params = get_hyper_params(classname=XGBClassifier)
#
# -> 1880     return __my_classification(
#
#    1881         classname=XGBClassifier,
#
#    1882         x_train=x_train,
#
#    1883         y_train=y_train,
#
#    1884         x_test=x_test,
#
#    1885         y_test=y_test,
#
#    1886         conf_matrix=conf_matrix,
#
#    1887         cv=cv,
#
#    1888         hist=hist,
#
#    1889         roc=roc,
#
#    1890         pr=pr,
#
#    1891         multiclass=multiclass,
#
#    1892         learning_curve=learning_curve,
#
#    1893         report=report,
#
#    1894         figsize=figsize,
#
#    1895         dpi=dpi,
#
#    1896         sort=sort,
#
#    1897         is_print=is_print,
#
#    1898         **params,
#
#    1899     )
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:145, in __my_classification(classname, x_train, y_train, x_test, y_test, conf_matrix, cv, hist, roc, pr, multiclass, learning_curve, report, figsize, dpi, sort, is_print, pruning, **params)
#
#     142 # ------------------------------------------------------
#
#     143 # 보고서 출력
#
#     144 if report and is_print:
#
# --> 145     my_classification_report(estimator, x_train, y_train, x_test, y_test, sort)
#
#     147 return estimator
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:509, in my_classification_report(estimator, x_train, y_train, x_test, y_test, sort)
#
#     507 else:
#
#     508     if x_test is not None and y_test is not None:
#
# --> 509         my_classification_multiclass_report(
#
#     510             estimator, x=x_test, y=y_test, sort=sort
#
#     511         )
#
#     512     else:
#
#     513         my_classification_multiclass_report(
#
#     514             estimator, x=x_train, y=y_train, sort=sort
#
#     515         )
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:721, in my_classification_multiclass_report(estimator, x, y, sort)
#
#     718 for i in range(0, class_size):
#
#     719     # VIF
#
#     720     if len(x.columns) > 1:
#
# --> 721         vif = [
#
#     722             variance_inflation_factor(x, list(x.columns).index(v))
#
#     723             for i, v in enumerate(x.columns)
#
#     724         ]
#
#     725     else:
#
#     726         vif = 0
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:722, in <listcomp>(.0)
#
#     718 for i in range(0, class_size):
#
#     719     # VIF
#
#     720     if len(x.columns) > 1:
#
#     721         vif = [
#
# --> 722             variance_inflation_factor(x, list(x.columns).index(v))
#
#     723             for i, v in enumerate(x.columns)
#
#     724         ]
#
#     725     else:
#
#     726         vif = 0
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\outliers_influence.py:197, in variance_inflation_factor(exog, exog_idx)
#
#     195 mask = np.arange(k_vars) != exog_idx
#
#     196 x_noti = exog[:, mask]
#
# --> 197 r_squared_i = OLS(x_i, x_noti).fit().rsquared
#
#     198 vif = 1. / (1. - r_squared_i)
#
#     199 return vif
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:923, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#
#     920     msg = ("Weights are not supported in OLS and will be ignored"
#
#     921            "An exception will be raised in the next version.")
#
#     922     warnings.warn(msg, ValueWarning)
#
# --> 923 super(OLS, self).__init__(endog, exog, missing=missing,
#
#     924                           hasconst=hasconst, **kwargs)
#
#     925 if "weights" in self._init_keys:
#
#     926     self._init_keys.remove("weights")
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:748, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#
#     746 else:
#
#     747     weights = weights.squeeze()
#
# --> 748 super(WLS, self).__init__(endog, exog, missing=missing,
#
#     749                           weights=weights, hasconst=hasconst, **kwargs)
#
#     750 nobs = self.exog.shape[0]
#
#     751 weights = self.weights
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:202, in RegressionModel.__init__(self, endog, exog, **kwargs)
#
#     201 def __init__(self, endog, exog, **kwargs):
#
# --> 202     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#
#     203     self.pinv_wexog: Float64Array | None = None
#
#     204     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#
#     269 def __init__(self, endog, exog=None, **kwargs):
#
# --> 270     super().__init__(endog, exog, **kwargs)
#
#     271     self.initialize()
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#
#      93 missing = kwargs.pop('missing', 'none')
#
#      94 hasconst = kwargs.pop('hasconst', None)
#
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#
#      96                               **kwargs)
#
#      97 self.k_constant = self.data.k_constant
#
#      98 self.exog = self.data.exog
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
#
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#
#     136     # kwargs arrays could have changed, easier to just attach here
#
#     137     for key in kwargs:
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#
#     672     exog = np.asarray(exog)
#
#     674 klass = handle_data_class_factory(endog, exog)
#
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#
#     676              **kwargs)
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\data.py:88, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#
#      86 self.const_idx = None
#
#      87 self.k_constant = 0
#
# ---> 88 self._handle_constant(hasconst)
#
#      89 self._check_integrity()
#
#      90 self._cache = {}
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\data.py:178, in ModelData._handle_constant(self, hasconst)
#
#     175 augmented_exog = np.column_stack(
#
#     176             (np.ones(self.exog.shape[0]), self.exog))
#
#     177 rank_augm = np.linalg.matrix_rank(augmented_exog)
#
# --> 178 rank_orig = np.linalg.matrix_rank(self.exog)
#
#     179 self.k_constant = int(rank_orig == rank_augm)
#
#     180 self.const_idx = None
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1922, in matrix_rank(A, tol, hermitian)
#
#    1920 if A.ndim < 2:
#
#    1921     return int(not all(A==0))
#
# -> 1922 S = svd(A, compute_uv=False, hermitian=hermitian)
#
#    1923 if tol is None:
#
#    1924     tol = S.max(axis=-1, keepdims=True) * max(A.shape[-2:]) * finfo(S.dtype).eps
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1693, in svd(a, full_matrices, compute_uv, hermitian)
#
#    1690     gufunc = _umath_linalg.svd_n
#
#    1692 signature = 'D->d' if isComplexType(t) else 'd->d'
#
# -> 1693 s = gufunc(a, signature=signature, extobj=extobj)
#
#    1694 s = s.astype(_realType(result_t), copy=False)
#
#    1695 return s
#
#
#
# KeyboardInterrupt:
