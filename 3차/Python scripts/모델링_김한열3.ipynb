# %%
# pip install --upgrade git+https://github.com/hyk2202/helper.git

import pandas as pd
from helper.util import *
from helper.analysis import *
from helper.tensor import *
from helper.plot import *
from helper.timeserise import *
from helper.core import *
from helper.classification import *
from helper.re import *
from helper.regression import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hyk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
origin = my_read_data('데이터_전처리_최종.xlsx',info=False, index_col='IDX')

# %%
df = origin.copy()
df.columns
# Out:
# Index(['발생날짜', '요일', '공휴일여부', '오전오후', '시간대', '시간', '사고인지 시간', '공공/민간 구분', '날씨',
#        '기온', '습도', '인적사고', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호', '공종_대분류',
#        '공종_중분류', '사고객체_대분류', '사고객체_중분류', '작업프로세스', '장소_대분류', '장소_중분류',
#        '부위_대분류', '부위_중분류', '사고원인_주원인', '사상자수', '사고신고사유_부상', '사고신고사유_사망',
#        '사고신고사유_물적', '시', '전체공사비', '전체공사비_분류', '해당공종_공사비', '구체적 사고원인',
#        '사고발생후 조치사항', '공사기간_시작일', '공사기간_종료일', '공종_시작일', '공종_종료일', '재발방지대책',
#        '공정률', '안전관리계획', '설계안전성검토', '작업자수', '지점 번호', '관측소', '기온.1', '강수량', '풍속',
#        '풍향', '습도.1', '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량',
#        '시정', '지면온도'],
#       dtype='object')

# %%
df.drop(['발생날짜','지점 번호','관측소'],axis=1,inplace=True)

# %%
temp = []
for i in df['인적사고']:
    if i == '기타':temp.append('분류불능')
    elif i == '없음':temp.append(None)
    else:temp.append(i)

df['인적사고'] = temp
df['인적사고'].value_counts()
# Out:
# 넘어짐       5814
# 떨어짐       4321
# 물체에 맞음    3509
# 끼임        2576
# 분류불능      2152
# 부딪힘       1850
# 절단, 베임    1688
# 깔림         521
# 질병         381
# 찔림         307
# 화상         186
# 교통사고       123
# 감전          48
# 질식          18
# Name: 인적사고, dtype: int64

# %%
temp =[]
for i in df['강수량']:
    if i>=0.1 : temp.append(1)
    else:temp.append(0)

# %%
# 결측치 : 0 정규작업 :1 그외: 2

temp = []
for i in df['사고인지 시간'].fillna(0):
    if i == 0 : temp.append(0)
    elif i == '정규작업 ': temp.append(1)
    else:temp.append(2)

df['사고인지 시간'] = temp
df['사고인지 시간'].value_counts()
# Out:
# 1    18032
# 0     3167
# 2     2523
# Name: 사고인지 시간, dtype: int64

# %%
# 결측치 : 0, 조치/해당없음:1, 비조치:2

temp = []
for i in df["보호(방호)조치여부 - 안전방호"].fillna(0):
    if i == 0 :temp.append(0)
    elif i == '비조치': temp.append(2)
    else:temp.append(1)
df["보호(방호)조치여부 - 안전방호"] =temp


df["보호(방호)조치여부 - 안전방호"].value_counts()
# Out:
# 1    17153
# 0     5411
# 2     1158
# Name: 보호(방호)조치여부 - 안전방호, dtype: int64

# %%
# 결측치 : 0, 조치/해당없음:1, 비조치:2

temp = []
for i in df["보호(방호)조치여부 - 개인방호"].fillna(0):
    if i == 0 :temp.append(0)
    elif i == '비조치': temp.append(2)
    else:temp.append(1)
df["보호(방호)조치여부 - 개인방호"] =temp


df["보호(방호)조치여부 - 개인방호"].value_counts()
# Out:
# 1    17455
# 0     5410
# 2      857
# Name: 보호(방호)조치여부 - 개인방호, dtype: int64

# %%
# 통신설비, 산업설비, 전기설비 => 기타
temp = []
for i in df['공종_대분류']:
    if i in ['통신설비','산업설비','전기설비']:temp.append('기타')
    else:temp.append(i)
df['공종_대분류'] =temp

# %%
# 비조치 :2 , 조치,해당없음 : 1 ,결측치 : 0
temp = []
for i in origin["작업프로세스"]:
    if i == '비조치': temp.append(2)
    elif i ==0:temp.append(1)
    else:temp.append(0)

# %%
#노동부고시 제2002-8호, 『화학물질 및 물리적인자의 노출기준』 중 <별표 4>의 고온의 노출기준
temp = []
for i in origin['지면온도']:
    if i <25.0: temp.append(0)
    elif i <25.9:temp.append(1)
    elif i<27.9:temp.append(2)
    elif i <30:temp.append(3)
    else:temp.append(4)
df['지면온도'] = temp

# %%
df['전체공사비_분류'] = df['전체공사비_분류'].map({'2,000만 ~ 5억원 미만':2, '2,000만 미만':1, '50억원 이상':4, '5억 ~ 50억원 미만':3, '분류불능':0})
df['전체공사비_분류'].value_counts()
# Out:
# 4    15759
# 2     3961
# 3     3654
# 1      228
# 0      120
# Name: 전체공사비_분류, dtype: int64

# %%
temp = []
for i in df['작업자수']:
    try:
        a = int(i[:3])
        if a == 100: temp.append(4)
        elif a == 300: temp.append(5)
        elif a == 500: temp.append(6)

    except:
        a = int(i[:2])
        if a ==19:temp.append(0)
        elif a == 20 :temp.append(1)
        elif a==50:temp.append(2)
df['작업자수'] = temp

# %%
temp = []
for i in origin['공정률']:
    try:
        if '미만' in i : temp.append(0)
        elif '이상' in i: temp.append(9)
        else:
            temp.append(int(i[:1]))
    except:
        
        temp.append(0)

df['공정률'] = temp

# %%
df.dtypes

    
fields=[]
for f in df.columns:
    if df[f].dtypes not in [
        "int",
        "int32",
        "int64",
        "float",
        "float32",
        "float64",
    ]:
        fields.append(f)

# %%
cate = df[fields]
df2 = df.drop(fields,axis=1)

# %%
df2 = my_replace_missing_value(df2,'constant',0)
cate = my_replace_missing_value(cate,'constant','0')

# %%
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '습도', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호',
#        '사상자수', '전체공사비_분류', '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1',
#        '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도'],
#       dtype='object')

# %%
fields.remove('공사기간_시작일')
fields.remove('공사기간_종료일')
fields.remove('공종_시작일')
fields.remove('공종_종료일')
fields.remove('구체적 사고원인')
fields.remove('사고발생후 조치사항')
fields.remove('재발방지대책')

# %%
drop_fields = ['시간대','습도','']

# %%
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '습도', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호',
#        '사상자수', '전체공사비_분류', '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1',
#        '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도'],
#       dtype='object')

# %%
cate = cate[fields]

# %%
drop_cols = ['기온', '습도', '구체적 사고원인', '사고발생후 조치사항', '재발방지대책', '공사기간_시작일', '공사기간_종료일', '공종_시작일',
             '공종_종료일', '관측소', '시간', '발생날짜', '지점 번호', '전체공사비_분류']

# %%
drop_cols = [x for x in drop_cols if x in df2.columns]
drop_cols
# Out:
# ['기온', '시간']

# %%
df2 = df2.drop(drop_cols,axis=1)
df2[fields]=cate
df2.dtypes
# fields.remove('인적사고')
# Out:
# 시간대                  float64
# 사고인지 시간              float64
# 보호(방호)조치여부 - 안전방호    float64
# 보호(방호)조치여부 - 개인방호    float64
# 사상자수                 float64
# 공정률                  float64
# 작업자수                 float64
# 기온.1                 float64
# 강수량                  float64
# 풍속                   float64
# 풍향                   float64
# 습도.1                 float64
# 증기압                  float64
# 이슬점온도                float64
# 현지기압                 float64
# 해면기압                 float64
# 일조                   float64
# 전운량                  float64
# 중하층운량                float64
# 시정                   float64
# 지면온도                 float64
# 요일                    object
# 공휴일여부                 object
# 오전오후                  object
# 공공/민간 구분              object
# 날씨                    object
# 인적사고                  object
# 공종_대분류                object
# 공종_중분류                object
# 사고객체_대분류              object
# 사고객체_중분류              object
# 작업프로세스                object
# 장소_대분류                object
# 장소_중분류                object
# 부위_대분류                object
# 부위_중분류                object
# 사고원인_주원인              object
# 사고신고사유_부상             object
# 사고신고사유_사망             object
# 사고신고사유_물적             object
# 시                     object
# 전체공사비                 object
# 해당공종_공사비              object
# 안전관리계획                object
# 설계안전성검토               object
# 시간                    object
# 기온                    object
# dtype: object

# %%
df2 = df2.dropna()

# %%
df2 = df2[df2['인적사고'] != '0'].dropna()

# %%
fields = [x for x in fields if x in df2.columns]
fields
# Out:
# ['요일',
#  '공휴일여부',
#  '오전오후',
#  '시간',
#  '공공/민간 구분',
#  '날씨',
#  '기온',
#  '공종_대분류',
#  '공종_중분류',
#  '사고객체_대분류',
#  '사고객체_중분류',
#  '작업프로세스',
#  '장소_대분류',
#  '장소_중분류',
#  '부위_대분류',
#  '부위_중분류',
#  '사고원인_주원인',
#  '사고신고사유_부상',
#  '사고신고사유_사망',
#  '사고신고사유_물적',
#  '시',
#  '전체공사비',
#  '해당공종_공사비',
#  '안전관리계획',
#  '설계안전성검토']

# %%
x = my_dummies(df2,*fields)
y = my_labelling(df2[['인적사고']],'인적사고')

# %%
x.shape
# Out:
# (23494, 1740)

# %%
x['인적사고'] = y

# %%
x_train,x_test,y_train,y_test = my_train_test_split(x,'인적사고')
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((18795, 1739), (4699, 1739), (18795,), (4699,))

# %%
# params = {
#     "n_estimators": [10, 20, 50, 100],
#     "criterion": ["squared_error", "absolute_error", "friedman_mse", "poisson"],
#     "max_features": ["sqrt", "log2"],
#     "max_depth": [10, 20, 50, None],
# }

# %% [markdown]
# xgb - y 갯수 줄이기 전
#
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
# [분류분석 성능평가]
#
#
# | | 훈련데이터 |   검증데이터 | 설명                                                      |
# |--|--|--|--|
# | 정확도(Accuracy)  |     0.541919 |     0.488936 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.655207 |     0.420337 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.541919 |     0.335646 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.409932 |     0.357504 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.917224 |     0.868432 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.913331 |     0.860516 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |

# %% [markdown]
# [Best Params]
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
#
#
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |--|--|--|--|
# | 정확도(Accuracy)  |     0.545696 |     0.509137 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.675546 |     0.469469 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.545696 |     0.361035 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.416669 |     0.381702 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.894882 |     0.868483 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.895783 |     0.861934 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |

# %%
my_xgb_classification(x_train,y_train,x_test,y_test, pr=False,roc=False,hist=False,learning_curve=False)
# Out:
# [교차검증 TOP5]
# +----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+--------------------+-------------------+
# |    |   subsample |   reg_lambda |   reg_alpha |   n_estimators |   min_child_weight |   max_depth |   learning_rate |   gamma |   colsample_bytree |   mean_test_score |
# |----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+--------------------+-------------------|
# |  0 |           1 |            7 |           1 |            200 |                  1 |           6 |             0.1 |       2 |                0.7 |          0.500559 |
# |  1 |         0.5 |            5 |           1 |            200 |                  7 |           2 |             0.3 |       4 |                0.8 |          0.495238 |
# |  2 |           1 |            9 |           3 |            500 |                  3 |           2 |             0.3 |       3 |                0.6 |          0.494387 |
# |  3 |         0.5 |            9 |           1 |            100 |                  3 |           4 |             0.1 |       2 |                0.7 |          0.493748 |
# |  4 |           1 |            5 |           1 |            300 |                  9 |           6 |             0.5 |       3 |                0.7 |          0.493695 |
# +----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+--------------------+-------------------+
#
# [Best Params]
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.549933 |     0.494786 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.574784 |     0.456709 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.549933 |     0.337374 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.398216 |     0.352466 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.896252 |     0.843923 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.899275 |     0.847544 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [변수 중요도]
# +------------------------------------------------+---------+-------------+-----------+
# |                                                |   score |        rate |    cumsum |
# |------------------------------------------------+---------+-------------+-----------|
# | 사고인지 시간                                  |     360 |   0.0318274 | 0.0318274 |
# | 보호(방호)조치여부 - 안전방호                  |     353 |   0.0312086 |  0.063036 |
# | 기온.1                                         |     306 |   0.0270533 | 0.0900893 |
# | 보호(방호)조치여부 - 개인방호                  |     269 |   0.0237822 |  0.113871 |
# | 시정                                           |     250 |   0.0221024 |  0.135974 |
# | 현지기압                                       |     233 |   0.0205994 |  0.156573 |
# | 사고신고사유_사망_사망 내용 없음               |     223 |   0.0197153 |  0.176289 |
# | 작업자수                                       |     214 |   0.0189196 |  0.195208 |
# | 습도.1                                         |     214 |   0.0189196 |  0.214128 |
# | 사고객체_대분류_기타                           |     210 |    0.018566 |  0.232694 |
# | 해면기압                                       |     191 |   0.0168862 |   0.24958 |
# | 증기압                                         |     188 |    0.016621 |  0.266201 |
# | 풍속                                           |     181 |   0.0160021 |  0.282203 |
# | 사상자수                                       |     170 |   0.0150296 |  0.297233 |
# | 공정률                                         |     164 |   0.0144992 |  0.311732 |
# | 사고원인_주원인_작업자 부주의                  |     163 |   0.0144108 |  0.326143 |
# | 시간대                                         |     159 |   0.0140571 |    0.3402 |
# | 사고객체_중분류_공구류                         |     158 |   0.0139687 |  0.354169 |
# | 풍향                                           |     154 |   0.0136151 |  0.367784 |
# | 작업프로세스_절단작업                          |     151 |   0.0133498 |  0.381133 |
# | 작업프로세스_운반작업                          |     147 |   0.0129962 |   0.39413 |
# | 사고객체_대분류_건설기계                       |     147 |   0.0129962 |  0.407126 |
# | 사고객체_대분류_건설자재                       |     134 |   0.0118469 |  0.418973 |
# | 작업프로세스_이동                              |     132 |   0.0116701 |  0.430643 |
# | 사고객체_대분류_토사 및 암반                   |     118 |   0.0104323 |  0.441075 |
# | 이슬점온도                                     |     115 |   0.0101671 |  0.451242 |
# | 공종_대분류_토목                               |     104 |  0.00919459 |  0.460437 |
# | 사고객체_중분류_작업발판                       |     102 |  0.00901777 |  0.469455 |
# | 공종_중분류_철근콘크리트공사                   |      97 |  0.00857572 |   0.47803 |
# | 부위_중분류_바닥                               |      93 |  0.00822208 |  0.486252 |
# | 사고객체_대분류_질병                           |      91 |  0.00804527 |  0.494298 |
# | 사고객체_중분류_기타                           |      90 |  0.00795686 |  0.502254 |
# | 부위_중분류_상부(위)                           |      82 |  0.00724958 |  0.509504 |
# | 사고원인_주원인_기타                           |      80 |  0.00707276 |  0.516577 |
# | 작업프로세스_설치작업                          |      79 |  0.00698435 |  0.523561 |
# | 전운량                                         |      77 |  0.00680753 |  0.530369 |
# | 일조                                           |      76 |  0.00671912 |  0.537088 |
# | 장소_중분류_외부                               |      75 |  0.00663071 |  0.543719 |
# | 장소_중분류_내부                               |      74 |   0.0065423 |  0.550261 |
# | 부위_중분류_앞                                 |      74 |   0.0065423 |  0.556803 |
# | 사고객체_중분류_사다리                         |      73 |  0.00645389 |  0.563257 |
# | 부위_중분류_기타                               |      73 |  0.00645389 |  0.569711 |
# | 부위_중분류_옆                                 |      73 |  0.00645389 |  0.576165 |
# | 사고원인_주원인_운전자 자격관리 미흡           |      70 |  0.00618867 |  0.582353 |
# | 중하층운량                                     |      69 |  0.00610026 |  0.588454 |
# | 전체공사비_1,000억원 이상                      |      66 |  0.00583503 |  0.594289 |
# | 부위_중분류_하부(아래)                         |      66 |  0.00583503 |  0.600124 |
# | 사고객체_중분류_자재                           |      65 |  0.00574662 |   0.60587 |
# | 사고원인_주원인_개인 안전보호구 착용 불량      |      65 |  0.00574662 |  0.611617 |
# | 작업프로세스_해체작업                          |      65 |  0.00574662 |  0.617364 |
# | 안전관리계획_대상현장(1/2종)                   |      65 |  0.00574662 |   0.62311 |
# | 사고객체_중분류_비계                           |      64 |  0.00565821 |  0.628768 |
# | 사고객체_중분류_철근                           |      59 |  0.00521616 |  0.633985 |
# | 사고객체_대분류_건설공구                       |      58 |  0.00512775 |  0.639112 |
# | 작업프로세스_기타                              |      58 |  0.00512775 |   0.64424 |
# | 사고원인_주원인_작업자의 불안전한 행동         |      58 |  0.00512775 |  0.649368 |
# | 사고객체_중분류_전주, 전선                     |      54 |  0.00477411 |  0.654142 |
# | 장소_대분류_공동주택                           |      53 |   0.0046857 |  0.658828 |
# | 사고원인_주원인_작업자 통제 미흡               |      52 |  0.00459729 |  0.663425 |
# | 사고신고사유_부상_부상 내용 없음               |      51 |  0.00450889 |  0.667934 |
# | 부위_대분류_공구류                             |      50 |  0.00442048 |  0.672354 |
# | 공종_대분류_기타                               |      50 |  0.00442048 |  0.676775 |
# | 사고객체_중분류_건물                           |      50 |  0.00442048 |  0.681195 |
# | 사고원인_주원인_작업순서 미준수                |      50 |  0.00442048 |  0.685616 |
# | 작업프로세스_마감작업                          |      49 |  0.00433207 |  0.689948 |
# | 사고객체_중분류_차량                           |      48 |  0.00424366 |  0.694191 |
# | 안전관리계획_비대상현장                        |      48 |  0.00424366 |  0.698435 |
# | 부위_중분류_고소                               |      47 |  0.00415525 |   0.70259 |
# | 사고원인_주원인_작업자 건강상태 확인 미흡      |      47 |  0.00415525 |  0.706746 |
# | 사고원인_주원인_위험정보 미제공                |      45 |  0.00397843 |  0.710724 |
# | 부위_중분류_뒤                                 |      44 |  0.00389002 |  0.714614 |
# | 사고원인_주원인_시공품질 미확보                |      40 |  0.00353638 |   0.71815 |
# | 사고객체_중분류_굴착기                         |      40 |  0.00353638 |  0.721687 |
# | 사고객체_대분류_부재                           |      40 |  0.00353638 |  0.725223 |
# | 장소_대분류_기타                               |      39 |  0.00344797 |  0.728671 |
# | 사고객체_중분류_덤프트럭                       |      39 |  0.00344797 |  0.732119 |
# | 작업프로세스_용접작업                          |      39 |  0.00344797 |  0.735567 |
# | 부위_대분류_기타                               |      39 |  0.00344797 |  0.739015 |
# | 작업프로세스_타설작업                          |      38 |  0.00335956 |  0.742375 |
# | 사고객체_중분류_안전시설물                     |      37 |  0.00327115 |  0.745646 |
# | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 |      36 |  0.00318274 |  0.748829 |
# | 공종_중분류_철골공사                           |      35 |  0.00309433 |  0.751923 |
# | 시_서울특별시                                  |      34 |  0.00300592 |  0.754929 |
# | 시간_10:00                                     |      34 |  0.00300592 |  0.757935 |
# | 장소_대분류_공장                               |      33 |  0.00291751 |  0.760852 |
# | 공종_중분류_수장공사                           |      31 |  0.00274069 |  0.763593 |
# | 사고객체_중분류_거푸집                         |      31 |  0.00274069 |  0.766334 |
# | 사고객체_중분류_비산물                         |      30 |  0.00265229 |  0.768986 |
# | 사고객체_중분류_핀                             |      30 |  0.00265229 |  0.771638 |
# | 작업프로세스_정리작업                          |      29 |  0.00256388 |  0.774202 |
# | 장소_대분류_업무시설                           |      29 |  0.00256388 |  0.776766 |
# | 작업프로세스_도장작업                          |      29 |  0.00256388 |   0.77933 |
# | 공종_중분류_기타                               |      28 |  0.00247547 |  0.781805 |
# | 사고객체_대분류_시설물                         |      27 |  0.00238706 |  0.784192 |
# | 공휴일여부_휴일                                |      27 |  0.00238706 |  0.786579 |
# | 해당공종_공사비_100억~150억원미만              |      27 |  0.00238706 |  0.788966 |
# | 작업프로세스_전기작업                          |      26 |  0.00229865 |  0.791265 |
# | 장소_중분류_인접주변                           |      26 |  0.00229865 |  0.793564 |
# | 작업프로세스_인양작업                          |      26 |  0.00229865 |  0.795862 |
# | 설계안전성검토_대상                            |      25 |  0.00221024 |  0.798073 |
# | 작업프로세스_벌목작업                          |      25 |  0.00221024 |  0.800283 |
# | 해당공종_공사비_20억~50억원미만                |      25 |  0.00221024 |  0.802493 |
# | 부위_대분류_사다리                             |      24 |  0.00212183 |  0.804615 |
# | 사고객체_중분류_데크플레이트                   |      24 |  0.00212183 |  0.806737 |
# | 작업프로세스_상차 및 하역작업                  |      24 |  0.00212183 |  0.808859 |
# | 공종_중분류_금속공사                           |      23 |  0.00203342 |  0.810892 |
# | 요일_화요일                                    |      23 |  0.00203342 |  0.812925 |
# | 작업프로세스_양중작업                          |      23 |  0.00203342 |  0.814959 |
# | 공종_중분류_해체 및 철거공사                   |      23 |  0.00203342 |  0.816992 |
# | 공종_중분류_건축 토공사                        |      22 |  0.00194501 |  0.818937 |
# | 공공/민간 구분_민간                            |      22 |  0.00194501 |  0.820882 |
# | 시_충청남도                                    |      22 |  0.00194501 |  0.822827 |
# | 장소_대분류_하수도                             |      22 |  0.00194501 |  0.824772 |
# | 날씨_흐림                                      |      21 |   0.0018566 |  0.826629 |
# | 장소_대분류_창고시설                           |      21 |   0.0018566 |  0.828486 |
# | 작업프로세스_형틀 및 목공                      |      21 |   0.0018566 |  0.830342 |
# | 부위_대분류_철근                               |      21 |   0.0018566 |  0.832199 |
# | 사고객체_중분류_개구부                         |      20 |  0.00176819 |  0.833967 |
# | 사고객체_중분류_배관                           |      20 |  0.00176819 |  0.835735 |
# | 부위_대분류_작업발판                           |      20 |  0.00176819 |  0.837503 |
# | 전체공사비_300억 ~ 500억원 미만                |      20 |  0.00176819 |  0.839272 |
# | 사고객체_중분류_지게차                         |      20 |  0.00176819 |   0.84104 |
# | 시간_14:00                                     |      20 |  0.00176819 |  0.842808 |
# | 공종_중분류_전기설비공사                       |      19 |  0.00167978 |  0.844488 |
# | 공종_중분류_미장공사                           |      19 |  0.00167978 |  0.846167 |
# | 공종_중분류_도장공사                           |      19 |  0.00167978 |  0.847847 |
# | 공종_중분류_기계설비공사                       |      19 |  0.00167978 |  0.849527 |
# | 시_경기도                                      |      19 |  0.00167978 |  0.851207 |
# | 시_광주광역시                                  |      19 |  0.00167978 |  0.852887 |
# | 지면온도                                       |      19 |  0.00167978 |  0.854566 |
# | 부위_대분류_자재                               |      18 |  0.00159137 |  0.856158 |
# | 부위_대분류_전주, 전선                         |      18 |  0.00159137 |  0.857749 |
# | 사고객체_중분류_시스템동바리                   |      18 |  0.00159137 |   0.85934 |
# | 시간_11:00                                     |      18 |  0.00159137 |  0.860932 |
# | 사고원인_주원인_안전관리계획 수립 미흡         |      18 |  0.00159137 |  0.862523 |
# | 요일_일요일                                    |      18 |  0.00159137 |  0.864115 |
# | 작업프로세스_조립작업                          |      18 |  0.00159137 |  0.865706 |
# | 전체공사비_500억 ~ 1,000억원 미만              |      17 |  0.00150296 |  0.867209 |
# | 사고객체_중분류_질병                           |      17 |  0.00150296 |  0.868712 |
# | 날씨_맑음                                      |      16 |  0.00141455 |  0.870126 |
# | 해당공종_공사비_5억~10억원미만                 |      16 |  0.00141455 |  0.871541 |
# | 시_부산광역시                                  |      16 |  0.00141455 |  0.872956 |
# | 사고객체_중분류_굴착사면                       |      16 |  0.00141455 |   0.87437 |
# | 시간_8:00                                      |      15 |  0.00132614 |  0.875696 |
# | 사고객체_중분류_고소작업차(고소작업대 등)      |      15 |  0.00132614 |  0.877022 |
# | 장소_중분류_지붕                               |      15 |  0.00132614 |  0.878349 |
# | 시간_16:00                                     |      15 |  0.00132614 |  0.879675 |
# | 시간_15:00                                     |      15 |  0.00132614 |  0.881001 |
# | 부위_대분류_비계                               |      15 |  0.00132614 |  0.882327 |
# | 사고원인_주원인_사다리 사용수칙 미준수         |      14 |  0.00123773 |  0.883565 |
# | 공공/민간 구분_공공                            |      14 |  0.00123773 |  0.884802 |
# | 작업프로세스_연결작업                          |      14 |  0.00123773 |   0.88604 |
# | 기온_30℃                                       |      14 |  0.00123773 |  0.887278 |
# | 부위_대분류_굴착기                             |      14 |  0.00123773 |  0.888516 |
# | 해당공종_공사비_4,000만~1억원미만              |      14 |  0.00123773 |  0.889753 |
# | 사고객체_중분류_절토사면                       |      14 |  0.00123773 |  0.890991 |
# | 전체공사비_150억 ~ 200억원 미만                |      14 |  0.00123773 |  0.892229 |
# | 사고객체_중분류_슬래브                         |      14 |  0.00123773 |  0.893467 |
# | 사고객체_중분류_강관동바리                     |      13 |  0.00114932 |  0.894616 |
# | 해당공종_공사비_분류불능                       |      13 |  0.00114932 |  0.895765 |
# | 부위_대분류_건물                               |      13 |  0.00114932 |  0.896915 |
# | 공종_중분류_산업설비공사                       |      13 |  0.00114932 |  0.898064 |
# | 해당공종_공사비_2,000만~4,000만원미만          |      13 |  0.00114932 |  0.899213 |
# | 시_충청북도                                    |      13 |  0.00114932 |  0.900362 |
# | 작업프로세스_항타 및 항발작업                  |      13 |  0.00114932 |  0.901512 |
# | 기온_25℃                                       |      13 |  0.00114932 |  0.902661 |
# | 장소_대분류_도로                               |      13 |  0.00114932 |   0.90381 |
# | 기온_20℃                                       |      13 |  0.00114932 |   0.90496 |
# | 시_경상남도                                    |      13 |  0.00114932 |  0.906109 |
# | 사고객체_중분류_철골부재                       |      13 |  0.00114932 |  0.907258 |
# | 시_대구광역시                                  |      12 |  0.00106091 |  0.908319 |
# | 부위_중분류_지하                               |      12 |  0.00106091 |   0.90938 |
# | 부위_대분류_질병                               |      12 |  0.00106091 |  0.910441 |
# | 작업프로세스_준비작업                          |      12 |  0.00106091 |  0.911502 |
# | 부위_대분류_차량                               |      12 |  0.00106091 |  0.912563 |
# | 장소_대분류_근린생활시설                       |      12 |  0.00106091 |  0.913624 |
# | 부위_대분류_거푸집                             |      12 |  0.00106091 |  0.914685 |
# | 부위_대분류_덤프트럭                           |      12 |  0.00106091 |  0.915746 |
# | 사고객체_중분류_흙막이가시설                   |      12 |  0.00106091 |  0.916807 |
# | 요일_수요일                                    |      12 |  0.00106091 |  0.917868 |
# | 공종_중분류_목공사                             |      12 |  0.00106091 |  0.918928 |
# | 시간_13:00                                     |      11 | 0.000972505 |  0.919901 |
# | 해당공종_공사비_3억~5억원미만                  |      11 | 0.000972505 |  0.920873 |
# | 기온_18℃                                       |      11 | 0.000972505 |  0.921846 |
# | 요일_토요일                                    |      11 | 0.000972505 |  0.922818 |
# | 부위_대분류_핀                                 |      11 | 0.000972505 |  0.923791 |
# | 공종_중분류_조적공사                           |      11 | 0.000972505 |  0.924764 |
# | 시_제주특별자치도                              |      11 | 0.000972505 |  0.925736 |
# | 해당공종_공사비_500억~1,000억원미만            |      11 | 0.000972505 |  0.926709 |
# | 안전관리계획_대상현장(1/2종외)                 |      11 | 0.000972505 |  0.927681 |
# | 사고원인_주원인_계측데이터 관리 미흡           |      11 | 0.000972505 |  0.928654 |
# | 공종_중분류_관공사                             |      11 | 0.000972505 |  0.929626 |
# | 기온_33℃                                       |      10 | 0.000884095 |   0.93051 |
# | 공종_중분류_토공사                             |      10 | 0.000884095 |  0.931394 |
# | 장소_대분류_상수도                             |      10 | 0.000884095 |  0.932278 |
# | 해당공종_공사비_10억~20억원미만                |      10 | 0.000884095 |  0.933162 |
# | 장소_중분류_외벽                               |      10 | 0.000884095 |  0.934047 |
# | 부위_대분류_배관                               |      10 | 0.000884095 |  0.934931 |
# | 공종_대분류_기계설비                           |      10 | 0.000884095 |  0.935815 |
# | 기온_8℃                                        |      10 | 0.000884095 |  0.936699 |
# | 전체공사비_20억 ~ 50억원 미만                  |      10 | 0.000884095 |  0.937583 |
# | 사고원인_주원인_시공관리 미흡                  |      10 | 0.000884095 |  0.938467 |
# | 사고객체_중분류_항타 및 항발기                 |      10 | 0.000884095 |  0.939351 |
# | 기온_5℃                                        |      10 | 0.000884095 |  0.940235 |
# | 사고객체_중분류_파이프서포트                   |      10 | 0.000884095 |  0.941119 |
# | 사고객체_중분류_기타 가시설                    |      10 | 0.000884095 |  0.942003 |
# | 작업프로세스_매설작업                          |      10 | 0.000884095 |  0.942887 |
# | 요일_목요일                                    |      10 | 0.000884095 |  0.943772 |
# | 시_울산광역시                                  |       9 | 0.000795686 |  0.944567 |
# | 전체공사비_2억 ~ 3억원 미만                    |       9 | 0.000795686 |  0.945363 |
# | 전체공사비_200억 ~ 300억원 미만                |       9 | 0.000795686 |  0.946159 |
# | 시간_9:30                                      |       9 | 0.000795686 |  0.946954 |
# | 전체공사비_100억 ~ 150억원 미만                |       9 | 0.000795686 |   0.94775 |
# | 시간_8:30                                      |       9 | 0.000795686 |  0.948546 |
# | 부위_대분류_안전시설물                         |       9 | 0.000795686 |  0.949341 |
# | 기온_28℃                                       |       9 | 0.000795686 |  0.950137 |
# | 기온_15℃                                       |       9 | 0.000795686 |  0.950933 |
# | 부위_대분류_지게차                             |       9 | 0.000795686 |  0.951728 |
# | 사고신고사유_물적_물적피해 내용 없음           |       9 | 0.000795686 |  0.952524 |
# | 요일_월요일                                    |       9 | 0.000795686 |   0.95332 |
# | 사고객체_중분류_작업대차                       |       9 | 0.000795686 |  0.954115 |
# | 장소_대분류_문화및집회시설                     |       9 | 0.000795686 |  0.954911 |
# | 시_세종특별자치시                              |       9 | 0.000795686 |  0.955707 |
# | 시간_14:30                                     |       9 | 0.000795686 |  0.956503 |
# | 사고객체_중분류_지반                           |       8 | 0.000707276 |   0.95721 |
# | 부위_대분류_고소작업차(고소작업대 등)          |       8 | 0.000707276 |  0.957917 |
# | 공종_중분류_지붕 및 홈통공사                   |       8 | 0.000707276 |  0.958624 |
# | 전체공사비_10억 ~ 20억원 미만                  |       8 | 0.000707276 |  0.959332 |
# | 시간_8:50                                      |       8 | 0.000707276 |  0.960039 |
# | 작업프로세스_보수 및 교체작업                  |       8 | 0.000707276 |  0.960746 |
# | 해당공종_공사비_150억~200억원미만              |       8 | 0.000707276 |  0.961453 |
# | 사고객체_중분류_벽체                           |       8 | 0.000707276 |  0.962161 |
# | 부위_대분류_비산물                             |       8 | 0.000707276 |  0.962868 |
# | 사고객체_중분류_창호                           |       8 | 0.000707276 |  0.963575 |
# | 사고원인_주원인_작업전 점검 미흡               |       8 | 0.000707276 |  0.964283 |
# | 시_전라북도                                    |       7 | 0.000618867 |  0.964901 |
# | 시_대전광역시                                  |       7 | 0.000618867 |   0.96552 |
# | 부위_대분류_데크플레이트                       |       7 | 0.000618867 |  0.966139 |
# | 부위_대분류_굴착사면                           |       7 | 0.000618867 |  0.966758 |
# | 시간_15:30                                     |       7 | 0.000618867 |  0.967377 |
# | 설계안전성검토_비대상                          |       7 | 0.000618867 |  0.967996 |
# | 전체공사비_3억 ~ 5억원 미만                    |       7 | 0.000618867 |  0.968615 |
# | 사고객체_중분류_천정패널                       |       7 | 0.000618867 |  0.969233 |
# | 시간_10:05                                     |       7 | 0.000618867 |  0.969852 |
# | 해당공종_공사비_50억~100억원미만               |       7 | 0.000618867 |  0.970471 |
# | 해당공종_공사비_1,000만원미만                  |       7 | 0.000618867 |   0.97109 |
# | 공종_중분류_도로 및 포장공사                   |       7 | 0.000618867 |  0.971709 |
# | 공종_중분류_말뚝공사                           |       7 | 0.000618867 |  0.972328 |
# | 사고객체_중분류_콘크리트펌프                   |       7 | 0.000618867 |  0.972947 |
# | 시간_10:30                                     |       6 | 0.000530457 |  0.973477 |
# | 부위_대분류_항타 및 항발기                     |       6 | 0.000530457 |  0.974008 |
# | 부위_대분류_슬래브                             |       6 | 0.000530457 |  0.974538 |
# | 장소_대분류_판매시설                           |       6 | 0.000530457 |  0.975069 |
# | 해당공종_공사비_1억~2억원미만                  |       6 | 0.000530457 |  0.975599 |
# | 사고객체_중분류_천공기                         |       6 | 0.000530457 |  0.976129 |
# | 장소_대분류_도로교량                           |       6 | 0.000530457 |   0.97666 |
# | 해당공종_공사비_1,000만~2,000만원미만          |       5 | 0.000442048 |  0.977102 |
# | 부위_대분류_기타 가시설                        |       5 | 0.000442048 |  0.977544 |
# | 해당공종_공사비_200억~300억원미만              |       5 | 0.000442048 |  0.977986 |
# | 장소_대분류_교육연구시설                       |       5 | 0.000442048 |  0.978428 |
# | 사고객체_중분류_건설폐기물                     |       5 | 0.000442048 |   0.97887 |
# | 사고객체_중분류_지지대                         |       5 | 0.000442048 |  0.979312 |
# | 공종_중분류_교량공사                           |       5 | 0.000442048 |  0.979754 |
# | 시간_16:30                                     |       5 | 0.000442048 |  0.980196 |
# | 공종_중분류_타일 및 돌공사                     |       5 | 0.000442048 |  0.980638 |
# | 기온_27℃                                       |       5 | 0.000442048 |   0.98108 |
# | 해당공종_공사비_1,000억원이상                  |       5 | 0.000442048 |  0.981522 |
# | 시간_11:30                                     |       5 | 0.000442048 |  0.981964 |
# | 기온_19℃                                       |       5 | 0.000442048 |  0.982407 |
# | 강수량                                         |       4 | 0.000353638 |   0.98276 |
# | 기온_10℃                                       |       4 | 0.000353638 |  0.983114 |
# | 작업프로세스_천공작업                          |       4 | 0.000353638 |  0.983467 |
# | 사고원인_주원인_기계장비 불안전한 거치         |       4 | 0.000353638 |  0.983821 |
# | 기온_17℃                                       |       4 | 0.000353638 |  0.984175 |
# | 부위_대분류_철골부재                           |       4 | 0.000353638 |  0.984528 |
# | 시_경상북도                                    |       4 | 0.000353638 |  0.984882 |
# | 시간_13:30                                     |       4 | 0.000353638 |  0.985236 |
# | 기온_22℃                                       |       4 | 0.000353638 |  0.985589 |
# | 기온_23℃                                       |       4 | 0.000353638 |  0.985943 |
# | 장소_대분류_숙박시설                           |       4 | 0.000353638 |  0.986297 |
# | 기온_32℃                                       |       4 | 0.000353638 |   0.98665 |
# | 공종_중분류_건축물 부대공사                    |       4 | 0.000353638 |  0.987004 |
# | 전체공사비_5억 ~ 10억원 미만                   |       4 | 0.000353638 |  0.987357 |
# | 사고원인_주원인_시방기준 등 미준수             |       3 | 0.000265229 |  0.987623 |
# | 시_인천광역시                                  |       3 | 0.000265229 |  0.987888 |
# | 시_전라남도                                    |       3 | 0.000265229 |  0.988153 |
# | 사고원인_주원인_안전발판 설치 미흡             |       3 | 0.000265229 |  0.988418 |
# | 전체공사비_50억 ~ 100억원 미만                 |       3 | 0.000265229 |  0.988684 |
# | 전체공사비_4,000만 ~ 1억원 미만                |       3 | 0.000265229 |  0.988949 |
# | 작업프로세스_굴착작업                          |       3 | 0.000265229 |  0.989214 |
# | 사고객체_중분류_기중기(이동식크레인 등)        |       3 | 0.000265229 |  0.989479 |
# | 부위_대분류_콘크리트펌프                       |       3 | 0.000265229 |  0.989744 |
# | 공종_중분류_터널공사                           |       3 | 0.000265229 |   0.99001 |
# | 공종_중분류_창호 및 유리공사                   |       3 | 0.000265229 |  0.990275 |
# | 공종_중분류_방수공사                           |       3 | 0.000265229 |   0.99054 |
# | 부위_대분류_절토사면                           |       3 | 0.000265229 |  0.990805 |
# | 부위_대분류_시스템동바리                       |       3 | 0.000265229 |  0.991071 |
# | 장소_대분류_부지조성                           |       3 | 0.000265229 |  0.991336 |
# | 기온_34℃                                       |       3 | 0.000265229 |  0.991601 |
# | 기온_11℃                                       |       3 | 0.000265229 |  0.991866 |
# | 부위_대분류_개구부                             |       3 | 0.000265229 |  0.992132 |
# | 작업프로세스_적재작업                          |       3 | 0.000265229 |  0.992397 |
# | 부위_대분류_작업대차                           |       3 | 0.000265229 |  0.992662 |
# | 장소_대분류_석유화학공장                       |       3 | 0.000265229 |  0.992927 |
# | 작업프로세스_부설 및 다짐작업                  |       3 | 0.000265229 |  0.993192 |
# | 사고객체_중분류_타워크레인                     |       3 | 0.000265229 |  0.993458 |
# | 공종_중분류_철도 및 궤도공사                   |       2 | 0.000176819 |  0.993635 |
# | 부위_대분류_타워크레인                         |       2 | 0.000176819 |  0.993811 |
# | 시간_11:10                                     |       2 | 0.000176819 |  0.993988 |
# | 부위_대분류_벽체                               |       2 | 0.000176819 |  0.994165 |
# | 기온_3℃                                        |       2 | 0.000176819 |  0.994342 |
# | 부위_대분류_경사면                             |       2 | 0.000176819 |  0.994519 |
# | 기온_7℃                                        |       2 | 0.000176819 |  0.994695 |
# | 부위_대분류_강관동바리                         |       2 | 0.000176819 |  0.994872 |
# | 기온_24℃                                       |       2 | 0.000176819 |  0.995049 |
# | 장소_대분류_자동차관련시설                     |       2 | 0.000176819 |  0.995226 |
# | 부위_대분류_지반                               |       2 | 0.000176819 |  0.995403 |
# | 기온_12℃                                       |       2 | 0.000176819 |   0.99558 |
# | 장소_대분류_절토사면                           |       2 | 0.000176819 |  0.995756 |
# | 해당공종_공사비_300억~500억원미만              |       2 | 0.000176819 |  0.995933 |
# | 오전오후_오후                                  |       2 | 0.000176819 |   0.99611 |
# | 부위_대분류_파이프서포트                       |       2 | 0.000176819 |  0.996287 |
# | 부위_대분류_흙막이가시설                       |       2 | 0.000176819 |  0.996464 |
# | 작업프로세스_설비작업                          |       2 | 0.000176819 |   0.99664 |
# | 부위_대분류_천공기                             |       2 | 0.000176819 |  0.996817 |
# | 기온_16℃                                       |       2 | 0.000176819 |  0.996994 |
# | 기온_13℃                                       |       2 | 0.000176819 |  0.997171 |
# | 시간_17:00                                     |       2 | 0.000176819 |  0.997348 |
# | 시간_16:05                                     |       2 | 0.000176819 |  0.997525 |
# | 사고객체_중분류_지하매설물                     |       1 | 8.84095e-05 |  0.997613 |
# | 사고객체_중분류_경사면                         |       1 | 8.84095e-05 |  0.997701 |
# | 장소_대분류_단독주택                           |       1 | 8.84095e-05 |   0.99779 |
# | 시간_10:10                                     |       1 | 8.84095e-05 |  0.997878 |
# | 공종_중분류_항만공사                           |       1 | 8.84095e-05 |  0.997967 |
# | 해당공종_공사비_2억~3억원미만                  |       1 | 8.84095e-05 |  0.998055 |
# | 시간_9:20                                      |       1 | 8.84095e-05 |  0.998143 |
# | 공종_중분류_관공사 부대공사                    |       1 | 8.84095e-05 |  0.998232 |
# | 시간_13:40                                     |       1 | 8.84095e-05 |   0.99832 |
# | 날씨_강우                                      |       1 | 8.84095e-05 |  0.998409 |
# | 시간_9:00                                      |       1 | 8.84095e-05 |  0.998497 |
# | 날씨_안개                                      |       1 | 8.84095e-05 |  0.998585 |
# | 기온_0℃                                        |       1 | 8.84095e-05 |  0.998674 |
# | 시간_7:30                                      |       1 | 8.84095e-05 |  0.998762 |
# | 시간_16:15                                     |       1 | 8.84095e-05 |  0.998851 |
# | 시간_15:10                                     |       1 | 8.84095e-05 |  0.998939 |
# | 시간_14:40                                     |       1 | 8.84095e-05 |  0.999027 |
# | 기온_1℃                                        |       1 | 8.84095e-05 |  0.999116 |
# | 전체공사비_분류불능                            |       1 | 8.84095e-05 |  0.999204 |
# | 시간_13:10                                     |       1 | 8.84095e-05 |  0.999293 |
# | 부위_대분류_천정패널                           |       1 | 8.84095e-05 |  0.999381 |
# | 시간_12:50                                     |       1 | 8.84095e-05 |   0.99947 |
# | 시간_9:15                                      |       1 | 8.84095e-05 |  0.999558 |
# | 부위_대분류_기중기(이동식크레인 등)            |       1 | 8.84095e-05 |  0.999646 |
# | 기온_6℃                                        |       1 | 8.84095e-05 |  0.999735 |
# | 부위_대분류_건설폐기물                         |       1 | 8.84095e-05 |  0.999823 |
# | 시간_10:35                                     |       1 | 8.84095e-05 |  0.999912 |
# | 시간_11:20                                     |       1 | 8.84095e-05 |         1 |
# +------------------------------------------------+---------+-------------+-----------+
#
# [Roc Curve]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[57], line 1
#
# ----> 1 my_xgb_classification(x_train,y_train,x_test,y_test, pr=False,roc=False,hist=False,learning_curve=False)
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:1880, in my_xgb_classification(x_train, y_train, x_test, y_test, conf_matrix, cv, hist, roc, pr, multiclass, learning_curve, report, figsize, dpi, sort, is_print, **params)
#
#    1858 @register_method
#
#    1859 def my_xgb_classification(
#
#    1860     x_train: DataFrame,
#
#    (...)
#
#    1876     **params,
#
#    1877 ) -> XGBClassifier:
#
#    1878     params = get_hyper_params(classname=XGBClassifier)
#
# -> 1880     return __my_classification(
#
#    1881         classname=XGBClassifier,
#
#    1882         x_train=x_train,
#
#    1883         y_train=y_train,
#
#    1884         x_test=x_test,
#
#    1885         y_test=y_test,
#
#    1886         conf_matrix=conf_matrix,
#
#    1887         cv=cv,
#
#    1888         hist=hist,
#
#    1889         roc=roc,
#
#    1890         pr=pr,
#
#    1891         multiclass=multiclass,
#
#    1892         learning_curve=learning_curve,
#
#    1893         report=report,
#
#    1894         figsize=figsize,
#
#    1895         dpi=dpi,
#
#    1896         sort=sort,
#
#    1897         is_print=is_print,
#
#    1898         **params,
#
#    1899     )
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:145, in __my_classification(classname, x_train, y_train, x_test, y_test, conf_matrix, cv, hist, roc, pr, multiclass, learning_curve, report, figsize, dpi, sort, is_print, pruning, **params)
#
#     142 # ------------------------------------------------------
#
#     143 # 보고서 출력
#
#     144 if report and is_print:
#
# --> 145     my_classification_report(estimator, x_train, y_train, x_test, y_test, sort)
#
#     147 return estimator
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:509, in my_classification_report(estimator, x_train, y_train, x_test, y_test, sort)
#
#     507 else:
#
#     508     if x_test is not None and y_test is not None:
#
# --> 509         my_classification_multiclass_report(
#
#     510             estimator, x=x_test, y=y_test, sort=sort
#
#     511         )
#
#     512     else:
#
#     513         my_classification_multiclass_report(
#
#     514             estimator, x=x_train, y=y_train, sort=sort
#
#     515         )
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:721, in my_classification_multiclass_report(estimator, x, y, sort)
#
#     718 for i in range(0, class_size):
#
#     719     # VIF
#
#     720     if len(x.columns) > 1:
#
# --> 721         vif = [
#
#     722             variance_inflation_factor(x, list(x.columns).index(v))
#
#     723             for i, v in enumerate(x.columns)
#
#     724         ]
#
#     725     else:
#
#     726         vif = 0
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:722, in <listcomp>(.0)
#
#     718 for i in range(0, class_size):
#
#     719     # VIF
#
#     720     if len(x.columns) > 1:
#
#     721         vif = [
#
# --> 722             variance_inflation_factor(x, list(x.columns).index(v))
#
#     723             for i, v in enumerate(x.columns)
#
#     724         ]
#
#     725     else:
#
#     726         vif = 0
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\outliers_influence.py:197, in variance_inflation_factor(exog, exog_idx)
#
#     195 mask = np.arange(k_vars) != exog_idx
#
#     196 x_noti = exog[:, mask]
#
# --> 197 r_squared_i = OLS(x_i, x_noti).fit().rsquared
#
#     198 vif = 1. / (1. - r_squared_i)
#
#     199 return vif
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:335, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#
#     330 if method == "pinv":
#
#     331     if not (hasattr(self, 'pinv_wexog') and
#
#     332             hasattr(self, 'normalized_cov_params') and
#
#     333             hasattr(self, 'rank')):
#
# --> 335         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#
#     336         self.normalized_cov_params = np.dot(
#
#     337             self.pinv_wexog, np.transpose(self.pinv_wexog))
#
#     339         # Cache these singular values for use later.
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tools\tools.py:264, in pinv_extended(x, rcond)
#
#     262 x = np.asarray(x)
#
#     263 x = x.conjugate()
#
# --> 264 u, s, vt = np.linalg.svd(x, False)
#
#     265 s_orig = np.copy(s)
#
#     266 m = u.shape[0]
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#
#    1678         gufunc = _umath_linalg.svd_n_s
#
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#
#    1682 u = u.astype(result_t, copy=False)
#
#    1683 s = s.astype(_realType(result_t), copy=False)
#
#
#
# KeyboardInterrupt:
