# %%
# pip install --upgrade git+https://github.com/hyk2202/helper.git

import pandas as pd
from helper.util import *
from helper.analysis import *
from helper.tensor import *
from helper.plot import *
from helper.timeserise import *
from helper.core import *
from helper.classification import *
from helper.re import *
from helper.regression import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hyk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
origin = my_read_data('데이터_전처리_최종.xlsx',info=False, index_col='IDX')

# %%
df = origin.copy()
df.columns
# Out:
# Index(['발생날짜', '요일', '공휴일여부', '오전오후', '시간대', '시간', '사고인지 시간', '공공/민간 구분', '날씨',
#        '기온', '습도', '인적사고', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호', '공종_대분류',
#        '공종_중분류', '사고객체_대분류', '사고객체_중분류', '작업프로세스', '장소_대분류', '장소_중분류',
#        '부위_대분류', '부위_중분류', '사고원인_주원인', '사상자수', '사고신고사유_부상', '사고신고사유_사망',
#        '사고신고사유_물적', '시', '전체공사비', '전체공사비_분류', '해당공종_공사비', '구체적 사고원인',
#        '사고발생후 조치사항', '공사기간_시작일', '공사기간_종료일', '공종_시작일', '공종_종료일', '재발방지대책',
#        '공정률', '안전관리계획', '설계안전성검토', '작업자수', '지점 번호', '관측소', '기온.1', '강수량', '풍속',
#        '풍향', '습도.1', '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량',
#        '시정', '지면온도'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 발생날짜                 datetime64[ns]
# 요일                           object
# 공휴일여부                        object
# 오전오후                         object
# 시간대                           int64
# 시간                           object
# 사고인지 시간                      object
# 공공/민간 구분                     object
# 날씨                           object
# 기온                           object
# 습도                          float64
# 인적사고                         object
# 보호(방호)조치여부 - 안전방호            object
# 보호(방호)조치여부 - 개인방호            object
# 공종_대분류                       object
# 공종_중분류                       object
# 사고객체_대분류                     object
# 사고객체_중분류                     object
# 작업프로세스                       object
# 장소_대분류                       object
# 장소_중분류                       object
# 부위_대분류                       object
# 부위_중분류                       object
# 사고원인_주원인                     object
# 사상자수                          int64
# 사고신고사유_부상                    object
# 사고신고사유_사망                    object
# 사고신고사유_물적                    object
# 시                            object
# 전체공사비                        object
# 전체공사비_분류                     object
# 해당공종_공사비                     object
# 구체적 사고원인                     object
# 사고발생후 조치사항                   object
# 공사기간_시작일                     object
# 공사기간_종료일                     object
# 공종_시작일                       object
# 공종_종료일                       object
# 재발방지대책                       object
# 공정률                          object
# 안전관리계획                       object
# 설계안전성검토                      object
# 작업자수                         object
# 지점 번호                         int64
# 관측소                          object
# 기온.1                        float64
# 강수량                         float64
# 풍속                          float64
# 풍향                          float64
# 습도.1                        float64
# 증기압                         float64
# 이슬점온도                       float64
# 현지기압                        float64
# 해면기압                        float64
# 일조                          float64
# 전운량                         float64
# 중하층운량                       float64
# 시정                          float64
# 지면온도                        float64
# dtype: object

# %%
df.drop(['발생날짜','지점 번호','관측소'],axis=1,inplace=True)

# %%
temp = []
for i in df['인적사고']:
    if i == '기타':temp.append('분류불능')
    elif i == '없음':temp.append(None)
    else:temp.append(i)

df['인적사고'] = temp
df['인적사고'].value_counts()
# Out:
# 넘어짐       5814
# 떨어짐       4321
# 물체에 맞음    3509
# 끼임        2576
# 분류불능      2152
# 부딪힘       1850
# 절단, 베임    1688
# 깔림         521
# 질병         381
# 찔림         307
# 화상         186
# 교통사고       123
# 감전          48
# 질식          18
# Name: 인적사고, dtype: int64

# %%
temp =[]
for i in df['강수량']:
    if i>=0.1 : temp.append(1)
    else:temp.append(0)

# %%
# 결측치 : 0 정규작업 :1 그외: 2

temp = []
for i in df['사고인지 시간'].fillna(0):
    if i == 0 : temp.append(0)
    elif i == '정규작업 ': temp.append(1)
    else:temp.append(2)

df['사고인지 시간'] = temp
df['사고인지 시간'].value_counts()
# Out:
# 1    18032
# 0     3167
# 2     2523
# Name: 사고인지 시간, dtype: int64

# %%
# 결측치 : 0, 조치/해당없음:1, 비조치:2

temp = []
for i in df["보호(방호)조치여부 - 안전방호"].fillna(0):
    if i == 0 :temp.append(0)
    elif i == '비조치': temp.append(2)
    else:temp.append(1)
df["보호(방호)조치여부 - 안전방호"] =temp


df["보호(방호)조치여부 - 안전방호"].value_counts()
# Out:
# 1    17153
# 0     5411
# 2     1158
# Name: 보호(방호)조치여부 - 안전방호, dtype: int64

# %%
# 결측치 : 0, 조치/해당없음:1, 비조치:2

temp = []
for i in df["보호(방호)조치여부 - 개인방호"].fillna(0):
    if i == 0 :temp.append(0)
    elif i == '비조치': temp.append(2)
    else:temp.append(1)
df["보호(방호)조치여부 - 개인방호"] =temp


df["보호(방호)조치여부 - 개인방호"].value_counts()
# Out:
# 1    17455
# 0     5410
# 2      857
# Name: 보호(방호)조치여부 - 개인방호, dtype: int64

# %%
# 통신설비, 산업설비, 전기설비 => 기타
temp = []
for i in df['공종_대분류']:
    if i in ['통신설비','산업설비','전기설비']:temp.append('기타')
    else:temp.append(i)
df['공종_대분류'] =temp

# %%
# 비조치 :2 , 조치,해당없음 : 1 ,결측치 : 0
temp = []
for i in origin["작업프로세스"]:
    if i == '비조치': temp.append(2)
    elif i ==0:temp.append(1)
    else:temp.append(0)

# %%
#노동부고시 제2002-8호, 『화학물질 및 물리적인자의 노출기준』 중 <별표 4>의 고온의 노출기준
temp = []
for i in origin['지면온도']:
    if i <25.0: temp.append(0)
    elif i <25.9:temp.append(1)
    elif i<27.9:temp.append(2)
    elif i <30:temp.append(3)
    else:temp.append(4)
df['지면온도'] = temp

# %%
df['전체공사비_분류'] = df['전체공사비_분류'].map({'2,000만 ~ 5억원 미만':2, '2,000만 미만':1, '50억원 이상':4, '5억 ~ 50억원 미만':3, '분류불능':0})
df['전체공사비_분류'].value_counts()
# Out:
# 4    15759
# 2     3961
# 3     3654
# 1      228
# 0      120
# Name: 전체공사비_분류, dtype: int64

# %%
temp = []
for i in df['작업자수']:
    try:
        a = int(i[:3])
        if a == 100: temp.append(4)
        elif a == 300: temp.append(5)
        elif a == 500: temp.append(6)

    except:
        a = int(i[:2])
        if a ==19:temp.append(0)
        elif a == 20 :temp.append(1)
        elif a==50:temp.append(2)
df['작업자수'] = temp

# %%
temp = []
for i in origin['공정률']:
    try:
        if '미만' in i : temp.append(0)
        elif '이상' in i: temp.append(9)
        else:
            temp.append(int(i[:1]))
    except:
        
        temp.append(0)

df['공정률'] = temp

# %%
df.dtypes

    
fields=[]
for f in df.columns:
    if df[f].dtypes not in [
        "int",
        "int32",
        "int64",
        "float",
        "float32",
        "float64",
    ]:
        fields.append(f)

# %%
cate = df[fields]
df2 = df.drop(fields,axis=1)

# %%
df2 = my_replace_missing_value(df2,'constant',0)
cate = my_replace_missing_value(cate,'constant','0')

# %%
df2['구체적 사고원인']
# Out:
# IDX
# 0        자재 절단 작업시 목장갑을 착용하면 안되지만 작업자 부주의로 목장갑 착용상태에서 작...
# 1        안전벨트를 착용하였으나 체결하지 않은 상태로 해당구간으로 이동하던 중 중심을 잃고 추락함
# 2        24년 4월12일 09시 경 지상 1층 A-2구간에서 골조업체 정리 직영인부가 각재...
# 3                           회전하는 원형톱에 합판절단 중 장갑이 끼여 손가락절단.
# 4                                      말비계에서 내려오던 중 발목 접지름
#                                ...
# 23717    청소 중 보밑 동바리가 받칠필요가없다고 판단하여 제거 후 청소소하려고 고정핀을 제거...
# 23718                   작업자 개인 지병(알코올성 경기)으로 인해 의식을 잃고 넘어짐
# 23719    반복작업에 의한 팔꿈치 통증 발생, 반복 작업시 충분한 휴식 및 적정운반양 지정, ...
# 23720       전용도구 미사용으로 인한 띠장 절단 작업 중 H-BEAM 절단부에 왼손 약지를 베임
# 23721                        창틀 위의 유로폼 해체 중 폼이 떨어져 가슴에 부딪힘
# Name: 구체적 사고원인, Length: 23722, dtype: object

# %%
import pandas as pd

df2['총_공사기간'] = (pd.to_datetime(df2['공사기간_종료일']) - pd.to_datetime(df2['공사기간_시작일'])).dt.days
df2['공종공사기간'] = (pd.to_datetime(df2['공종_종료일']) - pd.to_datetime(df2['공종_시작일'])).dt.days
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '습도', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호',
#        '사상자수', '전체공사비_분류', '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1',
#        '증기압', '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도',
#        '요일', '공휴일여부', '오전오후', '시간', '공공/민간 구분', '날씨', '기온', '인적사고', '공종_대분류',
#        '공종_중분류', '사고객체_대분류', '사고객체_중분류', '작업프로세스', '장소_대분류', '장소_중분류',
#        '부위_대분류', '부위_중분류', '사고원인_주원인', '사고신고사유_부상', '사고신고사유_사망', '사고신고사유_물적',
#        '시', '전체공사비', '해당공종_공사비', '구체적 사고원인', '사고발생후 조치사항', '공사기간_시작일',
#        '공사기간_종료일', '공종_시작일', '공종_종료일', '재발방지대책', '안전관리계획', '설계안전성검토', '총_공사기간',
#        '공종공사기간'],
#       dtype='object')

# %%
fields.remove('공사기간_시작일')
fields.remove('공사기간_종료일')
fields.remove('공종_시작일')
fields.remove('공종_종료일')
fields.remove('구체적 사고원인')
fields.remove('사고발생후 조치사항')
fields.remove('재발방지대책')

# %%
drop_fields = ['시간대','습도','']

# %%
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '습도', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호',
#        '사상자수', '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1', '증기압',
#        '이슬점온도', '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도'],
#       dtype='object')

# %%
cate = cate[fields]

# %%
drop_cols = ['기온', '습도', '구체적 사고원인', '사고발생후 조치사항', '재발방지대책', '공사기간_시작일', '공사기간_종료일', '공종_시작일',
             '공종_종료일', '관측소', '시간', '발생날짜', '지점 번호', '전체공사비_분류']

# %%
drop_cols = [x for x in drop_cols if x in df2.columns]
drop_cols
# Out:
# ['습도']

# %%
df3 = df2[['인적사고','공종_대분류','공종_중분류','총_공사기간','공정률','전체공사비_분류','요일','공휴일여부','보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호','작업프로세스','장소_대분류','장소_중분류','사고원인_주원인']]

# %%
df2 = df2.drop(drop_cols,axis=1)
df2[fields]=cate
df2.dtypes
# fields.remove('인적사고')
# Out:
# 시간대                  float64
# 사고인지 시간              float64
# 보호(방호)조치여부 - 안전방호    float64
# 보호(방호)조치여부 - 개인방호    float64
# 사상자수                 float64
# 공정률                  float64
# 작업자수                 float64
# 기온.1                 float64
# 강수량                  float64
# 풍속                   float64
# 풍향                   float64
# 습도.1                 float64
# 증기압                  float64
# 이슬점온도                float64
# 현지기압                 float64
# 해면기압                 float64
# 일조                   float64
# 전운량                  float64
# 중하층운량                float64
# 시정                   float64
# 지면온도                 float64
# 요일                    object
# 공휴일여부                 object
# 오전오후                  object
# 시간                    object
# 공공/민간 구분              object
# 날씨                    object
# 기온                    object
# 인적사고                  object
# 공종_대분류                object
# 공종_중분류                object
# 사고객체_대분류              object
# 사고객체_중분류              object
# 작업프로세스                object
# 장소_대분류                object
# 장소_중분류                object
# 부위_대분류                object
# 부위_중분류                object
# 사고원인_주원인              object
# 사고신고사유_부상             object
# 사고신고사유_사망             object
# 사고신고사유_물적             object
# 시                     object
# 전체공사비                 object
# 전체공사비_분류              object
# 해당공종_공사비              object
# 안전관리계획                object
# 설계안전성검토               object
# dtype: object

# %%
df2 = df2.dropna()

# %%
df2 = df2[df2['인적사고'] != '0'].dropna()

# %%
df3 = df3[df3['인적사고'] != '0'].dropna()

# %%
fields = [x for x in fields if x in df2.columns]
fields
# Out:
# ['요일',
#  '공휴일여부',
#  '오전오후',
#  '시간',
#  '공공/민간 구분',
#  '날씨',
#  '기온',
#  '인적사고',
#  '공종_대분류',
#  '공종_중분류',
#  '사고객체_대분류',
#  '사고객체_중분류',
#  '작업프로세스',
#  '장소_대분류',
#  '장소_중분류',
#  '부위_대분류',
#  '부위_중분류',
#  '사고원인_주원인',
#  '사고신고사유_부상',
#  '사고신고사유_사망',
#  '사고신고사유_물적',
#  '시',
#  '전체공사비',
#  '전체공사비_분류',
#  '해당공종_공사비',
#  '안전관리계획',
#  '설계안전성검토']

# %%
df2.columns
# Out:
# Index(['시간대', '사고인지 시간', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호', '사상자수',
#        '공정률', '작업자수', '기온.1', '강수량', '풍속', '풍향', '습도.1', '증기압', '이슬점온도',
#        '현지기압', '해면기압', '일조', '전운량', '중하층운량', '시정', '지면온도', '요일', '공휴일여부',
#        '오전오후', '시간', '공공/민간 구분', '날씨', '기온', '인적사고', '공종_대분류', '공종_중분류',
#        '사고객체_대분류', '사고객체_중분류', '작업프로세스', '장소_대분류', '장소_중분류', '부위_대분류',
#        '부위_중분류', '사고원인_주원인', '사고신고사유_부상', '사고신고사유_사망', '사고신고사유_물적', '시',
#        '전체공사비', '전체공사비_분류', '해당공종_공사비', '안전관리계획', '설계안전성검토'],
#       dtype='object')

# %%
df2['설계안전성검토'].value_counts()
# Out:
# 비대상    15189
# 대상      8304
# 0          1
# Name: 설계안전성검토, dtype: int64

# %%
df3 = df2[['시간대', '사고인지 시간', '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호','공정률', '작업자수','강수량', '풍속', '풍향', '습도.1', '일조', '전운량', '중하층운량', '시정', '지면온도', '요일', '공휴일여부','공공/민간 구분','공종_대분류', '공종_중분류',
       '사고객체_대분류', '사고객체_중분류', '작업프로세스', '장소_대분류', '장소_중분류', '부위_대분류',
       '부위_중분류', '사고원인_주원인', '사고신고사유_부상', '사고신고사유_사망', '사고신고사유_물적', '시','전체공사비_분류', '해당공종_공사비']]
df3.dtypes
# Out:
# 시간대                  float64
# 사고인지 시간              float64
# 보호(방호)조치여부 - 안전방호    float64
# 보호(방호)조치여부 - 개인방호    float64
# 공정률                  float64
# 작업자수                 float64
# 강수량                  float64
# 풍속                   float64
# 풍향                   float64
# 습도.1                 float64
# 일조                   float64
# 전운량                  float64
# 중하층운량                float64
# 시정                   float64
# 지면온도                 float64
# 요일                    object
# 공휴일여부                 object
# 공공/민간 구분              object
# 공종_대분류                object
# 공종_중분류                object
# 사고객체_대분류              object
# 사고객체_중분류              object
# 작업프로세스                object
# 장소_대분류                object
# 장소_중분류                object
# 부위_대분류                object
# 부위_중분류                object
# 사고원인_주원인              object
# 사고신고사유_부상             object
# 사고신고사유_사망             object
# 사고신고사유_물적             object
# 시                     object
# 전체공사비_분류              object
# 해당공종_공사비              object
# dtype: object

# %%
df3.columns
# Out:
# Index(['인적사고', '공종_대분류', '공종_중분류', '총_공사기간', '공정률', '전체공사비_분류', '요일', '공휴일여부',
#        '보호(방호)조치여부 - 안전방호', '보호(방호)조치여부 - 개인방호', '작업프로세스', '장소_대분류', '장소_중분류',
#        '사고원인_주원인'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# 인적사고                  object
# 공종_대분류                object
# 공종_중분류                object
# 총_공사기간                 int64
# 공정률                  float64
# 전체공사비_분류             float64
# 요일                    object
# 공휴일여부                 object
# 보호(방호)조치여부 - 안전방호    float64
# 보호(방호)조치여부 - 개인방호    float64
# 작업프로세스                object
# 장소_대분류                object
# 장소_중분류                object
# 사고원인_주원인              object
# dtype: object

# %%
x = my_dummies(df3.drop('인적사고',axis=1),'공종_대분류', '공종_중분류', '요일',
       '공휴일여부', '작업프로세스', '장소_대분류',
       '장소_중분류', '사고원인_주원인')
y = my_labelling(df3[['인적사고']],'인적사고')

# %%
x.shape
# Out:
# (23494, 156)

# %%
x['인적사고'] = y

# %%
x_train,x_test,y_train,y_test = my_train_test_split(x,'인적사고')
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((18795, 155), (4699, 155), (18795,), (4699,))

# %%
# params = {
#     "n_estimators": [10, 20, 50, 100],
#     "criterion": ["squared_error", "absolute_error", "friedman_mse", "poisson"],
#     "max_features": ["sqrt", "log2"],
#     "max_depth": [10, 20, 50, None],
# }

# %% [markdown]
# xgb - y 갯수 줄이기 전
#
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
# [분류분석 성능평가]
#
#
# | | 훈련데이터 |   검증데이터 | 설명                                                      |
# |--|--|--|--|
# | 정확도(Accuracy)  |     0.541919 |     0.488936 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.655207 |     0.420337 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.541919 |     0.335646 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.409932 |     0.357504 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.917224 |     0.868432 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.913331 |     0.860516 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |

# %% [markdown]
# [Best Params]
# {'subsample': 1, 'reg_lambda': 7, 'reg_alpha': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 0.7}
#
#
#
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |--|--|--|--|
# | 정확도(Accuracy)  |     0.545696 |     0.509137 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.675546 |     0.469469 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.545696 |     0.361035 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.416669 |     0.381702 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.894882 |     0.868483 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.895783 |     0.861934 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |

# %%
my_xgb_classification(x_train,y_train,x_test,y_test, pr=False,roc=False,hist=False,learning_curve=False)
# Out:
# [교차검증 TOP5]
# +----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+-------------------------+--------------------+-------------------+
# |    |   subsample |   reg_lambda |   reg_alpha |   n_estimators |   min_child_weight |   max_depth |   learning_rate |   gamma |   early_stopping_rounds |   colsample_bytree |   mean_test_score |
# |----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+-------------------------+--------------------+-------------------|
# |  0 |           1 |            9 |           1 |            500 |                  7 |          10 |            0.01 |       0 |                      10 |                0.8 |          0.414578 |
# |  1 |           1 |            7 |           1 |            200 |                  1 |          10 |             0.1 |       4 |                      10 |                0.7 |          0.411546 |
# |  2 |         0.7 |            3 |           1 |            200 |                  5 |           0 |             0.5 |       2 |                      10 |                0.8 |          0.410322 |
# |  3 |         0.5 |            9 |           1 |            100 |                  3 |           6 |             0.1 |       4 |                      10 |                0.7 |          0.408513 |
# |  4 |         0.5 |            9 |           5 |            200 |                  1 |          10 |               1 |       2 |                      10 |                0.8 |          0.408406 |
# +----+-------------+--------------+-------------+----------------+--------------------+-------------+-----------------+---------+-------------------------+--------------------+-------------------+
#
# [Best Params]
# {'subsample': 1, 'reg_lambda': 9, 'reg_alpha': 1, 'n_estimators': 500, 'min_child_weight': 7, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 0, 'early_stopping_rounds': 10, 'colsample_bytree': 0.8}
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.462197 |     0.405405 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.352554 |     0.269902 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.462197 |     0.201203 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.239153 |     0.200358 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.840726 |     0.766048 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.846147 |      0.77405 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [변수 중요도]
# +------------------------------------------------+---------+-------------+----------+
# |                                                |   score |        rate |   cumsum |
# |------------------------------------------------+---------+-------------+----------|
# | 총_공사기간                                    |   57365 |    0.248958 | 0.248958 |
# | 공정률                                         |   26156 |    0.113514 | 0.362473 |
# | 장소_중분류_내부                               |    7173 |   0.0311301 | 0.393603 |
# | 전체공사비_분류                                |    7087 |   0.0307569 |  0.42436 |
# | 사고원인_주원인_작업자 부주의                  |    7015 |   0.0304444 | 0.454804 |
# | 보호(방호)조치여부 - 안전방호                  |    6788 |   0.0294592 | 0.484264 |
# | 장소_중분류_외부                               |    6518 |   0.0282875 | 0.512551 |
# | 공종_중분류_철근콘크리트공사                   |    5346 |   0.0232011 | 0.535752 |
# | 공종_대분류_토목                               |    4726 |   0.0205104 | 0.556262 |
# | 장소_대분류_공동주택                           |    4359 |   0.0189176 |  0.57518 |
# | 보호(방호)조치여부 - 개인방호                  |    3408 |   0.0147904 |  0.58997 |
# | 작업프로세스_기타                              |    3356 |   0.0145647 | 0.604535 |
# | 사고원인_주원인_기타                           |    3263 |   0.0141611 | 0.618696 |
# | 요일_화요일                                    |    3214 |   0.0139484 | 0.632645 |
# | 요일_목요일                                    |    2859 |   0.0124078 | 0.645053 |
# | 공휴일여부_휴일                                |    2667 |   0.0115745 | 0.656627 |
# | 작업프로세스_설치작업                          |    2626 |   0.0113966 | 0.668024 |
# | 요일_수요일                                    |    2583 |     0.01121 | 0.679234 |
# | 요일_월요일                                    |    2555 |   0.0110884 | 0.690322 |
# | 작업프로세스_운반작업                          |    2443 |   0.0106024 | 0.700924 |
# | 공종_대분류_기타                               |    2428 |   0.0105373 | 0.711462 |
# | 작업프로세스_절단작업                          |    2313 |   0.0100382 |   0.7215 |
# | 작업프로세스_해체작업                          |    2170 |  0.00941759 | 0.730917 |
# | 작업프로세스_이동                              |    2089 |  0.00906605 | 0.739984 |
# | 사고원인_주원인_작업자의 불안전한 행동         |    2087 |  0.00905737 | 0.749041 |
# | 장소_대분류_기타                               |    2003 |  0.00869282 | 0.757734 |
# | 장소_중분류_인접주변                           |    1788 |  0.00775974 | 0.765493 |
# | 요일_토요일                                    |    1693 |  0.00734745 | 0.772841 |
# | 작업프로세스_정리작업                          |    1584 |   0.0068744 | 0.779715 |
# | 공종_중분류_토공사                             |    1505 |  0.00653155 | 0.786247 |
# | 장소_대분류_업무시설                           |    1451 |   0.0062972 | 0.792544 |
# | 장소_대분류_공장                               |    1443 |  0.00626248 | 0.798807 |
# | 작업프로세스_마감작업                          |    1434 |  0.00622342 |  0.80503 |
# | 사고원인_주원인_개인 안전보호구 착용 불량      |    1418 |  0.00615398 | 0.811184 |
# | 사고원인_주원인_운전자 자격관리 미흡           |    1342 |  0.00582415 | 0.817008 |
# | 공종_중분류_기타                               |    1318 |  0.00571999 | 0.822728 |
# | 작업프로세스_조립작업                          |    1270 |  0.00551167 |  0.82824 |
# | 작업프로세스_타설작업                          |    1267 |  0.00549865 | 0.833738 |
# | 작업프로세스_형틀 및 목공                      |    1228 |   0.0053294 | 0.839068 |
# | 공종_중분류_해체 및 철거공사                   |    1164 |  0.00505164 | 0.844119 |
# | 장소_대분류_도로                               |    1159 |  0.00502995 | 0.849149 |
# | 사고원인_주원인_작업자 통제 미흡               |    1127 |  0.00489107 |  0.85404 |
# | 장소_대분류_교육연구시설                       |    1081 |  0.00469143 | 0.858732 |
# | 요일_일요일                                    |    1072 |  0.00465237 | 0.863384 |
# | 공종_중분류_도로 및 포장공사                   |    1060 |   0.0046003 | 0.867985 |
# | 공종_중분류_관공사                             |    1054 |  0.00457426 | 0.872559 |
# | 사고원인_주원인_작업순서 미준수                |    1048 |  0.00454822 | 0.877107 |
# | 사고원인_주원인_위험정보 미제공                |     942 |  0.00408819 | 0.881195 |
# | 장소_대분류_근린생활시설                       |     882 |  0.00382779 | 0.885023 |
# | 공종_중분류_기계설비공사                       |     858 |  0.00372364 | 0.888747 |
# | 작업프로세스_전기작업                          |     834 |  0.00361948 | 0.892366 |
# | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 |     831 |  0.00360646 | 0.895973 |
# | 장소_대분류_창고시설                           |     810 |  0.00351532 | 0.899488 |
# | 사고원인_주원인_시공품질 미확보                |     807 |   0.0035023 |  0.90299 |
# | 공종_중분류_미장공사                           |     795 |  0.00345022 |  0.90644 |
# | 작업프로세스_용접작업                          |     791 |  0.00343286 | 0.909873 |
# | 작업프로세스_준비작업                          |     788 |  0.00341984 | 0.913293 |
# | 작업프로세스_벌목작업                          |     755 |  0.00327663 |  0.91657 |
# | 공종_중분류_수장공사                           |     755 |  0.00327663 | 0.919846 |
# | 공종_중분류_전기설비공사                       |     701 |  0.00304227 | 0.922889 |
# | 작업프로세스_굴착작업                          |     694 |  0.00301189 | 0.925901 |
# | 공종_중분류_건축 토공사                        |     667 |  0.00289471 | 0.928795 |
# | 작업프로세스_양중작업                          |     599 |   0.0025996 | 0.931395 |
# | 작업프로세스_도장작업                          |     571 |  0.00247808 | 0.933873 |
# | 장소_중분류_외벽                               |     562 |  0.00243902 | 0.936312 |
# | 작업프로세스_상차 및 하역작업                  |     558 |  0.00242166 | 0.938734 |
# | 장소_대분류_하수도                             |     530 |  0.00230015 | 0.941034 |
# | 공종_중분류_철골공사                           |     528 |  0.00229147 | 0.943325 |
# | 작업프로세스_설비작업                          |     527 |  0.00228713 | 0.945612 |
# | 사고원인_주원인_작업자 건강상태 확인 미흡      |     526 |  0.00228279 | 0.947895 |
# | 공종_중분류_타일 및 돌공사                     |     503 |  0.00218297 | 0.950078 |
# | 장소_대분류_부지조성                           |     476 |  0.00206579 | 0.952144 |
# | 장소_대분류_상수도                             |     457 |  0.00198333 | 0.954127 |
# | 공종_대분류_기계설비                           |     448 |  0.00194428 | 0.956072 |
# | 작업프로세스_인양작업                          |     437 |  0.00189654 | 0.957968 |
# | 공종_중분류_건축물 부대공사                    |     433 |  0.00187918 | 0.959847 |
# | 공종_중분류_도장공사                           |     429 |  0.00186182 | 0.961709 |
# | 공종_중분류_금속공사                           |     406 |    0.001762 | 0.963471 |
# | 공종_중분류_목공사                             |     389 |  0.00168822 | 0.965159 |
# | 작업프로세스_매설작업                          |     387 |  0.00167954 | 0.966839 |
# | 작업프로세스_연결작업                          |     382 |  0.00165784 | 0.968497 |
# | 장소_중분류_지붕                               |     356 |    0.001545 | 0.970042 |
# | 공종_중분류_창호 및 유리공사                   |     326 |  0.00141481 | 0.971456 |
# | 장소_대분류_문화및집회시설                     |     326 |  0.00141481 | 0.972871 |
# | 공종_중분류_교량공사                           |     320 |  0.00138877 |  0.97426 |
# | 작업프로세스_천공작업                          |     284 |  0.00123253 | 0.975493 |
# | 장소_대분류_도로교량                           |     279 |  0.00121083 | 0.976703 |
# | 사고원인_주원인_안전관리계획 수립 미흡         |     273 |  0.00118479 | 0.977888 |
# | 공종_중분류_산업설비공사                       |     267 |  0.00115875 | 0.979047 |
# | 사고원인_주원인_시방기준 등 미준수             |     250 |  0.00108498 | 0.980132 |
# | 사고원인_주원인_시공관리 미흡                  |     242 |  0.00105026 | 0.981182 |
# | 작업프로세스_항타 및 항발작업                  |     240 |  0.00104158 | 0.982224 |
# | 사고원인_주원인_사다리 사용수칙 미준수         |     240 |  0.00104158 | 0.983265 |
# | 사고원인_주원인_안전발판 설치 미흡             |     237 |  0.00102856 | 0.984294 |
# | 공종_중분류_터널공사                           |     229 | 0.000993837 | 0.985288 |
# | 공종_중분류_조적공사                           |     197 | 0.000854961 | 0.986143 |
# | 사고원인_주원인_기계장비 불안전한 거치         |     180 | 0.000781182 | 0.986924 |
# | 작업프로세스_청소작업                          |     176 | 0.000763823 | 0.987688 |
# | 공종_중분류_방수공사                           |     175 | 0.000759483 | 0.988447 |
# | 작업프로세스_보수 및 교체작업                  |     170 | 0.000737783 | 0.989185 |
# | 사고원인_주원인_적정 공법검토 미흡             |     164 | 0.000711744 | 0.989897 |
# | 공종_중분류_말뚝공사                           |     149 | 0.000646645 | 0.990543 |
# | 공종_중분류_관공사 부대공사                    |     146 | 0.000633626 | 0.991177 |
# | 사고원인_주원인_사전 설계도서검토 미흡         |     141 | 0.000611926 | 0.991789 |
# | 작업프로세스_부설 및 다짐작업                  |     130 | 0.000564187 | 0.992353 |
# | 장소_대분류_석유화학공장                       |     119 | 0.000516448 |  0.99287 |
# | 장소_대분류_노유자시설                         |     119 | 0.000516448 | 0.993386 |
# | 사고원인_주원인_작업전 점검 미흡               |     113 | 0.000490409 | 0.993876 |
# | 장소_대분류_의료시설                           |     104 |  0.00045135 | 0.994328 |
# | 작업프로세스_확인 및 점검작업                  |     102 |  0.00044267 |  0.99477 |
# | 공종_중분류_철도 및 궤도공사                   |      98 |  0.00042531 | 0.995196 |
# | 장소_대분류_운수시설                           |      95 | 0.000412291 | 0.995608 |
# | 공종_중분류_지붕 및 홈통공사                   |      92 | 0.000399271 | 0.996007 |
# | 장소_대분류_단독주택                           |      87 | 0.000377571 | 0.996385 |
# | 작업프로세스_쌓기작업                          |      83 | 0.000360212 | 0.996745 |
# | 사고원인_주원인_불량자재 관리 미흡             |      83 | 0.000360212 | 0.997105 |
# | 사고원인_주원인_구조안전 미확보                |      81 | 0.000351532 | 0.997457 |
# | 장소_대분류_자동차관련시설                     |      78 | 0.000338512 | 0.997795 |
# | 작업프로세스_적재작업                          |      78 | 0.000338512 | 0.998134 |
# | 작업프로세스_정비작업                          |      52 | 0.000225675 |  0.99836 |
# | 공종_중분류_하천공사                           |      51 | 0.000221335 | 0.998581 |
# | 장소_대분류_운동시설                           |      50 | 0.000216995 | 0.998798 |
# | 장소_대분류_숙박시설                           |      50 | 0.000216995 | 0.999015 |
# | 공종_중분류_지정공사                           |      39 | 0.000169256 | 0.999184 |
# | 장소_대분류_종교시설                           |      38 | 0.000164916 | 0.999349 |
# | 장소_대분류_도로터널                           |      34 | 0.000147557 | 0.999497 |
# | 장소_대분류_철도터널                           |      30 | 0.000130197 | 0.999627 |
# | 사고원인_주원인_계측데이터 관리 미흡           |      26 | 0.000112837 |  0.99974 |
# | 사고원인_주원인_품질관리 미흡                  |      21 | 9.11379e-05 | 0.999831 |
# | 사고원인_주원인_지반조사 미흡                  |      16 | 6.94384e-05 |   0.9999 |
# | 장소_대분류_지하철                             |       8 | 3.47192e-05 | 0.999935 |
# | 장소_대분류_일반및고속철도                     |       4 | 1.73596e-05 | 0.999952 |
# | 사고원인_주원인_구조계산 오류                  |       3 | 1.30197e-05 | 0.999965 |
# | 장소_대분류_판매시설                           |       2 |  8.6798e-06 | 0.999974 |
# | 장소_대분류_관개수로                           |       2 |  8.6798e-06 | 0.999983 |
# | 사고원인_주원인_설치·해체과정 관리 미흡        |       1 |  4.3399e-06 | 0.999987 |
# | 공종_중분류_강구조물공사                       |       1 |  4.3399e-06 | 0.999991 |
# | 장소_대분류_제방(통관/호안)                    |       1 |  4.3399e-06 | 0.999996 |
# | 장소_대분류_옹벽                               |       1 |  4.3399e-06 |        1 |
# +------------------------------------------------+---------+-------------+----------+
#
# [Roc Curve]
# +-----+------------+---------+------------------------------------------------+---------+
# |     | 종속변수   |   CLASS | 독립변수                                       |     VIF |
# |-----+------------+---------+------------------------------------------------+---------|
# |  41 | 인적사고   |       0 | 공종_중분류_특수 건축물공사                    | 1.04326 |
# |  30 | 인적사고   |       0 | 공종_중분류_지반조사                           | 1.05378 |
# |  42 | 인적사고   |       0 | 공종_중분류_프리캐스트 콘크리트공사            | 1.06468 |
# |   8 | 인적사고   |       0 | 공종_중분류_강구조물공사                       | 1.07287 |
# |  32 | 인적사고   |       0 | 공종_중분류_지정공사                           | 1.07412 |
# |  17 | 인적사고   |       0 | 공종_중분류_댐 및 제방공사                     | 1.09613 |
# |  27 | 인적사고   |       0 | 공종_중분류_조경공사                           | 1.10171 |
# |  29 | 인적사고   |       0 | 공종_중분류_지반개량공사                       | 1.10594 |
# |  33 | 인적사고   |       0 | 공종_중분류_창호 및 유리공사                   | 1.17427 |
# |  21 | 인적사고   |       0 | 공종_중분류_목공사                             | 1.18745 |
# |  23 | 인적사고   |       0 | 공종_중분류_방수공사                           | 1.19683 |
# |  14 | 인적사고   |       0 | 공종_중분류_금속공사                           | 1.21667 |
# |  12 | 인적사고   |       0 | 공종_중분류_관공사 부대공사                    | 1.22249 |
# | 123 | 인적사고   |       0 | 장소_중분류_외벽                               | 1.23307 |
# |  40 | 인적사고   |       0 | 공종_중분류_통신설비공사                       | 1.25359 |
# |  28 | 인적사고   |       0 | 공종_중분류_조적공사                           | 1.29341 |
# |  31 | 인적사고   |       0 | 공종_중분류_지붕 및 홈통공사                   | 1.29846 |
# |  20 | 인적사고   |       0 | 공종_중분류_말뚝공사                           | 1.31985 |
# | 126 | 인적사고   |       0 | 장소_중분류_지붕                               | 1.32436 |
# |  37 | 인적사고   |       0 | 공종_중분류_타일 및 돌공사                     | 1.34123 |
# |   9 | 인적사고   |       0 | 공종_중분류_건축 토공사                        | 1.38534 |
# | 153 | 인적사고   |       0 | 사고원인_주원인_지반조사 미흡                  | 1.42398 |
# |  10 | 인적사고   |       0 | 공종_중분류_건축물 부대공사                    | 1.43996 |
# |  25 | 인적사고   |       0 | 공종_중분류_수장공사                           |  1.4412 |
# | 125 | 인적사고   |       0 | 장소_중분류_인접주변                           | 1.44493 |
# |  34 | 인적사고   |       0 | 공종_중분류_철골공사                           | 1.48635 |
# |  18 | 인적사고   |       0 | 공종_중분류_도로 및 포장공사                   | 1.50442 |
# | 129 | 인적사고   |       0 | 사고원인_주원인_구조계산 오류                  | 1.53872 |
# | 113 | 인적사고   |       0 | 장소_대분류_절토사면                           | 1.56851 |
# | 136 | 인적사고   |       0 | 사고원인_주원인_사다리 사용수칙 미준수         | 1.57815 |
# |  43 | 인적사고   |       0 | 공종_중분류_하천공사                           | 1.60139 |
# |  22 | 인적사고   |       0 | 공종_중분류_미장공사                           | 1.64203 |
# |  36 | 인적사고   |       0 | 공종_중분류_철도 및 궤도공사                   | 1.64494 |
# |  72 | 인적사고   |       0 | 작업프로세스_적재작업                          | 1.64979 |
# |  44 | 인적사고   |       0 | 공종_중분류_항만공사                           | 1.66414 |
# |  13 | 인적사고   |       0 | 공종_중분류_교량공사                           | 1.66584 |
# | 138 | 인적사고   |       0 | 사고원인_주원인_설치·해체과정 관리 미흡        | 1.68144 |
# |  45 | 인적사고   |       0 | 공종_중분류_해체 및 철거공사                   | 1.68218 |
# | 152 | 인적사고   |       0 | 사고원인_주원인_적정 공법검토 미흡             | 1.69379 |
# |  99 | 인적사고   |       0 | 장소_대분류_방송통신시설                       |  1.7007 |
# | 109 | 인적사고   |       0 | 장소_대분류_위험물저장및처리시설               | 1.72396 |
# | 143 | 인적사고   |       0 | 사고원인_주원인_안전발판 설치 미흡             | 1.73919 |
# | 133 | 인적사고   |       0 | 사고원인_주원인_단독작업                       | 1.77207 |
# |  76 | 인적사고   |       0 | 작업프로세스_정비작업                          | 1.77474 |
# | 154 | 인적사고   |       0 | 사고원인_주원인_품질관리 미흡                  | 1.79126 |
# |  88 | 인적사고   |       0 | 장소_대분류_관개수로                           | 1.83416 |
# |  39 | 인적사고   |       0 | 공종_중분류_토공사                             | 1.93731 |
# |  19 | 인적사고   |       0 | 공종_중분류_도장공사                           |    1.95 |
# |  46 | 인적사고   |       0 | 요일_목요일                                    | 1.99319 |
# |  11 | 인적사고   |       0 | 공종_중분류_관공사                             | 1.99322 |
# |  47 | 인적사고   |       0 | 요일_수요일                                    | 1.99927 |
# | 131 | 인적사고   |       0 | 사고원인_주원인_기계장비 불안전한 거치         | 2.01343 |
# |  51 | 인적사고   |       0 | 요일_화요일                                    | 2.02196 |
# | 130 | 인적사고   |       0 | 사고원인_주원인_구조안전 미확보                | 2.03508 |
# |  59 | 인적사고   |       0 | 작업프로세스_벌목작업                          | 2.04154 |
# | 151 | 인적사고   |       0 | 사고원인_주원인_작업전 점검 미흡               | 2.06417 |
# | 121 | 인적사고   |       0 | 장소_대분류_하수처리시설                       | 2.07855 |
# |  48 | 인적사고   |       0 | 요일_월요일                                    | 2.08343 |
# | 128 | 인적사고   |       0 | 사고원인_주원인_계측데이터 관리 미흡           | 2.08955 |
# |  61 | 인적사고   |       0 | 작업프로세스_부설 및 다짐작업                  | 2.18764 |
# |  79 | 인적사고   |       0 | 작업프로세스_천공작업                          | 2.18768 |
# | 135 | 인적사고   |       0 | 사고원인_주원인_불량자재 관리 미흡             | 2.19976 |
# |  58 | 인적사고   |       0 | 작업프로세스_반출작업                          | 2.20132 |
# | 106 | 인적사고   |       0 | 장소_대분류_옹벽                               | 2.21157 |
# | 147 | 인적사고   |       0 | 사고원인_주원인_작업자 건강상태 확인 미흡      | 2.24966 |
# |  82 | 인적사고   |       0 | 작업프로세스_항타 및 항발작업                  | 2.26181 |
# |  38 | 인적사고   |       0 | 공종_중분류_터널공사                           | 2.26343 |
# | 100 | 인적사고   |       0 | 장소_대분류_방파제                             | 2.28284 |
# | 142 | 인적사고   |       0 | 사고원인_주원인_안전관리계획 수립 미흡         | 2.32984 |
# |  57 | 인적사고   |       0 | 작업프로세스_매설작업                          | 2.38335 |
# |  60 | 인적사고   |       0 | 작업프로세스_보수 및 교체작업                  | 2.39616 |
# |  85 | 인적사고   |       0 | 작업프로세스_확인 및 점검작업                  | 2.59983 |
# | 111 | 인적사고   |       0 | 장소_대분류_일반및고속철도                     | 2.60744 |
# | 114 | 인적사고   |       0 | 장소_대분류_제방(통관/호안)                    | 2.64343 |
# |  73 | 인적사고   |       0 | 작업프로세스_전기작업                          | 2.65369 |
# |  62 | 인적사고   |       0 | 작업프로세스_상차 및 하역작업                  | 2.67496 |
# | 137 | 인적사고   |       0 | 사고원인_주원인_사전 설계도서검토 미흡         | 2.74473 |
# |  65 | 인적사고   |       0 | 작업프로세스_쌓기작업                          | 2.80648 |
# | 127 | 인적사고   |       0 | 사고원인_주원인_개인 안전보호구 착용 불량      | 2.87839 |
# |  66 | 인적사고   |       0 | 작업프로세스_양중작업                          |  2.8908 |
# | 108 | 인적사고   |       0 | 장소_대분류_운수시설                           | 2.89587 |
# | 115 | 인적사고   |       0 | 장소_대분류_종교시설                           |  3.0624 |
# | 119 | 인적사고   |       0 | 장소_대분류_판매시설                           | 3.09739 |
# | 134 | 인적사고   |       0 | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 | 3.09792 |
# |  93 | 인적사고   |       0 | 장소_대분류_노유자시설                         | 3.16735 |
# | 116 | 인적사고   |       0 | 장소_대분류_지하철                             | 3.22124 |
# | 110 | 인적사고   |       0 | 장소_대분류_의료시설                           | 3.25241 |
# |  67 | 인적사고   |       0 | 작업프로세스_연결작업                          | 3.27874 |
# | 124 | 인적사고   |       0 | 장소_중분류_외부                               | 3.34006 |
# |  90 | 인적사고   |       0 | 장소_대분류_교정및군사시설                     |  3.3561 |
# | 103 | 인적사고   |       0 | 장소_대분류_석유화학공장                       | 3.35787 |
# |  68 | 인적사고   |       0 | 작업프로세스_용접작업                          | 3.41276 |
# | 112 | 인적사고   |       0 | 장소_대분류_자동차관련시설                     | 3.41842 |
# | 141 | 인적사고   |       0 | 사고원인_주원인_시방기준 등 미준수             | 3.47549 |
# |  71 | 인적사고   |       0 | 작업프로세스_인양작업                          | 3.50548 |
# |  97 | 인적사고   |       0 | 장소_대분류_도로터널                           | 3.53918 |
# |  53 | 인적사고   |       0 | 작업프로세스_굴착작업                          |   3.583 |
# |  49 | 인적사고   |       0 | 요일_일요일                                    | 3.76327 |
# | 118 | 인적사고   |       0 | 장소_대분류_철도터널                           | 3.81884 |
# |  80 | 인적사고   |       0 | 작업프로세스_청소작업                          |  3.8191 |
# | 140 | 인적사고   |       0 | 사고원인_주원인_시공품질 미확보                | 3.93221 |
# | 107 | 인적사고   |       0 | 장소_대분류_운동시설                           | 3.96842 |
# |  63 | 인적사고   |       0 | 작업프로세스_설비작업                          | 4.13545 |
# |   0 | 인적사고   |       0 | 총_공사기간                                    | 4.40619 |
# |  55 | 인적사고   |       0 | 작업프로세스_도장작업                          | 4.49597 |
# |  35 | 인적사고   |       0 | 공종_중분류_철근콘크리트공사                   | 4.55634 |
# | 139 | 인적사고   |       0 | 사고원인_주원인_시공관리 미흡                  |  4.6875 |
# | 144 | 인적사고   |       0 | 사고원인_주원인_운전자 자격관리 미흡           | 4.71284 |
# |   1 | 인적사고   |       0 | 공정률                                         | 4.88641 |
# | 122 | 인적사고   |       0 | 장소_중분류_내부                               | 5.30451 |
# |  94 | 인적사고   |       0 | 장소_대분류_단독주택                           | 5.63958 |
# | 102 | 인적사고   |       0 | 장소_대분류_상수도                             | 5.75755 |
# | 146 | 인적사고   |       0 | 사고원인_주원인_작업순서 미준수                | 5.90232 |
# | 104 | 인적사고   |       0 | 장소_대분류_숙박시설                           | 6.09686 |
# |  96 | 인적사고   |       0 | 장소_대분류_도로교량                           | 6.12281 |
# | 145 | 인적사고   |       0 | 사고원인_주원인_위험정보 미제공                | 6.17172 |
# |   7 | 인적사고   |       0 | 공종_대분류_토목                               | 6.34885 |
# |  78 | 인적사고   |       0 | 작업프로세스_준비작업                          | 6.63542 |
# |  98 | 인적사고   |       0 | 장소_대분류_문화및집회시설                     | 6.65736 |
# | 149 | 인적사고   |       0 | 사고원인_주원인_작업자 통제 미흡               | 6.83298 |
# | 101 | 인적사고   |       0 | 장소_대분류_부지조성                           | 7.01587 |
# |  74 | 인적사고   |       0 | 작업프로세스_절단작업                          |  7.0938 |
# |  81 | 인적사고   |       0 | 작업프로세스_타설작업                          |  7.2196 |
# |  24 | 인적사고   |       0 | 공종_중분류_산업설비공사                       | 7.73351 |
# | 120 | 인적사고   |       0 | 장소_대분류_하수도                             | 9.18902 |
# |  50 | 인적사고   |       0 | 요일_토요일                                    |  9.3357 |
# |  56 | 인적사고   |       0 | 작업프로세스_마감작업                          | 9.43312 |
# |  84 | 인적사고   |       0 | 작업프로세스_형틀 및 목공                      | 10.3601 |
# |  52 | 인적사고   |       0 | 공휴일여부_휴일                                | 11.2644 |
# | 117 | 인적사고   |       0 | 장소_대분류_창고시설                           | 11.6269 |
# |  26 | 인적사고   |       0 | 공종_중분류_전기설비공사                       | 12.2957 |
# |  77 | 인적사고   |       0 | 작업프로세스_조립작업                          | 12.4549 |
# |  95 | 인적사고   |       0 | 장소_대분류_도로                               | 13.6835 |
# |  75 | 인적사고   |       0 | 작업프로세스_정리작업                          | 14.9634 |
# | 150 | 인적사고   |       0 | 사고원인_주원인_작업자의 불안전한 행동         | 16.4008 |
# |  54 | 인적사고   |       0 | 작업프로세스_기타                              | 18.1458 |
# |  91 | 인적사고   |       0 | 장소_대분류_근린생활시설                       | 19.2283 |
# |   2 | 인적사고   |       0 | 전체공사비_분류                                | 19.5044 |
# |  89 | 인적사고   |       0 | 장소_대분류_교육연구시설                       | 19.8293 |
# |  69 | 인적사고   |       0 | 작업프로세스_운반작업                          | 20.4558 |
# |   3 | 인적사고   |       0 | 보호(방호)조치여부 - 안전방호                  | 20.6888 |
# |   4 | 인적사고   |       0 | 보호(방호)조치여부 - 개인방호                  | 22.1378 |
# |  70 | 인적사고   |       0 | 작업프로세스_이동                              | 24.1215 |
# |  83 | 인적사고   |       0 | 작업프로세스_해체작업                          | 24.1914 |
# | 132 | 인적사고   |       0 | 사고원인_주원인_기타                           | 24.2497 |
# | 105 | 인적사고   |       0 | 장소_대분류_업무시설                           | 25.8684 |
# |  87 | 인적사고   |       0 | 장소_대분류_공장                               | 26.5615 |
# |  92 | 인적사고   |       0 | 장소_대분류_기타                               | 34.0331 |
# |  15 | 인적사고   |       0 | 공종_중분류_기계설비공사                       | 34.9034 |
# |   5 | 인적사고   |       0 | 공종_대분류_기계설비                           | 35.1965 |
# |  64 | 인적사고   |       0 | 작업프로세스_설치작업                          | 40.0056 |
# |  16 | 인적사고   |       0 | 공종_중분류_기타                               |  48.485 |
# |   6 | 인적사고   |       0 | 공종_대분류_기타                               | 67.9927 |
# |  86 | 인적사고   |       0 | 장소_대분류_공동주택                           | 93.6798 |
# | 148 | 인적사고   |       0 | 사고원인_주원인_작업자 부주의                  | 103.184 |
# +-----+------------+---------+------------------------------------------------+---------+
# +-----+------------+---------+------------------------------------------------+---------+
# |     | 종속변수   |   CLASS | 독립변수                                       |     VIF |
# |-----+------------+---------+------------------------------------------------+---------|
# |  41 | 인적사고   |       1 | 공종_중분류_특수 건축물공사                    | 1.04326 |
# |  30 | 인적사고   |       1 | 공종_중분류_지반조사                           | 1.05378 |
# |  42 | 인적사고   |       1 | 공종_중분류_프리캐스트 콘크리트공사            | 1.06468 |
# |   8 | 인적사고   |       1 | 공종_중분류_강구조물공사                       | 1.07287 |
# |  32 | 인적사고   |       1 | 공종_중분류_지정공사                           | 1.07412 |
# |  17 | 인적사고   |       1 | 공종_중분류_댐 및 제방공사                     | 1.09613 |
# |  27 | 인적사고   |       1 | 공종_중분류_조경공사                           | 1.10171 |
# |  29 | 인적사고   |       1 | 공종_중분류_지반개량공사                       | 1.10594 |
# |  33 | 인적사고   |       1 | 공종_중분류_창호 및 유리공사                   | 1.17427 |
# |  21 | 인적사고   |       1 | 공종_중분류_목공사                             | 1.18745 |
# |  23 | 인적사고   |       1 | 공종_중분류_방수공사                           | 1.19683 |
# |  14 | 인적사고   |       1 | 공종_중분류_금속공사                           | 1.21667 |
# |  12 | 인적사고   |       1 | 공종_중분류_관공사 부대공사                    | 1.22249 |
# | 123 | 인적사고   |       1 | 장소_중분류_외벽                               | 1.23307 |
# |  40 | 인적사고   |       1 | 공종_중분류_통신설비공사                       | 1.25359 |
# |  28 | 인적사고   |       1 | 공종_중분류_조적공사                           | 1.29341 |
# |  31 | 인적사고   |       1 | 공종_중분류_지붕 및 홈통공사                   | 1.29846 |
# |  20 | 인적사고   |       1 | 공종_중분류_말뚝공사                           | 1.31985 |
# | 126 | 인적사고   |       1 | 장소_중분류_지붕                               | 1.32436 |
# |  37 | 인적사고   |       1 | 공종_중분류_타일 및 돌공사                     | 1.34123 |
# |   9 | 인적사고   |       1 | 공종_중분류_건축 토공사                        | 1.38534 |
# | 153 | 인적사고   |       1 | 사고원인_주원인_지반조사 미흡                  | 1.42398 |
# |  10 | 인적사고   |       1 | 공종_중분류_건축물 부대공사                    | 1.43996 |
# |  25 | 인적사고   |       1 | 공종_중분류_수장공사                           |  1.4412 |
# | 125 | 인적사고   |       1 | 장소_중분류_인접주변                           | 1.44493 |
# |  34 | 인적사고   |       1 | 공종_중분류_철골공사                           | 1.48635 |
# |  18 | 인적사고   |       1 | 공종_중분류_도로 및 포장공사                   | 1.50442 |
# | 129 | 인적사고   |       1 | 사고원인_주원인_구조계산 오류                  | 1.53872 |
# | 113 | 인적사고   |       1 | 장소_대분류_절토사면                           | 1.56851 |
# | 136 | 인적사고   |       1 | 사고원인_주원인_사다리 사용수칙 미준수         | 1.57815 |
# |  43 | 인적사고   |       1 | 공종_중분류_하천공사                           | 1.60139 |
# |  22 | 인적사고   |       1 | 공종_중분류_미장공사                           | 1.64203 |
# |  36 | 인적사고   |       1 | 공종_중분류_철도 및 궤도공사                   | 1.64494 |
# |  72 | 인적사고   |       1 | 작업프로세스_적재작업                          | 1.64979 |
# |  44 | 인적사고   |       1 | 공종_중분류_항만공사                           | 1.66414 |
# |  13 | 인적사고   |       1 | 공종_중분류_교량공사                           | 1.66584 |
# | 138 | 인적사고   |       1 | 사고원인_주원인_설치·해체과정 관리 미흡        | 1.68144 |
# |  45 | 인적사고   |       1 | 공종_중분류_해체 및 철거공사                   | 1.68218 |
# | 152 | 인적사고   |       1 | 사고원인_주원인_적정 공법검토 미흡             | 1.69379 |
# |  99 | 인적사고   |       1 | 장소_대분류_방송통신시설                       |  1.7007 |
# | 109 | 인적사고   |       1 | 장소_대분류_위험물저장및처리시설               | 1.72396 |
# | 143 | 인적사고   |       1 | 사고원인_주원인_안전발판 설치 미흡             | 1.73919 |
# | 133 | 인적사고   |       1 | 사고원인_주원인_단독작업                       | 1.77207 |
# |  76 | 인적사고   |       1 | 작업프로세스_정비작업                          | 1.77474 |
# | 154 | 인적사고   |       1 | 사고원인_주원인_품질관리 미흡                  | 1.79126 |
# |  88 | 인적사고   |       1 | 장소_대분류_관개수로                           | 1.83416 |
# |  39 | 인적사고   |       1 | 공종_중분류_토공사                             | 1.93731 |
# |  19 | 인적사고   |       1 | 공종_중분류_도장공사                           |    1.95 |
# |  46 | 인적사고   |       1 | 요일_목요일                                    | 1.99319 |
# |  11 | 인적사고   |       1 | 공종_중분류_관공사                             | 1.99322 |
# |  47 | 인적사고   |       1 | 요일_수요일                                    | 1.99927 |
# | 131 | 인적사고   |       1 | 사고원인_주원인_기계장비 불안전한 거치         | 2.01343 |
# |  51 | 인적사고   |       1 | 요일_화요일                                    | 2.02196 |
# | 130 | 인적사고   |       1 | 사고원인_주원인_구조안전 미확보                | 2.03508 |
# |  59 | 인적사고   |       1 | 작업프로세스_벌목작업                          | 2.04154 |
# | 151 | 인적사고   |       1 | 사고원인_주원인_작업전 점검 미흡               | 2.06417 |
# | 121 | 인적사고   |       1 | 장소_대분류_하수처리시설                       | 2.07855 |
# |  48 | 인적사고   |       1 | 요일_월요일                                    | 2.08343 |
# | 128 | 인적사고   |       1 | 사고원인_주원인_계측데이터 관리 미흡           | 2.08955 |
# |  61 | 인적사고   |       1 | 작업프로세스_부설 및 다짐작업                  | 2.18764 |
# |  79 | 인적사고   |       1 | 작업프로세스_천공작업                          | 2.18768 |
# | 135 | 인적사고   |       1 | 사고원인_주원인_불량자재 관리 미흡             | 2.19976 |
# |  58 | 인적사고   |       1 | 작업프로세스_반출작업                          | 2.20132 |
# | 106 | 인적사고   |       1 | 장소_대분류_옹벽                               | 2.21157 |
# | 147 | 인적사고   |       1 | 사고원인_주원인_작업자 건강상태 확인 미흡      | 2.24966 |
# |  82 | 인적사고   |       1 | 작업프로세스_항타 및 항발작업                  | 2.26181 |
# |  38 | 인적사고   |       1 | 공종_중분류_터널공사                           | 2.26343 |
# | 100 | 인적사고   |       1 | 장소_대분류_방파제                             | 2.28284 |
# | 142 | 인적사고   |       1 | 사고원인_주원인_안전관리계획 수립 미흡         | 2.32984 |
# |  57 | 인적사고   |       1 | 작업프로세스_매설작업                          | 2.38335 |
# |  60 | 인적사고   |       1 | 작업프로세스_보수 및 교체작업                  | 2.39616 |
# |  85 | 인적사고   |       1 | 작업프로세스_확인 및 점검작업                  | 2.59983 |
# | 111 | 인적사고   |       1 | 장소_대분류_일반및고속철도                     | 2.60744 |
# | 114 | 인적사고   |       1 | 장소_대분류_제방(통관/호안)                    | 2.64343 |
# |  73 | 인적사고   |       1 | 작업프로세스_전기작업                          | 2.65369 |
# |  62 | 인적사고   |       1 | 작업프로세스_상차 및 하역작업                  | 2.67496 |
# | 137 | 인적사고   |       1 | 사고원인_주원인_사전 설계도서검토 미흡         | 2.74473 |
# |  65 | 인적사고   |       1 | 작업프로세스_쌓기작업                          | 2.80648 |
# | 127 | 인적사고   |       1 | 사고원인_주원인_개인 안전보호구 착용 불량      | 2.87839 |
# |  66 | 인적사고   |       1 | 작업프로세스_양중작업                          |  2.8908 |
# | 108 | 인적사고   |       1 | 장소_대분류_운수시설                           | 2.89587 |
# | 115 | 인적사고   |       1 | 장소_대분류_종교시설                           |  3.0624 |
# | 119 | 인적사고   |       1 | 장소_대분류_판매시설                           | 3.09739 |
# | 134 | 인적사고   |       1 | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 | 3.09792 |
# |  93 | 인적사고   |       1 | 장소_대분류_노유자시설                         | 3.16735 |
# | 116 | 인적사고   |       1 | 장소_대분류_지하철                             | 3.22124 |
# | 110 | 인적사고   |       1 | 장소_대분류_의료시설                           | 3.25241 |
# |  67 | 인적사고   |       1 | 작업프로세스_연결작업                          | 3.27874 |
# | 124 | 인적사고   |       1 | 장소_중분류_외부                               | 3.34006 |
# |  90 | 인적사고   |       1 | 장소_대분류_교정및군사시설                     |  3.3561 |
# | 103 | 인적사고   |       1 | 장소_대분류_석유화학공장                       | 3.35787 |
# |  68 | 인적사고   |       1 | 작업프로세스_용접작업                          | 3.41276 |
# | 112 | 인적사고   |       1 | 장소_대분류_자동차관련시설                     | 3.41842 |
# | 141 | 인적사고   |       1 | 사고원인_주원인_시방기준 등 미준수             | 3.47549 |
# |  71 | 인적사고   |       1 | 작업프로세스_인양작업                          | 3.50548 |
# |  97 | 인적사고   |       1 | 장소_대분류_도로터널                           | 3.53918 |
# |  53 | 인적사고   |       1 | 작업프로세스_굴착작업                          |   3.583 |
# |  49 | 인적사고   |       1 | 요일_일요일                                    | 3.76327 |
# | 118 | 인적사고   |       1 | 장소_대분류_철도터널                           | 3.81884 |
# |  80 | 인적사고   |       1 | 작업프로세스_청소작업                          |  3.8191 |
# | 140 | 인적사고   |       1 | 사고원인_주원인_시공품질 미확보                | 3.93221 |
# | 107 | 인적사고   |       1 | 장소_대분류_운동시설                           | 3.96842 |
# |  63 | 인적사고   |       1 | 작업프로세스_설비작업                          | 4.13545 |
# |   0 | 인적사고   |       1 | 총_공사기간                                    | 4.40619 |
# |  55 | 인적사고   |       1 | 작업프로세스_도장작업                          | 4.49597 |
# |  35 | 인적사고   |       1 | 공종_중분류_철근콘크리트공사                   | 4.55634 |
# | 139 | 인적사고   |       1 | 사고원인_주원인_시공관리 미흡                  |  4.6875 |
# | 144 | 인적사고   |       1 | 사고원인_주원인_운전자 자격관리 미흡           | 4.71284 |
# |   1 | 인적사고   |       1 | 공정률                                         | 4.88641 |
# | 122 | 인적사고   |       1 | 장소_중분류_내부                               | 5.30451 |
# |  94 | 인적사고   |       1 | 장소_대분류_단독주택                           | 5.63958 |
# | 102 | 인적사고   |       1 | 장소_대분류_상수도                             | 5.75755 |
# | 146 | 인적사고   |       1 | 사고원인_주원인_작업순서 미준수                | 5.90232 |
# | 104 | 인적사고   |       1 | 장소_대분류_숙박시설                           | 6.09686 |
# |  96 | 인적사고   |       1 | 장소_대분류_도로교량                           | 6.12281 |
# | 145 | 인적사고   |       1 | 사고원인_주원인_위험정보 미제공                | 6.17172 |
# |   7 | 인적사고   |       1 | 공종_대분류_토목                               | 6.34885 |
# |  78 | 인적사고   |       1 | 작업프로세스_준비작업                          | 6.63542 |
# |  98 | 인적사고   |       1 | 장소_대분류_문화및집회시설                     | 6.65736 |
# | 149 | 인적사고   |       1 | 사고원인_주원인_작업자 통제 미흡               | 6.83298 |
# | 101 | 인적사고   |       1 | 장소_대분류_부지조성                           | 7.01587 |
# |  74 | 인적사고   |       1 | 작업프로세스_절단작업                          |  7.0938 |
# |  81 | 인적사고   |       1 | 작업프로세스_타설작업                          |  7.2196 |
# |  24 | 인적사고   |       1 | 공종_중분류_산업설비공사                       | 7.73351 |
# | 120 | 인적사고   |       1 | 장소_대분류_하수도                             | 9.18902 |
# |  50 | 인적사고   |       1 | 요일_토요일                                    |  9.3357 |
# |  56 | 인적사고   |       1 | 작업프로세스_마감작업                          | 9.43312 |
# |  84 | 인적사고   |       1 | 작업프로세스_형틀 및 목공                      | 10.3601 |
# |  52 | 인적사고   |       1 | 공휴일여부_휴일                                | 11.2644 |
# | 117 | 인적사고   |       1 | 장소_대분류_창고시설                           | 11.6269 |
# |  26 | 인적사고   |       1 | 공종_중분류_전기설비공사                       | 12.2957 |
# |  77 | 인적사고   |       1 | 작업프로세스_조립작업                          | 12.4549 |
# |  95 | 인적사고   |       1 | 장소_대분류_도로                               | 13.6835 |
# |  75 | 인적사고   |       1 | 작업프로세스_정리작업                          | 14.9634 |
# | 150 | 인적사고   |       1 | 사고원인_주원인_작업자의 불안전한 행동         | 16.4008 |
# |  54 | 인적사고   |       1 | 작업프로세스_기타                              | 18.1458 |
# |  91 | 인적사고   |       1 | 장소_대분류_근린생활시설                       | 19.2283 |
# |   2 | 인적사고   |       1 | 전체공사비_분류                                | 19.5044 |
# |  89 | 인적사고   |       1 | 장소_대분류_교육연구시설                       | 19.8293 |
# |  69 | 인적사고   |       1 | 작업프로세스_운반작업                          | 20.4558 |
# |   3 | 인적사고   |       1 | 보호(방호)조치여부 - 안전방호                  | 20.6888 |
# |   4 | 인적사고   |       1 | 보호(방호)조치여부 - 개인방호                  | 22.1378 |
# |  70 | 인적사고   |       1 | 작업프로세스_이동                              | 24.1215 |
# |  83 | 인적사고   |       1 | 작업프로세스_해체작업                          | 24.1914 |
# | 132 | 인적사고   |       1 | 사고원인_주원인_기타                           | 24.2497 |
# | 105 | 인적사고   |       1 | 장소_대분류_업무시설                           | 25.8684 |
# |  87 | 인적사고   |       1 | 장소_대분류_공장                               | 26.5615 |
# |  92 | 인적사고   |       1 | 장소_대분류_기타                               | 34.0331 |
# |  15 | 인적사고   |       1 | 공종_중분류_기계설비공사                       | 34.9034 |
# |   5 | 인적사고   |       1 | 공종_대분류_기계설비                           | 35.1965 |
# |  64 | 인적사고   |       1 | 작업프로세스_설치작업                          | 40.0056 |
# |  16 | 인적사고   |       1 | 공종_중분류_기타                               |  48.485 |
# |   6 | 인적사고   |       1 | 공종_대분류_기타                               | 67.9927 |
# |  86 | 인적사고   |       1 | 장소_대분류_공동주택                           | 93.6798 |
# | 148 | 인적사고   |       1 | 사고원인_주원인_작업자 부주의                  | 103.184 |
# +-----+------------+---------+------------------------------------------------+---------+
# +-----+------------+---------+------------------------------------------------+---------+
# |     | 종속변수   |   CLASS | 독립변수                                       |     VIF |
# |-----+------------+---------+------------------------------------------------+---------|
# |  41 | 인적사고   |       2 | 공종_중분류_특수 건축물공사                    | 1.04326 |
# |  30 | 인적사고   |       2 | 공종_중분류_지반조사                           | 1.05378 |
# |  42 | 인적사고   |       2 | 공종_중분류_프리캐스트 콘크리트공사            | 1.06468 |
# |   8 | 인적사고   |       2 | 공종_중분류_강구조물공사                       | 1.07287 |
# |  32 | 인적사고   |       2 | 공종_중분류_지정공사                           | 1.07412 |
# |  17 | 인적사고   |       2 | 공종_중분류_댐 및 제방공사                     | 1.09613 |
# |  27 | 인적사고   |       2 | 공종_중분류_조경공사                           | 1.10171 |
# |  29 | 인적사고   |       2 | 공종_중분류_지반개량공사                       | 1.10594 |
# |  33 | 인적사고   |       2 | 공종_중분류_창호 및 유리공사                   | 1.17427 |
# |  21 | 인적사고   |       2 | 공종_중분류_목공사                             | 1.18745 |
# |  23 | 인적사고   |       2 | 공종_중분류_방수공사                           | 1.19683 |
# |  14 | 인적사고   |       2 | 공종_중분류_금속공사                           | 1.21667 |
# |  12 | 인적사고   |       2 | 공종_중분류_관공사 부대공사                    | 1.22249 |
# | 123 | 인적사고   |       2 | 장소_중분류_외벽                               | 1.23307 |
# |  40 | 인적사고   |       2 | 공종_중분류_통신설비공사                       | 1.25359 |
# |  28 | 인적사고   |       2 | 공종_중분류_조적공사                           | 1.29341 |
# |  31 | 인적사고   |       2 | 공종_중분류_지붕 및 홈통공사                   | 1.29846 |
# |  20 | 인적사고   |       2 | 공종_중분류_말뚝공사                           | 1.31985 |
# | 126 | 인적사고   |       2 | 장소_중분류_지붕                               | 1.32436 |
# |  37 | 인적사고   |       2 | 공종_중분류_타일 및 돌공사                     | 1.34123 |
# |   9 | 인적사고   |       2 | 공종_중분류_건축 토공사                        | 1.38534 |
# | 153 | 인적사고   |       2 | 사고원인_주원인_지반조사 미흡                  | 1.42398 |
# |  10 | 인적사고   |       2 | 공종_중분류_건축물 부대공사                    | 1.43996 |
# |  25 | 인적사고   |       2 | 공종_중분류_수장공사                           |  1.4412 |
# | 125 | 인적사고   |       2 | 장소_중분류_인접주변                           | 1.44493 |
# |  34 | 인적사고   |       2 | 공종_중분류_철골공사                           | 1.48635 |
# |  18 | 인적사고   |       2 | 공종_중분류_도로 및 포장공사                   | 1.50442 |
# | 129 | 인적사고   |       2 | 사고원인_주원인_구조계산 오류                  | 1.53872 |
# | 113 | 인적사고   |       2 | 장소_대분류_절토사면                           | 1.56851 |
# | 136 | 인적사고   |       2 | 사고원인_주원인_사다리 사용수칙 미준수         | 1.57815 |
# |  43 | 인적사고   |       2 | 공종_중분류_하천공사                           | 1.60139 |
# |  22 | 인적사고   |       2 | 공종_중분류_미장공사                           | 1.64203 |
# |  36 | 인적사고   |       2 | 공종_중분류_철도 및 궤도공사                   | 1.64494 |
# |  72 | 인적사고   |       2 | 작업프로세스_적재작업                          | 1.64979 |
# |  44 | 인적사고   |       2 | 공종_중분류_항만공사                           | 1.66414 |
# |  13 | 인적사고   |       2 | 공종_중분류_교량공사                           | 1.66584 |
# | 138 | 인적사고   |       2 | 사고원인_주원인_설치·해체과정 관리 미흡        | 1.68144 |
# |  45 | 인적사고   |       2 | 공종_중분류_해체 및 철거공사                   | 1.68218 |
# | 152 | 인적사고   |       2 | 사고원인_주원인_적정 공법검토 미흡             | 1.69379 |
# |  99 | 인적사고   |       2 | 장소_대분류_방송통신시설                       |  1.7007 |
# | 109 | 인적사고   |       2 | 장소_대분류_위험물저장및처리시설               | 1.72396 |
# | 143 | 인적사고   |       2 | 사고원인_주원인_안전발판 설치 미흡             | 1.73919 |
# | 133 | 인적사고   |       2 | 사고원인_주원인_단독작업                       | 1.77207 |
# |  76 | 인적사고   |       2 | 작업프로세스_정비작업                          | 1.77474 |
# | 154 | 인적사고   |       2 | 사고원인_주원인_품질관리 미흡                  | 1.79126 |
# |  88 | 인적사고   |       2 | 장소_대분류_관개수로                           | 1.83416 |
# |  39 | 인적사고   |       2 | 공종_중분류_토공사                             | 1.93731 |
# |  19 | 인적사고   |       2 | 공종_중분류_도장공사                           |    1.95 |
# |  46 | 인적사고   |       2 | 요일_목요일                                    | 1.99319 |
# |  11 | 인적사고   |       2 | 공종_중분류_관공사                             | 1.99322 |
# |  47 | 인적사고   |       2 | 요일_수요일                                    | 1.99927 |
# | 131 | 인적사고   |       2 | 사고원인_주원인_기계장비 불안전한 거치         | 2.01343 |
# |  51 | 인적사고   |       2 | 요일_화요일                                    | 2.02196 |
# | 130 | 인적사고   |       2 | 사고원인_주원인_구조안전 미확보                | 2.03508 |
# |  59 | 인적사고   |       2 | 작업프로세스_벌목작업                          | 2.04154 |
# | 151 | 인적사고   |       2 | 사고원인_주원인_작업전 점검 미흡               | 2.06417 |
# | 121 | 인적사고   |       2 | 장소_대분류_하수처리시설                       | 2.07855 |
# |  48 | 인적사고   |       2 | 요일_월요일                                    | 2.08343 |
# | 128 | 인적사고   |       2 | 사고원인_주원인_계측데이터 관리 미흡           | 2.08955 |
# |  61 | 인적사고   |       2 | 작업프로세스_부설 및 다짐작업                  | 2.18764 |
# |  79 | 인적사고   |       2 | 작업프로세스_천공작업                          | 2.18768 |
# | 135 | 인적사고   |       2 | 사고원인_주원인_불량자재 관리 미흡             | 2.19976 |
# |  58 | 인적사고   |       2 | 작업프로세스_반출작업                          | 2.20132 |
# | 106 | 인적사고   |       2 | 장소_대분류_옹벽                               | 2.21157 |
# | 147 | 인적사고   |       2 | 사고원인_주원인_작업자 건강상태 확인 미흡      | 2.24966 |
# |  82 | 인적사고   |       2 | 작업프로세스_항타 및 항발작업                  | 2.26181 |
# |  38 | 인적사고   |       2 | 공종_중분류_터널공사                           | 2.26343 |
# | 100 | 인적사고   |       2 | 장소_대분류_방파제                             | 2.28284 |
# | 142 | 인적사고   |       2 | 사고원인_주원인_안전관리계획 수립 미흡         | 2.32984 |
# |  57 | 인적사고   |       2 | 작업프로세스_매설작업                          | 2.38335 |
# |  60 | 인적사고   |       2 | 작업프로세스_보수 및 교체작업                  | 2.39616 |
# |  85 | 인적사고   |       2 | 작업프로세스_확인 및 점검작업                  | 2.59983 |
# | 111 | 인적사고   |       2 | 장소_대분류_일반및고속철도                     | 2.60744 |
# | 114 | 인적사고   |       2 | 장소_대분류_제방(통관/호안)                    | 2.64343 |
# |  73 | 인적사고   |       2 | 작업프로세스_전기작업                          | 2.65369 |
# |  62 | 인적사고   |       2 | 작업프로세스_상차 및 하역작업                  | 2.67496 |
# | 137 | 인적사고   |       2 | 사고원인_주원인_사전 설계도서검토 미흡         | 2.74473 |
# |  65 | 인적사고   |       2 | 작업프로세스_쌓기작업                          | 2.80648 |
# | 127 | 인적사고   |       2 | 사고원인_주원인_개인 안전보호구 착용 불량      | 2.87839 |
# |  66 | 인적사고   |       2 | 작업프로세스_양중작업                          |  2.8908 |
# | 108 | 인적사고   |       2 | 장소_대분류_운수시설                           | 2.89587 |
# | 115 | 인적사고   |       2 | 장소_대분류_종교시설                           |  3.0624 |
# | 119 | 인적사고   |       2 | 장소_대분류_판매시설                           | 3.09739 |
# | 134 | 인적사고   |       2 | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 | 3.09792 |
# |  93 | 인적사고   |       2 | 장소_대분류_노유자시설                         | 3.16735 |
# | 116 | 인적사고   |       2 | 장소_대분류_지하철                             | 3.22124 |
# | 110 | 인적사고   |       2 | 장소_대분류_의료시설                           | 3.25241 |
# |  67 | 인적사고   |       2 | 작업프로세스_연결작업                          | 3.27874 |
# | 124 | 인적사고   |       2 | 장소_중분류_외부                               | 3.34006 |
# |  90 | 인적사고   |       2 | 장소_대분류_교정및군사시설                     |  3.3561 |
# | 103 | 인적사고   |       2 | 장소_대분류_석유화학공장                       | 3.35787 |
# |  68 | 인적사고   |       2 | 작업프로세스_용접작업                          | 3.41276 |
# | 112 | 인적사고   |       2 | 장소_대분류_자동차관련시설                     | 3.41842 |
# | 141 | 인적사고   |       2 | 사고원인_주원인_시방기준 등 미준수             | 3.47549 |
# |  71 | 인적사고   |       2 | 작업프로세스_인양작업                          | 3.50548 |
# |  97 | 인적사고   |       2 | 장소_대분류_도로터널                           | 3.53918 |
# |  53 | 인적사고   |       2 | 작업프로세스_굴착작업                          |   3.583 |
# |  49 | 인적사고   |       2 | 요일_일요일                                    | 3.76327 |
# | 118 | 인적사고   |       2 | 장소_대분류_철도터널                           | 3.81884 |
# |  80 | 인적사고   |       2 | 작업프로세스_청소작업                          |  3.8191 |
# | 140 | 인적사고   |       2 | 사고원인_주원인_시공품질 미확보                | 3.93221 |
# | 107 | 인적사고   |       2 | 장소_대분류_운동시설                           | 3.96842 |
# |  63 | 인적사고   |       2 | 작업프로세스_설비작업                          | 4.13545 |
# |   0 | 인적사고   |       2 | 총_공사기간                                    | 4.40619 |
# |  55 | 인적사고   |       2 | 작업프로세스_도장작업                          | 4.49597 |
# |  35 | 인적사고   |       2 | 공종_중분류_철근콘크리트공사                   | 4.55634 |
# | 139 | 인적사고   |       2 | 사고원인_주원인_시공관리 미흡                  |  4.6875 |
# | 144 | 인적사고   |       2 | 사고원인_주원인_운전자 자격관리 미흡           | 4.71284 |
# |   1 | 인적사고   |       2 | 공정률                                         | 4.88641 |
# | 122 | 인적사고   |       2 | 장소_중분류_내부                               | 5.30451 |
# |  94 | 인적사고   |       2 | 장소_대분류_단독주택                           | 5.63958 |
# | 102 | 인적사고   |       2 | 장소_대분류_상수도                             | 5.75755 |
# | 146 | 인적사고   |       2 | 사고원인_주원인_작업순서 미준수                | 5.90232 |
# | 104 | 인적사고   |       2 | 장소_대분류_숙박시설                           | 6.09686 |
# |  96 | 인적사고   |       2 | 장소_대분류_도로교량                           | 6.12281 |
# | 145 | 인적사고   |       2 | 사고원인_주원인_위험정보 미제공                | 6.17172 |
# |   7 | 인적사고   |       2 | 공종_대분류_토목                               | 6.34885 |
# |  78 | 인적사고   |       2 | 작업프로세스_준비작업                          | 6.63542 |
# |  98 | 인적사고   |       2 | 장소_대분류_문화및집회시설                     | 6.65736 |
# | 149 | 인적사고   |       2 | 사고원인_주원인_작업자 통제 미흡               | 6.83298 |
# | 101 | 인적사고   |       2 | 장소_대분류_부지조성                           | 7.01587 |
# |  74 | 인적사고   |       2 | 작업프로세스_절단작업                          |  7.0938 |
# |  81 | 인적사고   |       2 | 작업프로세스_타설작업                          |  7.2196 |
# |  24 | 인적사고   |       2 | 공종_중분류_산업설비공사                       | 7.73351 |
# | 120 | 인적사고   |       2 | 장소_대분류_하수도                             | 9.18902 |
# |  50 | 인적사고   |       2 | 요일_토요일                                    |  9.3357 |
# |  56 | 인적사고   |       2 | 작업프로세스_마감작업                          | 9.43312 |
# |  84 | 인적사고   |       2 | 작업프로세스_형틀 및 목공                      | 10.3601 |
# |  52 | 인적사고   |       2 | 공휴일여부_휴일                                | 11.2644 |
# ...
# |  76 | 인적사고   |       5 | 작업프로세스_정비작업                          | 1.77474 |
# | 154 | 인적사고   |       5 | 사고원인_주원인_품질관리 미흡                  | 1.79126 |
# |  88 | 인적사고   |       5 | 장소_대분류_관개수로                           | 1.83416 |
# |  39 | 인적사고   |       5 | 공종_중분류_토공사                             | 1.93731 |
# |  19 | 인적사고   |       5 | 공종_중분류_도장공사                           |    1.95 |
# |  46 | 인적사고   |       5 | 요일_목요일                                    | 1.99319 |
# |  11 | 인적사고   |       5 | 공종_중분류_관공사                             | 1.99322 |
# |  47 | 인적사고   |       5 | 요일_수요일                                    | 1.99927 |
# | 131 | 인적사고   |       5 | 사고원인_주원인_기계장비 불안전한 거치         | 2.01343 |
# |  51 | 인적사고   |       5 | 요일_화요일                                    | 2.02196 |
# | 130 | 인적사고   |       5 | 사고원인_주원인_구조안전 미확보                | 2.03508 |
# |  59 | 인적사고   |       5 | 작업프로세스_벌목작업                          | 2.04154 |
# | 151 | 인적사고   |       5 | 사고원인_주원인_작업전 점검 미흡               | 2.06417 |
# | 121 | 인적사고   |       5 | 장소_대분류_하수처리시설                       | 2.07855 |
# |  48 | 인적사고   |       5 | 요일_월요일                                    | 2.08343 |
# | 128 | 인적사고   |       5 | 사고원인_주원인_계측데이터 관리 미흡           | 2.08955 |
# |  61 | 인적사고   |       5 | 작업프로세스_부설 및 다짐작업                  | 2.18764 |
# |  79 | 인적사고   |       5 | 작업프로세스_천공작업                          | 2.18768 |
# | 135 | 인적사고   |       5 | 사고원인_주원인_불량자재 관리 미흡             | 2.19976 |
# |  58 | 인적사고   |       5 | 작업프로세스_반출작업                          | 2.20132 |
# | 106 | 인적사고   |       5 | 장소_대분류_옹벽                               | 2.21157 |
# | 147 | 인적사고   |       5 | 사고원인_주원인_작업자 건강상태 확인 미흡      | 2.24966 |
# |  82 | 인적사고   |       5 | 작업프로세스_항타 및 항발작업                  | 2.26181 |
# |  38 | 인적사고   |       5 | 공종_중분류_터널공사                           | 2.26343 |
# | 100 | 인적사고   |       5 | 장소_대분류_방파제                             | 2.28284 |
# | 142 | 인적사고   |       5 | 사고원인_주원인_안전관리계획 수립 미흡         | 2.32984 |
# |  57 | 인적사고   |       5 | 작업프로세스_매설작업                          | 2.38335 |
# |  60 | 인적사고   |       5 | 작업프로세스_보수 및 교체작업                  | 2.39616 |
# |  85 | 인적사고   |       5 | 작업프로세스_확인 및 점검작업                  | 2.59983 |
# | 111 | 인적사고   |       5 | 장소_대분류_일반및고속철도                     | 2.60744 |
# | 114 | 인적사고   |       5 | 장소_대분류_제방(통관/호안)                    | 2.64343 |
# |  73 | 인적사고   |       5 | 작업프로세스_전기작업                          | 2.65369 |
# |  62 | 인적사고   |       5 | 작업프로세스_상차 및 하역작업                  | 2.67496 |
# | 137 | 인적사고   |       5 | 사고원인_주원인_사전 설계도서검토 미흡         | 2.74473 |
# |  65 | 인적사고   |       5 | 작업프로세스_쌓기작업                          | 2.80648 |
# | 127 | 인적사고   |       5 | 사고원인_주원인_개인 안전보호구 착용 불량      | 2.87839 |
# |  66 | 인적사고   |       5 | 작업프로세스_양중작업                          |  2.8908 |
# | 108 | 인적사고   |       5 | 장소_대분류_운수시설                           | 2.89587 |
# | 115 | 인적사고   |       5 | 장소_대분류_종교시설                           |  3.0624 |
# | 119 | 인적사고   |       5 | 장소_대분류_판매시설                           | 3.09739 |
# | 134 | 인적사고   |       5 | 사고원인_주원인_부적정 기계장비 사용 통제 미흡 | 3.09792 |
# |  93 | 인적사고   |       5 | 장소_대분류_노유자시설                         | 3.16735 |
# | 116 | 인적사고   |       5 | 장소_대분류_지하철                             | 3.22124 |
# | 110 | 인적사고   |       5 | 장소_대분류_의료시설                           | 3.25241 |
# |  67 | 인적사고   |       5 | 작업프로세스_연결작업                          | 3.27874 |
# | 124 | 인적사고   |       5 | 장소_중분류_외부                               | 3.34006 |
# |  90 | 인적사고   |       5 | 장소_대분류_교정및군사시설                     |  3.3561 |
# | 103 | 인적사고   |       5 | 장소_대분류_석유화학공장                       | 3.35787 |
# |  68 | 인적사고   |       5 | 작업프로세스_용접작업                          | 3.41276 |
# | 112 | 인적사고   |       5 | 장소_대분류_자동차관련시설                     | 3.41842 |
# | 141 | 인적사고   |       5 | 사고원인_주원인_시방기준 등 미준수             | 3.47549 |
# |  71 | 인적사고   |       5 | 작업프로세스_인양작업                          | 3.50548 |
# |  97 | 인적사고   |       5 | 장소_대분류_도로터널                           | 3.53918 |
# |  53 | 인적사고   |       5 | 작업프로세스_굴착작업                          |   3.583 |
# |  49 | 인적사고   |       5 | 요일_일요일                                    | 3.76327 |
# | 118 | 인적사고   |       5 | 장소_대분류_철도터널                           | 3.81884 |
# |  80 | 인적사고   |       5 | 작업프로세스_청소작업                          |  3.8191 |
# | 140 | 인적사고   |       5 | 사고원인_주원인_시공품질 미확보                | 3.93221 |
# | 107 | 인적사고   |       5 | 장소_대분류_운동시설                           | 3.96842 |
# |  63 | 인적사고   |       5 | 작업프로세스_설비작업                          | 4.13545 |
# |   0 | 인적사고   |       5 | 총_공사기간                                    | 4.40619 |
# |  55 | 인적사고   |       5 | 작업프로세스_도장작업                          | 4.49597 |
# |  35 | 인적사고   |       5 | 공종_중분류_철근콘크리트공사                   | 4.55634 |
# | 139 | 인적사고   |       5 | 사고원인_주원인_시공관리 미흡                  |  4.6875 |
# | 144 | 인적사고   |       5 | 사고원인_주원인_운전자 자격관리 미흡           | 4.71284 |
# |   1 | 인적사고   |       5 | 공정률                                         | 4.88641 |
# | 122 | 인적사고   |       5 | 장소_중분류_내부                               | 5.30451 |
# |  94 | 인적사고   |       5 | 장소_대분류_단독주택                           | 5.63958 |
# | 102 | 인적사고   |       5 | 장소_대분류_상수도                             | 5.75755 |
# | 146 | 인적사고   |       5 | 사고원인_주원인_작업순서 미준수                | 5.90232 |
# | 104 | 인적사고   |       5 | 장소_대분류_숙박시설                           | 6.09686 |
# |  96 | 인적사고   |       5 | 장소_대분류_도로교량                           | 6.12281 |
# | 145 | 인적사고   |       5 | 사고원인_주원인_위험정보 미제공                | 6.17172 |
# |   7 | 인적사고   |       5 | 공종_대분류_토목                               | 6.34885 |
# |  78 | 인적사고   |       5 | 작업프로세스_준비작업                          | 6.63542 |
# |  98 | 인적사고   |       5 | 장소_대분류_문화및집회시설                     | 6.65736 |
# | 149 | 인적사고   |       5 | 사고원인_주원인_작업자 통제 미흡               | 6.83298 |
# | 101 | 인적사고   |       5 | 장소_대분류_부지조성                           | 7.01587 |
# |  74 | 인적사고   |       5 | 작업프로세스_절단작업                          |  7.0938 |
# |  81 | 인적사고   |       5 | 작업프로세스_타설작업                          |  7.2196 |
# |  24 | 인적사고   |       5 | 공종_중분류_산업설비공사                       | 7.73351 |
# | 120 | 인적사고   |       5 | 장소_대분류_하수도                             | 9.18902 |
# |  50 | 인적사고   |       5 | 요일_토요일                                    |  9.3357 |
# |  56 | 인적사고   |       5 | 작업프로세스_마감작업                          | 9.43312 |
# |  84 | 인적사고   |       5 | 작업프로세스_형틀 및 목공                      | 10.3601 |
# |  52 | 인적사고   |       5 | 공휴일여부_휴일                                | 11.2644 |
# | 117 | 인적사고   |       5 | 장소_대분류_창고시설                           | 11.6269 |
# |  26 | 인적사고   |       5 | 공종_중분류_전기설비공사                       | 12.2957 |
# |  77 | 인적사고   |       5 | 작업프로세스_조립작업                          | 12.4549 |
# |  95 | 인적사고   |       5 | 장소_대분류_도로                               | 13.6835 |
# |  75 | 인적사고   |       5 | 작업프로세스_정리작업                          | 14.9634 |
# | 150 | 인적사고   |       5 | 사고원인_주원인_작업자의 불안전한 행동         | 16.4008 |
# |  54 | 인적사고   |       5 | 작업프로세스_기타                              | 18.1458 |
# |  91 | 인적사고   |       5 | 장소_대분류_근린생활시설                       | 19.2283 |
# |   2 | 인적사고   |       5 | 전체공사비_분류                                | 19.5044 |
# |  89 | 인적사고   |       5 | 장소_대분류_교육연구시설                       | 19.8293 |
# |  69 | 인적사고   |       5 | 작업프로세스_운반작업                          | 20.4558 |
# |   3 | 인적사고   |       5 | 보호(방호)조치여부 - 안전방호                  | 20.6888 |
# |   4 | 인적사고   |       5 | 보호(방호)조치여부 - 개인방호                  | 22.1378 |
# |  70 | 인적사고   |       5 | 작업프로세스_이동                              | 24.1215 |
# |  83 | 인적사고   |       5 | 작업프로세스_해체작업                          | 24.1914 |
# | 132 | 인적사고   |       5 | 사고원인_주원인_기타                           | 24.2497 |
# | 105 | 인적사고   |       5 | 장소_대분류_업무시설                           | 25.8684 |
# |  87 | 인적사고   |       5 | 장소_대분류_공장                               | 26.5615 |
# |  92 | 인적사고   |       5 | 장소_대분류_기타                               | 34.0331 |
# |  15 | 인적사고   |       5 | 공종_중분류_기계설비공사                       | 34.9034 |
# |   5 | 인적사고   |       5 | 공종_대분류_기계설비                           | 35.1965 |
# |  64 | 인적사고   |       5 | 작업프로세스_설치작업                          | 40.0056 |
# |  16 | 인적사고   |       5 | 공종_중분류_기타                               |  48.485 |
# |   6 | 인적사고   |       5 | 공종_대분류_기타                               | 67.9927 |
# |  86 | 인적사고   |       5 | 장소_대분류_공동주택                           | 93.6798 |
# | 148 | 인적사고   |       5 | 사고원인_주원인_작업자 부주의                  | 103.184 |
# +-----+------------+---------+------------------------------------------------+---------+
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[58], line 1
#
# ----> 1 my_xgb_classification(x_train,y_train,x_test,y_test, pr=False,roc=False,hist=False,learning_curve=False)
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:1880, in my_xgb_classification(x_train, y_train, x_test, y_test, conf_matrix, cv, hist, roc, pr, multiclass, learning_curve, report, figsize, dpi, sort, is_print, **params)
#
#    1858 @register_method
#
#    1859 def my_xgb_classification(
#
#    1860     x_train: DataFrame,
#
#    (...)
#
#    1876     **params,
#
#    1877 ) -> XGBClassifier:
#
#    1878     params = get_hyper_params(classname=XGBClassifier)
#
# -> 1880     return __my_classification(
#
#    1881         classname=XGBClassifier,
#
#    1882         x_train=x_train,
#
#    1883         y_train=y_train,
#
#    1884         x_test=x_test,
#
#    1885         y_test=y_test,
#
#    1886         conf_matrix=conf_matrix,
#
#    1887         cv=cv,
#
#    1888         hist=hist,
#
#    1889         roc=roc,
#
#    1890         pr=pr,
#
#    1891         multiclass=multiclass,
#
#    1892         learning_curve=learning_curve,
#
#    1893         report=report,
#
#    1894         figsize=figsize,
#
#    1895         dpi=dpi,
#
#    1896         sort=sort,
#
#    1897         is_print=is_print,
#
#    1898         **params,
#
#    1899     )
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:145, in __my_classification(classname, x_train, y_train, x_test, y_test, conf_matrix, cv, hist, roc, pr, multiclass, learning_curve, report, figsize, dpi, sort, is_print, pruning, **params)
#
#     142 # ------------------------------------------------------
#
#     143 # 보고서 출력
#
#     144 if report and is_print:
#
# --> 145     my_classification_report(estimator, x_train, y_train, x_test, y_test, sort)
#
#     147 return estimator
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:509, in my_classification_report(estimator, x_train, y_train, x_test, y_test, sort)
#
#     507 else:
#
#     508     if x_test is not None and y_test is not None:
#
# --> 509         my_classification_multiclass_report(
#
#     510             estimator, x=x_test, y=y_test, sort=sort
#
#     511         )
#
#     512     else:
#
#     513         my_classification_multiclass_report(
#
#     514             estimator, x=x_train, y=y_train, sort=sort
#
#     515         )
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycallgraphix\wrapper.py:49, in register_method.<locals>.function_wrapper_for_node_storage(*args, **kwargs)
#
#      43     SingletonForCallGraph().set_entry(
#
#      44         entry=methodcall,
#
#      45         my_list=SingletonForCallGraph().my_list_source_functions,
#
#      46     )
#
#      48 start_time = time.perf_counter()
#
# ---> 49 result = func(*args, **kwargs)
#
#      50 end_time = time.perf_counter()
#
#      51 total_time_in_miliseconds = (end_time - start_time) * 1000
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:721, in my_classification_multiclass_report(estimator, x, y, sort)
#
#     718 for i in range(0, class_size):
#
#     719     # VIF
#
#     720     if len(x.columns) > 1:
#
# --> 721         vif = [
#
#     722             variance_inflation_factor(x, list(x.columns).index(v))
#
#     723             for i, v in enumerate(x.columns)
#
#     724         ]
#
#     725     else:
#
#     726         vif = 0
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\classification.py:722, in <listcomp>(.0)
#
#     718 for i in range(0, class_size):
#
#     719     # VIF
#
#     720     if len(x.columns) > 1:
#
#     721         vif = [
#
# --> 722             variance_inflation_factor(x, list(x.columns).index(v))
#
#     723             for i, v in enumerate(x.columns)
#
#     724         ]
#
#     725     else:
#
#     726         vif = 0
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\outliers_influence.py:197, in variance_inflation_factor(exog, exog_idx)
#
#     195 mask = np.arange(k_vars) != exog_idx
#
#     196 x_noti = exog[:, mask]
#
# --> 197 r_squared_i = OLS(x_i, x_noti).fit().rsquared
#
#     198 vif = 1. / (1. - r_squared_i)
#
#     199 return vif
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:335, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#
#     330 if method == "pinv":
#
#     331     if not (hasattr(self, 'pinv_wexog') and
#
#     332             hasattr(self, 'normalized_cov_params') and
#
#     333             hasattr(self, 'rank')):
#
# --> 335         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#
#     336         self.normalized_cov_params = np.dot(
#
#     337             self.pinv_wexog, np.transpose(self.pinv_wexog))
#
#     339         # Cache these singular values for use later.
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tools\tools.py:264, in pinv_extended(x, rcond)
#
#     262 x = np.asarray(x)
#
#     263 x = x.conjugate()
#
# --> 264 u, s, vt = np.linalg.svd(x, False)
#
#     265 s_orig = np.copy(s)
#
#     266 m = u.shape[0]
#
#
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#
#    1678         gufunc = _umath_linalg.svd_n_s
#
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#
#    1682 u = u.astype(result_t, copy=False)
#
#    1683 s = s.astype(_realType(result_t), copy=False)
#
#
#
# KeyboardInterrupt:
