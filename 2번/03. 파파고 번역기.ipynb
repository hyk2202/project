# %% [markdown]
# # 파파고 번역기
#
# 데이터 수집을 목적으로 할 경우 셀리니움은 requests가 접근하지 못하는 페이지에 접근하는 것이 주 용도이지만 원래 셀리니움은 웹 페이지 테스트 도구로 개발된 프로그램.
#
# 웹 페이지에 사용자가 직접 입력해야 하는 부분을 자동화 하는 것도 가능
# ## #01. 준비과정
#
# ### [1] 패키지 참조

# %%
import chromedriver_autoinstaller
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import time
import datetime as dt
import os
from selenium.webdriver.common.by import By
import re 
import json
import ast

# %% [markdown]
# ### [2] 번역할 파일 가져오기
#
# 번역할 문장이 행단위로 입력되어 있는 영문 텍스트 파일이 필요함

# %%
originSource = 'news.txt'

with open(originSource,'r',encoding='utf-8') as f:
    source = f.readlines()
    for i, s in enumerate(source):
        source[i] = s.strip()
source
# Out:
#   Cell In[37], line 1
# ...

# %% [markdown]
# ### [3] 크롬 브라우저 가동

# %%
chromedriver_autoinstaller.install()

driver = webdriver.Chrome()
driver.implicitly_wait(5)

# 파파고 페이지로 이동
driver.get("https://papago.naver.com/")
time.sleep(3) # 브라우저가 파파고로 이동하는데 걸리는 시간을 충분히 줘야함

# %% [markdown]
# ## #02. 번역 수행
#
# ### [1] step1
#
# 정석으로 작성

# %%
# 번역 결과가 저장될 텍스트 파일 생성

fileName = originSource[:originSource.rindex('.')]+'.md'

# %%
# 수업내용

# with open(fileName,"w",encoding="utf-8") as f: # 중간에 프로그램이 터지면 그전까지 번역했던것들을 저장해야함.
#     for s in source:
#         s = s.strip()
#         if not s:continue
#         print(s)
#         print('-'*50)

#         txtSource = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtSource"))
        
#         txtSource.clear() # 기존 입력값 삭제
#         txtSource.send_keys(s)
        
#         btnTranslate = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#btnTranslate"))
#         btnTranslate.click()

#         # 번역이 되는 동안 대기
#         time.sleep(1)

#         txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
        
#         # 번역결과 가져오기
#         currentTrans = txtTarget.text.strip()
#         print(currentTrans)
#         print('-'*50)
#         f.write(s)
#         f.write('\n\n')
#         f.write('> ')
#         f.write(currentTrans)
#         f.write('\n\n')

# %%
# 수정본

# 중간에 프로그램이 터져서 그 전까지만 저장된 경우 그 이후만 작동하면됨

if os.path.exists(fileName):
    with open(fileName,'r',encoding='utf-8') as f:
        check = f.readlines()
        check_list = []
        for s in check:
            s = s.strip()
            if not s : continue
            check_list.append(s)
        check_list = check_list[::2]
        # print(check_list)

    new_source = [x for x in source if x not in check_list]
    # print(new_source)
    with open(fileName,"a",encoding="utf-8") as f:  # 기존에 파일이 존재하는 경우 더해줘야함.
        for s in new_source:
            s = s.strip()
            if not s:continue
            print(s)
            print('-'*50)

            txtSource = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtSource"))
            
            txtSource.clear() # 기존 입력값 삭제
            txtSource.send_keys(s)
            
            btnTranslate = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#btnTranslate"))
            btnTranslate.click()

            # 번역이 되는 동안 대기
            time.sleep(1)

            txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
            
            # 번역결과 가져오기
            currentTrans = txtTarget.text.strip()
            print(currentTrans)
            print('-'*50)

            f.write(s)
            f.write('\n\n')
            f.write('> ')
            f.write(currentTrans)
            f.write('\n\n')
else:
    with open(fileName,"w",encoding="utf-8") as f: # 중간에 프로그램이 터지면 그전까지 번역했던것들을 저장해야함.
        for s in source:
            s = s.strip()
            if not s:continue
            print(s)
            print('-'*50)

            txtSource = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtSource"))
            
            txtSource.clear() # 기존 입력값 삭제
            txtSource.send_keys(s)
            
            btnTranslate = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#btnTranslate"))
            btnTranslate.click()

            # 번역이 되는 동안 대기
            time.sleep(1)

            txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
            
            # 번역결과 가져오기
            currentTrans = txtTarget.text.strip()
            print(currentTrans)
            print('-'*50)

            f.write(s)
            f.write('\n\n')
            f.write('> ')
            f.write(currentTrans)
            f.write('\n\n')

# %% [markdown]
# html 사용자 입력을 받아주는 태그
#
# `<input type = 'OOO'>` : 한줄입력
#
# `<textarea>` : 여러줄 입력

# %% [markdown]
# ### [2] step2
#
# 실제 사용시 생긴 오류 수정
#
# => step1 코드 전부를 긁어온 후 수정

# %%
# 수업내용
# prevTrans = ''
# prevSource = ''
# with open(fileName,"w",encoding="utf-8") as f: # 중간에 프로그램이 터지면 그전까지 번역했던것들을 저장해야함.
#     for s in source:
#         s = s.strip()
#         if not s:continue
#         # print(s)
#         # print('-'*50)

#         txtSource = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtSource"))
        
#         txtSource.clear() # 기존 입력값 삭제
#         txtSource.send_keys(s)
        
#         btnTranslate = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#btnTranslate"))
#         btnTranslate.click()

#         # 번역이 되는 동안 대기
#         time.sleep(1)

#         txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
        
#         # 번역결과 가져오기
#         currentTrans = txtTarget.text.strip()
#         while prevTrans == currentTrans: # 통신오류나 번역이 오래걸리는 경우 이전 번역결과를 가져와서 그대로 붙여넣게된다. 해당 오류 수정
            
#             if s == prevSource: break # 만약 실제 내용이 이전 내용과 동일하다면 해당 루프를 탈출하지 못하므로 해당 내용 수정
#             time.sleep(0.5)
#             txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
#             currentTrans = txtTarget.text.strip()
#         prevSource = s
#         prevTrans = currentTrans
#         # print(currentTrans)
#         # print('-'*50)
#         f.write(s)
#         f.write('\n\n')
#         f.write('> ')
#         f.write(currentTrans)
#         f.write('\n\n')

# %%
# 수정

def do_it(SOURCE):
    txtSource = None
    btnTranslate = None
    txtTarget = None
    for s in SOURCE:
        s = s.strip()
        if not s:continue
        # print(s)
        # print('-'*50)
        if txtSource:
            pass
        else:
            txtSource = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtSource"))
        
        txtSource.clear() # 기존 입력값 삭제
        txtSource.send_keys(s)
        if btnTranslate:
            pass
        else:
            btnTranslate = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#btnTranslate"))
        btnTranslate.click()

        # 번역이 되는 동안 대기
        time.sleep(1)
        if txtTarget:
            pass
        else:
            txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
        
        # 번역결과 가져오기
        currentTrans = txtTarget.text.strip()
        prevTrans = ''
        while prevTrans == currentTrans: 
            if s == prevSource: break 
            time.sleep(0.5)
            if txtTarget:
                pass
            else:
                txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
            currentTrans = txtTarget.text.strip()
        prevSource = s
        prevTrans = currentTrans
        # print(currentTrans)
        # print('-'*50)

        f.write(s)
        f.write('\n\n')
        f.write('> ')
        f.write(currentTrans)
        f.write('\n\n')

if os.path.exists(fileName):
    with open(fileName,'r',encoding='utf-8') as f:
        check = f.readlines()
        check_list = []
        for s in check:
            s = s.strip()
            if not s : continue
            check_list.append(s)
        if len(check_list)>2:
            check_list = check_list[:-2] # 마지막 부분 제거
        if len(check_list)%2==1:
            check_list = check_list[:-1] # 번역이 안된경우 해당 원문 삭제
        if len(check_list) >=2:
            prevTrans = check_list[-1][2:] # `> ` 부분 제거
            prevSource = check_list[-2]
            check_list = check_list[::2]
        else : 
            prevTrans = ''
            prevSource = ''
            check_list = []
        # print(prevTrans)
        # print('-'*50)
        # print(prevSource)
        # print(check_list)

    new_source = [x for x in source if x not in check_list]
    # print(new_source)
    
    
    with open(fileName,"a",encoding="utf-8") as f:  # 기존에 파일이 존재하는 경우 더해줘야함.
        do_it(new_source)
else:
    prevTrans = ''
    prevSource = ''
    
    with open(fileName,"w",encoding="utf-8") as f: 
        do_it(source)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[13], line 83
#      79     # print(new_source)
#      82     with open(fileName,"a",encoding="utf-8") as f:  # 기존에 파일이 존재하는 경우 더해줘야함.
# ---> 83         do_it(new_source)
#      84 else:
#      85     prevTrans = ''
#
# Cell In[13], line 34, in do_it(SOURCE)
#      32 # 번역결과 가져오기
#      33 currentTrans = txtTarget.text.strip()
# ---> 34 while prevTrans == currentTrans:
#      35     if s == prevSource: break
#      36     time.sleep(0.5)
#
# UnboundLocalError: cannot access local variable 'prevTrans' where it is not associated with a value

# %%
# 효율을 포기하고 다른 웹사이트에 대해  커버가 가능한 소스코드
# 수정

def do_it(SOURCE):
    txtSource = None
    btnTranslate = None
    txtTarget = None
    for s in SOURCE:
        s = s.strip()
        if not s:continue
        # print(s)
        # print('-'*50)
        txtSource = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtSource"))
        
        txtSource.clear() # 기존 입력값 삭제
        txtSource.send_keys(s)
        btnTranslate = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#btnTranslate"))
        btnTranslate.click()

        # 번역이 되는 동안 대기
        time.sleep(1)
        txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
        
        # 번역결과 가져오기
        currentTrans = txtTarget.text.strip()
        while prevTrans == currentTrans: 
            if s == prevSource: break 
            time.sleep(0.5)
            txtTarget = WebDriverWait(driver, 3).until(lambda x:x.find_element(By.CSS_SELECTOR,"#txtTarget"))
            currentTrans = txtTarget.text.strip()
        prevSource = s
        prevTrans = currentTrans
        # print(currentTrans)
        # print('-'*50)

        f.write(s)
        f.write('\n\n')
        f.write('> ')
        f.write(currentTrans)
        f.write('\n\n')

if os.path.exists(fileName):
    with open(fileName,'r',encoding='utf-8') as f:
        check = f.readlines()
        check_list = []
        for s in check:
            s = s.strip()
            if not s : continue
            check_list.append(s)
        prevTrans = check_list[-1][2:] # `> ` 부분 제거
        prevSource = check_list[-2]
        # print(prevTrans)
        # print('-'*50)
        # print(prevSource)
        check_list = check_list[::2]
        # print(check_list)

    new_source = [x for x in source if x not in check_list]
    # print(new_source)
    
    
    with open(fileName,"a",encoding="utf-8") as f:  # 기존에 파일이 존재하는 경우 더해줘야함.
        do_it(new_source)
else:
    prevTrans = ''
    prevSource = ''
    
    with open(fileName,"w",encoding="utf-8") as f: 
        do_it(source)
